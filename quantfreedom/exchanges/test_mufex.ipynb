# %%
from quantfreedom.exchanges.mufex import Mufex

from requests import get
from datetime import datetime, timedelta
import pandas as pd
import numpy as np

mufex = Mufex()
# %load_ext autoreload
# %autoreload 2

# %%
mufex.get_candles(candles_to_dl=435)
# Out:
# since_date_ms=2023-09-27 10:23:04, until_date_ms=2023-09-28 22:38:04
# Got 200 new candles for since=2023-09-27 10:23:04
# Getting candles since=2023-09-28 03:00:01
# Got 200 new candles for since=2023-09-28 03:00:01
# Getting candles since=2023-09-28 19:40:01
# Got 35 new candles for since=2023-09-28 19:40:01
# Getting candles since=2023-09-28 22:35:01
# Got 0 candles
# It took 0.03 minutes to create the candles dataframe
#               timestamp     open     high      low    close
# 0   2023-09-27 10:25:00  26366.3  26400.0  26366.3  26393.3
# 1   2023-09-27 10:30:00  26393.3  26420.3  26383.2  26412.4
# 2   2023-09-27 10:35:00  26412.4  26469.0  26411.2  26435.4
# 3   2023-09-27 10:40:00  26435.4  26444.3  26412.1  26412.7
# 4   2023-09-27 10:45:00  26412.7  26457.2  26412.7  26429.8
# ..                  ...      ...      ...      ...      ...
# 430 2023-09-28 22:15:00  26952.3  26980.8  26943.8  26980.8
# 431 2023-09-28 22:20:00  26980.8  27017.8  26976.7  27010.0
# 432 2023-09-28 22:25:00  27010.0  27018.9  27001.8  27012.3
# 433 2023-09-28 22:30:00  27012.3  27022.1  27005.1  27022.1
# 434 2023-09-28 22:35:00  27022.1  27038.5  27016.0  27034.8
#
# [435 rows x 5 columns]
