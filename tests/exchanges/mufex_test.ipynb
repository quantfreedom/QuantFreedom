# %%
import numpy as np
import pandas as pd
from my_stuff import MufexTestKeys, MufexKeys
from quantfreedom.exchanges.mufex_exchange.mufex import Mufex
from quantfreedom.helper_funcs import candles_to_df

np.set_printoptions(formatter={"float_kind": "{:0.1f}".format})

# %load_ext autoreload
# %autoreload 2

# %%
mufex_test = Mufex(
    api_key=MufexTestKeys.api_key,
    secret_key=MufexTestKeys.secret_key,
    use_test_net=True
)

# %%
mufex_test.get_all_symbols_info()
# Out:
# [{'symbol': 'ADAUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'ADA',
#   'quoteCoin': 'USDT',
#   'launchTime': '1697523406000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '4',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '50.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.0001',
#    'maxPrice': '9999999.0000',
#    'tickSize': '0.0001'},
#   'lotSizeFilter': {'maxTradingQty': '200000',
#    'minTradingQty': '1',
#    'qtyStep': '1',
#    'postOnlyMaxOrderQty': '1000000'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'},
#  {'symbol': 'APEUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'APE',
#   'quoteCoin': 'USDT',
#   'launchTime': '1697522978000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '3',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '50.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.001',
#    'maxPrice': '9999999.000',
#    'tickSize': '0.001'},
#   'lotSizeFilter': {'maxTradingQty': '100000',
#    'minTradingQty': '1',
#    'qtyStep': '1',
#    'postOnlyMaxOrderQty': '500000'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'},
#  {'symbol': 'AVAXUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'AVAX',
#   'quoteCoin': 'USDT',
#   'launchTime': '1697433821000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '3',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '50.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.001',
#    'maxPrice': '9999999.000',
#    'tickSize': '0.001'},
#   'lotSizeFilter': {'maxTradingQty': '5000',
#    'minTradingQty': '1',
#    'qtyStep': '1',
#    'postOnlyMaxOrderQty': '25000'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'},
#  {'symbol': 'BTCUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'BTC',
#   'quoteCoin': 'USDT',
#   'launchTime': '1699843410000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '2',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '150.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.10',
#    'maxPrice': '9999999.00',
#    'tickSize': '0.10'},
#   'lotSizeFilter': {'maxTradingQty': '100.000',
#    'minTradingQty': '0.001',
#    'qtyStep': '0.001',
#    'postOnlyMaxOrderQty': '500.000'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'},
#  {'symbol': 'DOTUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'DOT',
#   'quoteCoin': 'USDT',
#   'launchTime': '1697523642000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '3',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '50.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.001',
#    'maxPrice': '9999999.000',
#    'tickSize': '0.001'},
#   'lotSizeFilter': {'maxTradingQty': '50000.0',
#    'minTradingQty': '0.1',
#    'qtyStep': '0.1',
#    'postOnlyMaxOrderQty': '250000.0'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'},
#  {'symbol': 'ETCUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'ETC',
#   'quoteCoin': 'USDT',
#   'launchTime': '1697523884000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '3',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '50.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.001',
#    'maxPrice': '9999999.000',
#    'tickSize': '0.001'},
#   'lotSizeFilter': {'maxTradingQty': '10000.00',
#    'minTradingQty': '0.01',
#    'qtyStep': '0.01',
#    'postOnlyMaxOrderQty': '50000.00'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'},
#  {'symbol': 'ETHUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'ETH',
#   'quoteCoin': 'USDT',
#   'launchTime': '1637731965000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '2',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '150.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.01',
#    'maxPrice': '999999.00',
#    'tickSize': '0.01'},
#   'lotSizeFilter': {'maxTradingQty': '1000.00',
#    'minTradingQty': '0.01',
#    'qtyStep': '0.01',
#    'postOnlyMaxOrderQty': '5000.00'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'},
#  {'symbol': 'GMTUSDT',
#   'contractType': 'LinearPerpetual',
#   'status': 'Trading',
#   'baseCoin': 'GMT',
#   'quoteCoin': 'USDT',
#   'launchTime': '1697429505000',
#   'deliveryTime': '0',
#   'deliveryFeeRate': '',
#   'priceScale': '4',
#   'leverageFilter': {'minLeverage': '1',
#    'maxLeverage': '50.00',
#    'leverageStep': '0.01'},
#   'priceFilter': {'minPrice': '0.0001',
#    'maxPrice': '9999999.0000',
#    'tickSize': '0.0001'},
#   'lotSizeFilter': {'maxTradingQty': '100000',
#    'minTradingQty': '1',
#    'qtyStep': '1',
#    'postOnlyMaxOrderQty': '500000'},
#   'unifiedMarginTrade': True,
#   'fundingInterval': 480,
#   'settleCoin': 'USDT'}]
