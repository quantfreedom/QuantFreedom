# %%
import sys, os
from my_keys import MufexKeys
from multiprocessing import cpu_count
import pandas as pd
import numpy as np
from quantfreedom.helpers.helper_funcs import dl_ex_candles
from quantfreedom.core.backtest import or_backtest
from datetime import datetime
from time import gmtime, strftime

from strat import exchange_settings_tuple, static_os_tuple, long_strat

# %load_ext autoreload
# %autoreload 2

# %%
# %run -i long_backtest.py
# Out:
# Downloading candles
# Starting the backtest now ... and also here are some stats for your backtest.
#
# Total threads to use: 32
# Total indicator settings to test: 3
# Total order settings to test: 960
# Total settings combinations to test: 2,880
# Total settings combination chunks to process at the same time: 90
#
# Total candles: 8,928
# Total candles to test: 25,712,640
# Total candle chunks to be processed at the same time: 803,520
#
#
# Backtest results done now saving to hdf5
#
#
# It took 00 mins and 42 seconds to complete the backtest

# %%
pd.read_hdf('backtest_results.h5').sort_values('qf_score', ascending=False).head(15)
# Out:
#          total_trades  wins  losses  gains_pct  win_rate  qf_score  fees_paid  \
# set_idx
# 366              26.0    13      13    182.479    50.000     0.913    318.736
# 426              23.0    12      11    171.997    52.174     0.906    242.263
# 447              27.0    13      14    224.677    48.148     0.900    351.978
# 435              24.0    13      11    169.206    54.167     0.897    243.665
# 369              23.0    12      11    183.653    52.174     0.895    264.257
# 405              20.0    11       9    193.861    55.000     0.885    236.348
# 402              20.0    11       9    193.861    55.000     0.885    236.348
# 399              20.0    11       9    193.861    55.000     0.885    236.348
# 411              19.0    10       9    199.544    52.632     0.883    210.950
# 414              19.0    10       9    199.544    52.632     0.883    210.950
# 417              19.0    10       9    199.544    52.632     0.883    210.950
# 1389              9.0     7       2    365.552    77.778     0.874    125.207
# 459              17.0     9       8    148.065    52.941     0.861    186.953
# 462              17.0     9       8    148.065    52.941     0.861    186.953
# 465              17.0     9       8    148.065    52.941     0.861    186.953
#
#          total_pnl  ending_eq
# set_idx
# 366       1824.789   2824.789
# 426       1719.969   2719.969
# 447       2246.766   3246.766
# 435       1692.064   2692.064
# 369       1836.533   2836.533
# 405       1938.612   2938.612
# 402       1938.612   2938.612
# 399       1938.612   2938.612
# 411       1995.443   2995.443
# 414       1995.443   2995.443
# 417       1995.443   2995.443
# 1389      3655.523   4655.523
# 459       1480.651   2480.651
# 462       1480.651   2480.651
# 465       1480.651   2480.651

# %%
candles = dl_ex_candles(
    exchange="mufex",
    symbol="BTCUSDT",
    timeframe="5m",
    since_datetime=datetime(2023, 10, 1),
    until_datetime=datetime(2023, 11, 1),
)

backtest_results = or_backtest(
    candles=candles,
    exchange_settings_tuple=exchange_settings_tuple,
    static_os_tuple=static_os_tuple,
    strategy=long_strat,
    set_idx=435,
    disable_logger=False,
    plot_results=True,
)
# Out:
# DynamicOrderSettings(
#     account_pct_risk_per_trade = 0.03,
#     max_trades = 2,
#     risk_reward = 3.0,
#     sl_based_on_add_pct = 0.005,
#     sl_based_on_lookback = 50,
#     sl_bcb_type = 6,
#     sl_to_be_cb_type = 10,
#     sl_to_be_when_pct = 0.0,
#     trail_sl_bcb_type = 6,
#     trail_sl_by_pct = 0.01,
#     trail_sl_when_pct = 0.02,
# )
# IndicatorSettings(
#     rsi_is_above = 0,
#     rsi_is_below = 80,
#     rsi_length = 14,
# )
