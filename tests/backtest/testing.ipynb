# %%
import sys, os
from my_keys import MufexKeys
from multiprocessing import cpu_count
import pandas as pd
import numpy as np
from quantfreedom.helper_funcs import dl_ex_candles
from quantfreedom.backtest import or_backtest
from datetime import datetime
from time import gmtime, strftime

from strat import exchange_settings_tuple, static_os_tuple, long_strat

# %load_ext autoreload
# %autoreload 2

# %%
# %run -i run_backtest.py 32
# Out:
# Downloading candles
# Starting the backtest now ... and also here are some stats for your backtest.
#
# Total threads to use: 32
# Total indicator settings to test: 3
# Total order settings to test: 320
# Total settings combinations to test: 960
# Total settings combination chunks to process at the same time: 30
#
# Total candles: 10,368
# Total candles to test: 9,953,280
# Total candle chunks to be processed at the same time: 311,040
# Backtest took 78.55 seconds.

# %%
# Out:
# 'Wednesday, December 31, 1969 04:00:32'

# %%
pd.read_hdf('backtest_results.h5').sort_values('qf_score', ascending=False)
# Out:
# Empty DataFrame
# Columns: [total_trades, wins, losses, gains_pct, win_rate, qf_score, fees_paid, total_pnl, ending_eq]
# Index: []

# %%
candles = dl_ex_candles(
        exchange="binance_usdm",
        symbol="BTCUSDT",
        timeframe="5m",
        since_datetime=datetime(2024, 3, 1),
        until_datetime=datetime(2024, 4, 6),
    )

backtest_results = or_backtest(
    candles=candles,
    exchange_settings_tuple=exchange_settings_tuple,
    static_os_tuple=static_os_tuple,
    strategy=long_strat,
    set_idx=711,
    logger_bool=True,
    plot_results=True,
)
# Out:
# DynamicOrderSettings(
#     account_pct_risk_per_trade = 0.03,
#     max_trades = 4,
#     risk_reward = 5.0,
#     sl_based_on_add_pct = 0.002,
#     sl_based_on_lookback = 50,
#     sl_bcb_type = 3,
#     sl_to_be_cb_type = 6,
#     sl_to_be_when_pct = 0.0,
#     trail_sl_bcb_type = 3,
#     trail_sl_by_pct = 0.04,
#     trail_sl_when_pct = 0.02,
# )
# IndicatorSettings(
#     rsi_is_above = 0,
#     rsi_is_below = 40,
#     rsi_length = 14,
# )
