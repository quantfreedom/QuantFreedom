# %%
import pandas as pd
import numpy as np

from quantfreedom.enums.enums import OrderType
from quantfreedom.plotting.plot_helper_functions import (
    get_candle_trace_data,
    append_to_trace_data_list,
)

import plotly.graph_objects as go
import dash_bootstrap_components as dbc
from dash import Dash, dcc, html, dash_table
from jupyter_dash import JupyterDash
from plotly.subplots import make_subplots
from dash_bootstrap_templates import load_figure_template

from quantfreedom.utils import clear_cache
from quantfreedom.indicators.talib_ind import from_talib
from quantfreedom.evaluators.evaluators import eval_is_below, eval_is_above, combine_evals
import talib
from talib.abstract import Function
prices = pd.read_hdf('../data/prices.hd5')

# %%
rsi_ind = from_talib(
    func_name='rsi',
    df_prices=prices,
    cart_product=False,
    combos=False,
    timeperiod=[15, 30, 50],
)
rsi_ind['BTCUSDT'][15]
# Out:
# open_time
# 2022-04-01 00:00:00     NaN
# 2022-04-01 00:30:00     NaN
# 2022-04-01 01:00:00     NaN
# 2022-04-01 01:30:00     NaN
# 2022-04-01 02:00:00     NaN
#                        ...
# 2023-01-02 22:00:00   53.93
# 2023-01-02 22:30:00   46.42
# 2023-01-02 23:00:00   50.39
# 2023-01-02 23:30:00   41.23
# 2023-01-03 00:00:00   44.21
# Name: 15, Length: 13296, dtype: float64

# %%
bbands = from_talib(
    func_name='bbands',
    df_prices=prices,
    cart_product=False,
    combos=False,  
)
bbands
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 bbands = from_talib(
#       2     func_name='bbands',
#       3     df_prices=prices,
#       4     cart_product=False,
#       5     combos=False,
#       6 )
#       7 bbands
#
# File e:\coding\backtesters\quantfreedom\quantfreedom\indicators\talib_ind.py:323, in from_talib(func_name, cart_product, combos, df_prices, user_ind_df, **kwargs)
#     319         ind_settings_tup = ind_settings_tup + \
#     320             (float(x[c]),)
#     321 if in_names_key == "price":
#     322     final_array[:, counter] = Function(func_name)(
# --> 323         temp_df_prices,
#     324         *ind_settings_tup,
#     325         price=input_names_dict[in_names_key],
#     326     )[out_name]
#     328     pd_multind_tuples = pd_multind_tuples + (
#     329         current_symbol_tuple +
#     330         (out_name,) + ind_settings_tup,
#     331     )
#     332 elif in_names_key == "prices":
#
# File talib/_abstract.pxi:426, in talib._ta_lib.Function.__call__()
#
# File talib/_abstract.pxi:295, in talib._ta_lib.Function.set_function_args()
#
# File talib/_abstract.pxi:493, in talib._ta_lib.Function.__check_opt_input_value()
#
# TypeError: Invalid parameter value for nbdevup (expected float, got int)

# %%
stoch_ind
# Out:
# symbol              BTCUSDT                               XRPUSDT              \
# STOCH_output_names    slowk             slowd               slowk
# STOCH_fastk_period       5     10    15    5     10    15      5     10    15
# STOCH_slowk_period        3     3     3     3     3     3       3     3     3
# STOCH_slowk_matype        0     0     0     0     0     0       0     0     0
# STOCH_slowd_period        3     3     3     3     3     3       3     3     3
# STOCH_slowd_matype        0     0     0     0     0     0       0     0     0
# open_time
# 2022-04-01 00:00:00     NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN
# 2022-04-01 00:30:00     NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN
# 2022-04-01 01:00:00     NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN
# 2022-04-01 01:30:00     NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN
# 2022-04-01 02:00:00     NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN
# ...                     ...   ...   ...   ...   ...   ...     ...   ...   ...
# 2023-01-02 22:00:00   37.43 43.13 53.00 52.32 56.98 64.64   45.46 48.03 73.34
# 2023-01-02 22:30:00   26.63 28.49 35.91 39.99 44.96 52.59   27.75 33.67 53.32
# 2023-01-02 23:00:00   19.92 20.37 23.67 27.99 30.66 37.52   11.00 16.14 30.59
# 2023-01-02 23:30:00   18.40 18.40 18.40 21.65 22.42 25.99   12.50 12.50 14.09
# 2023-01-03 00:00:00   23.24 20.69 20.69 20.52 19.82 20.92    8.00  8.00  7.50
#
# symbol
# STOCH_output_names  slowd
# STOCH_fastk_period     5     10    15
# STOCH_slowk_period      3     3     3
# STOCH_slowk_matype      0     0     0
# STOCH_slowd_period      3     3     3
# STOCH_slowd_matype      0     0     0
# open_time
# 2022-04-01 00:00:00   NaN   NaN   NaN
# 2022-04-01 00:30:00   NaN   NaN   NaN
# 2022-04-01 01:00:00   NaN   NaN   NaN
# 2022-04-01 01:30:00   NaN   NaN   NaN
# 2022-04-01 02:00:00   NaN   NaN   NaN
# ...                   ...   ...   ...
# 2023-01-02 22:00:00 64.32 60.28 79.82
# 2023-01-02 22:30:00 47.86 48.69 69.60
# 2023-01-02 23:00:00 28.07 32.62 52.41
# 2023-01-02 23:30:00 17.08 20.77 32.67
# 2023-01-03 00:00:00 10.50 12.22 17.39
#
# [13296 rows x 12 columns]

# %%
ema_ind_on_rsi = from_talib(
    func_name='ema',
    user_ind_df=rsi_ind,
    cart_product=False,
    combos=False,
    timeperiod=[5, 20, 30]
)
ema_ind_on_rsi
# Out:
# symbol              BTCUSDT                                                  \
# RSI_timeperiod           15                30                50
# RSI_EMA_timeperiod       5     20    30    5     20    30    5     20    30
# open_time
# 2022-04-01 00:00:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 00:30:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:00:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:30:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 02:00:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2023-01-02 22:00:00   57.80 58.54 58.75 58.24 58.57 58.43 57.04 57.02 56.73
# 2023-01-02 22:30:00   54.01 57.39 57.96 56.25 57.97 58.03 55.87 56.69 56.52
# 2023-01-02 23:00:00   52.80 56.72 57.47 55.54 57.60 57.78 55.45 56.49 56.40
# 2023-01-02 23:30:00   48.95 55.25 56.42 53.26 56.75 57.19 54.03 55.99 56.07
# 2023-01-03 00:00:00   47.37 54.19 55.63 52.21 56.12 56.73 53.36 55.61 55.80
#
# symbol              XRPUSDT
# RSI_timeperiod           15                30                50
# RSI_EMA_timeperiod       5     20    30    5     20    30    5     20    30
# open_time
# 2022-04-01 00:00:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 00:30:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:00:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:30:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 02:00:00     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2023-01-02 22:00:00   65.74 66.19 64.05 63.06 61.92 59.81 59.78 58.38 56.62
# 2023-01-02 22:30:00   61.10 64.83 63.27 60.73 61.36 59.57 58.33 58.10 56.55
# 2023-01-02 23:00:00   57.83 63.53 62.49 59.07 60.82 59.32 57.30 57.83 56.46
# 2023-01-02 23:30:00   55.64 62.37 61.77 57.97 60.34 59.09 56.61 57.58 56.38
# 2023-01-03 00:00:00   51.76 60.62 60.62 55.87 59.52 58.62 55.27 57.11 56.14
#
# [13296 rows x 18 columns]

# %%
ema_ind_on_stoch = from_talib(
    func_name='ema',
    user_ind_df=stoch_ind,
    cart_product=False,
    combos=False,
    timeperiod=[20, 40, 60, 100]
)
ema_ind_on_stoch
# Out:
# symbol               BTCUSDT                                                  \
# STOCH_output_names     slowk
# STOCH_fastk_period        5                       10                      15
# STOCH_slowk_period         3                       3                       3
# STOCH_slowk_matype         0                       0                       0
# STOCH_slowd_period         3                       3                       3
# STOCH_slowd_matype         0                       0                       0
# STOCH_EMA_timeperiod     20    40    60    100   20    40    60    100   20
# open_time
# 2022-04-01 00:00:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 00:30:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:00:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:30:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 02:00:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2023-01-02 22:00:00    53.92 52.36 51.96 51.34 57.49 56.64 56.22 55.09 63.04
# 2023-01-02 22:30:00    51.32 51.11 51.13 50.85 54.73 55.27 55.31 54.57 60.45
# 2023-01-02 23:00:00    48.33 49.59 50.10 50.24 51.46 53.57 54.16 53.89 56.95
# 2023-01-02 23:30:00    45.48 48.07 49.06 49.61 48.31 51.85 52.99 53.19 53.28
# 2023-01-03 00:00:00    43.36 46.85 48.22 49.09 45.68 50.33 51.93 52.54 50.17
#
# symbol                      ... XRPUSDT                                      \
# STOCH_output_names          ...   slowd
# STOCH_fastk_period          ...      5           10                      15
# STOCH_slowk_period          ...       3           3                       3
# STOCH_slowk_matype          ...       0           0                       0
# STOCH_slowd_period          ...       3           3                       3
# STOCH_slowd_matype          ...       0           0                       0
# STOCH_EMA_timeperiod   40   ...     60    100   20    40    60    100   20
# open_time                   ...
# 2022-04-01 00:00:00    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 00:30:00    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:00:00    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 01:30:00    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2022-04-01 02:00:00    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                    ...  ...     ...   ...   ...   ...   ...   ...   ...
# 2023-01-02 22:00:00  62.46  ...   59.28 58.12 68.77 68.66 66.86 63.35 77.65
# 2023-01-02 22:30:00  61.16  ...   58.91 57.92 66.85 67.69 66.26 63.06 76.88
# 2023-01-02 23:00:00  59.33  ...   57.90 57.33 63.59 65.98 65.16 62.45 74.55
# 2023-01-02 23:30:00  57.34  ...   56.56 56.53 59.52 63.77 63.70 61.63 70.56
# 2023-01-03 00:00:00  55.55  ...   55.05 55.62 55.01 61.26 62.02 60.65 65.50
#
# symbol
# STOCH_output_names
# STOCH_fastk_period
# STOCH_slowk_period
# STOCH_slowk_matype
# STOCH_slowd_period
# STOCH_slowd_matype
# STOCH_EMA_timeperiod   40    60    100
# open_time
# 2022-04-01 00:00:00    NaN   NaN   NaN
# 2022-04-01 00:30:00    NaN   NaN   NaN
# 2022-04-01 01:00:00    NaN   NaN   NaN
# 2022-04-01 01:30:00    NaN   NaN   NaN
# 2022-04-01 02:00:00    NaN   NaN   NaN
# ...                    ...   ...   ...
# 2023-01-02 22:00:00  76.13 73.08 67.71
# 2023-01-02 22:30:00  75.81 72.97 67.74
# 2023-01-02 23:00:00  74.67 72.30 67.44
# 2023-01-02 23:30:00  72.62 71.00 66.75
# 2023-01-03 00:00:00  69.93 69.24 65.77
#
# [13296 rows x 48 columns]

# %%
ema_below_rsi = eval_is_below(
    want_to_evaluate=ema_ind_on_rsi,
    indicator_data=rsi_ind,
)
ema_above_stoch_slowk = eval_is_above(
    want_to_evaluate=ema_ind_on_stoch,
    indicator_data=stoch_ind_slowk,
)

# %%
combos_finished = combine_evals(
    bigger_df=ema_above_stoch_slowk,
    smaller_df=ema_below_rsi,
)

# %%
combos_finished
# Out:
# STOCH_fastk_period       5                                                    \
# STOCH_slowk_period        3
# STOCH_slowk_matype        0
# STOCH_slowd_period        3
# STOCH_slowd_matype        0
# STOCH_EMA_timeperiod    20
# EMA_is_above          STOCH
# RSI_timeperiod           15                   30                   50
# RSI_EMA_timeperiod       5      20     30     5      20     30     5      20
# EMA_is_below            RSI    RSI    RSI    RSI    RSI    RSI    RSI    RSI
# time
# 2020-10-01 00:00:00   False  False  False  False  False  False  False  False
# 2020-10-01 00:30:00   False  False  False  False  False  False  False  False
# 2020-10-01 01:00:00   False  False  False  False  False  False  False  False
# 2020-10-01 01:30:00   False  False  False  False  False  False  False  False
# 2020-10-01 02:00:00   False  False  False  False  False  False  False  False
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# 2021-02-22 21:30:00   False  False  False  False  False  False  False  False
# 2021-02-22 22:00:00   False  False  False  False  False  False  False  False
# 2021-02-22 22:30:00   False   True   True  False   True   True  False   True
# 2021-02-22 23:00:00   False   True   True  False   True   True  False   True
# 2021-02-22 23:30:00    True   True   True   True   True   True   True   True
#
# STOCH_fastk_period                  ...     15                              \
# STOCH_slowk_period                  ...      3
# STOCH_slowk_matype                  ...      0
# STOCH_slowd_period                  ...      3
# STOCH_slowd_matype                  ...      0
# STOCH_EMA_timeperiod           40   ...    60     100
# EMA_is_above                 STOCH  ...  STOCH  STOCH
# RSI_timeperiod                  15  ...     50     15                   30
# RSI_EMA_timeperiod       30     5   ...     30     5      20     30     5
# EMA_is_below            RSI    RSI  ...    RSI    RSI    RSI    RSI    RSI
# time                                ...
# 2020-10-01 00:00:00   False  False  ...  False  False  False  False  False
# 2020-10-01 00:30:00   False  False  ...  False  False  False  False  False
# 2020-10-01 01:00:00   False  False  ...  False  False  False  False  False
# 2020-10-01 01:30:00   False  False  ...  False  False  False  False  False
# 2020-10-01 02:00:00   False  False  ...  False  False  False  False  False
# ...                     ...    ...  ...    ...    ...    ...    ...    ...
# 2021-02-22 21:30:00   False  False  ...  False  False  False  False  False
# 2021-02-22 22:00:00   False  False  ...  False  False  False  False  False
# 2021-02-22 22:30:00    True  False  ...  False  False  False  False  False
# 2021-02-22 23:00:00    True  False  ...  False  False  False  False  False
# 2021-02-22 23:30:00    True   True  ...  False  False  False  False  False
#
# STOCH_fastk_period
# STOCH_slowk_period
# STOCH_slowk_matype
# STOCH_slowd_period
# STOCH_slowd_matype
# STOCH_EMA_timeperiod
# EMA_is_above
# RSI_timeperiod                         50
# RSI_EMA_timeperiod       20     30     5      20     30
# EMA_is_below            RSI    RSI    RSI    RSI    RSI
# time
# 2020-10-01 00:00:00   False  False  False  False  False
# 2020-10-01 00:30:00   False  False  False  False  False
# 2020-10-01 01:00:00   False  False  False  False  False
# 2020-10-01 01:30:00   False  False  False  False  False
# 2020-10-01 02:00:00   False  False  False  False  False
# ...                     ...    ...    ...    ...    ...
# 2021-02-22 21:30:00   False  False  False  False  False
# 2021-02-22 22:00:00   False  False  False  False  False
# 2021-02-22 22:30:00   False  False  False  False  False
# 2021-02-22 23:00:00   False  False  False  False  False
# 2021-02-22 23:30:00   False  False  False  False  False
#
# [6960 rows x 108 columns]

# %%
fig = go.Figure(
    data=[
        go.Scatter(
            x=prices.index,
            y=rsi_ind[15].values.flatten(),
            mode="lines",
            name="RSI",
        ),
        go.Scatter(
            x=prices.index,
            y=ema_ind_on_rsi[15][30].values,
            mode="lines",
            name="EMA on RSI",
        ),
        go.Scatter(
            x=prices.index,
            y=np.where(
                ema_below_rsi[(15, 30, "RSI")].values,
                ema_ind_on_rsi[(15, 30)].values,
                np.nan,
            ),
            mode="markers",
            name="Signals",
        ),
    ]
)
fig.show()
