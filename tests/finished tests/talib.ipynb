# %%
import quantfreedom as qf
import pandas as pd
from quantfreedom.indicators.talib_ind import *

# %load_ext autoreload
# %autoreload 2

prices = pd.read_hdf('../data/prices.hd5')

# %%
# talib_list_of_indicators()

# %%
# talib_func_list_website_link()

# %%
talib_ind_info('bbands')
# Out:
# {'name': 'BBANDS',
#  'group': 'Overlap Studies',
#  'display_name': 'Bollinger Bands',
#  'function_flags': ['Output scale same as input'],
#  'input_names': OrderedDict([('price', 'close')]),
#  'parameters': OrderedDict([('timeperiod', 5),
#               ('nbdevup', 2),
#               ('nbdevdn', 2),
#               ('matype', 0)]),
#  'output_flags': OrderedDict([('upperband',
#                ['Values represent an upper limit']),
#               ('middleband', ['Line']),
#               ('lowerband', ['Values represent a lower limit'])]),
#  'output_names': ['upperband', 'middleband', 'lowerband']}

# %%
talib_ind_info('stoch')
# Out:
# {'name': 'STOCH',
#  'group': 'Momentum Indicators',
#  'display_name': 'Stochastic',
#  'function_flags': None,
#  'input_names': OrderedDict([('prices', ['high', 'low', 'close'])]),
#  'parameters': OrderedDict([('fastk_period', 5),
#               ('slowk_period', 3),
#               ('slowk_matype', 0),
#               ('slowd_period', 3),
#               ('slowd_matype', 0)]),
#  'output_flags': OrderedDict([('slowk', ['Dashed Line']),
#               ('slowd', ['Dashed Line'])]),
#  'output_names': ['slowk', 'slowd']}

# %%
talib_ind_info('rsi')
# Out:
# {'name': 'RSI',
#  'group': 'Momentum Indicators',
#  'display_name': 'Relative Strength Index',
#  'function_flags': ['Function has an unstable period'],
#  'input_names': OrderedDict([('price', 'close')]),
#  'parameters': OrderedDict([('timeperiod', 14)]),
#  'output_flags': OrderedDict([('real', ['Line'])]),
#  'output_names': ['real']}

# %%
rsi = from_talib(
    func_name='rsi',
    price_data=prices,
    input_names = ['open'],
    parameters = {'timeperiod': [15, 20, 25, 30]}
)

# %%
from_talib(
    func_name='ema',
    indicator_data=rsi.data,
    parameters = {'timeperiod': [50, 70, 90]}
).data
# Out:
# symbol               BTCUSDT
# output                  real
# candle_body         ["open"]
# rsi_timeperiod            15                20                25
# ema_timeperiod            50    70    90    50    70    90    50    70    90
# open_time
# 2020-10-02 08:00:00    45.72   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  \
# 2020-10-02 08:30:00    45.39   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-02 09:00:00    44.96   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-02 09:30:00    44.47   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-02 10:00:00    44.14   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2021-04-14 21:30:00    51.48 53.47 54.46 52.86 54.53 55.31 53.86 55.26 55.88
# 2021-04-14 22:00:00    51.24 53.24 54.26 52.58 54.29 55.11 53.58 55.03 55.68
# 2021-04-14 22:30:00    50.95 52.97 54.03 52.27 54.02 54.88 53.28 54.77 55.47
# 2021-04-14 23:00:00    50.77 52.79 53.87 52.06 53.81 54.70 53.05 54.56 55.29
# 2021-04-14 23:30:00    50.70 52.68 53.75 51.91 53.66 54.56 52.89 54.40 55.15
#
# symbol                     ...   XRPUSD
# output                     ...     real
# candle_body                ... ["open"]
# rsi_timeperiod         30  ...       15    20                25
# ema_timeperiod         50  ...       90    50    70    90    50    70    90
# open_time                  ...
# 2020-10-02 08:00:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN  \
# 2020-10-02 08:30:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-02 09:00:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-02 09:30:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-02 10:00:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                   ...  ...      ...   ...   ...   ...   ...   ...   ...
# 2021-04-14 21:30:00 54.57  ...    55.11 52.98 54.80 55.84 53.87 55.49 56.38
# 2021-04-14 22:00:00 54.31  ...    55.13 53.04 54.79 55.81 53.88 55.45 56.33
# 2021-04-14 22:30:00 54.02  ...    55.07 52.98 54.70 55.72 53.79 55.34 56.23
# 2021-04-14 23:00:00 53.79  ...    55.04 52.97 54.65 55.65 53.74 55.26 56.15
# 2021-04-14 23:30:00 53.62  ...    55.08 53.06 54.66 55.64 53.77 55.24 56.11
#
# symbol
# output
# candle_body
# rsi_timeperiod         30
# ema_timeperiod         50    70    90
# open_time
# 2020-10-02 08:00:00   NaN   NaN   NaN
# 2020-10-02 08:30:00   NaN   NaN   NaN
# 2020-10-02 09:00:00   NaN   NaN   NaN
# 2020-10-02 09:30:00   NaN   NaN   NaN
# 2020-10-02 10:00:00   NaN   NaN   NaN
# ...                   ...   ...   ...
# 2021-04-14 21:30:00 54.56 56.00 56.78
# 2021-04-14 22:00:00 54.53 55.94 56.71
# 2021-04-14 22:30:00 54.43 55.83 56.61
# 2021-04-14 23:00:00 54.36 55.74 56.52
# 2021-04-14 23:30:00 54.36 55.70 56.47
#
# [9344 rows x 60 columns]

# %%
from_talib(
    func_name='stoch',
    price_data=prices,
    column_wise_combos = False,
    input_names = [['open', 'close', 'high'], ['open', 'high', 'low']],
    parameters=dict(
        fastk_period=[1, 10, 8, 5],
        slowk_period=[15, 9, 10, 5],
        slowk_matype=[6, 3, 7, 5]
    )
).data
# Out:
# symbol                                BTCUSDT
# output                                  slowd
# candle_body         ["open", "close", "high"]
# stoch_fastk_period                         1
# stoch_slowk_period                         5                        9
# stoch_slowk_matype                          3     5      6     7     3     5
# stoch_slowd_period                          3     3      3     3     3     3
# stoch_slowd_matype                          0     0      0     0     0     0
# open_time
# 2020-10-01 03:00:00                       NaN 53.95    NaN   NaN   NaN   NaN  \
# 2020-10-01 03:30:00                       NaN 72.79 239.12   NaN   NaN   NaN
# 2020-10-01 04:00:00                       NaN 86.07 237.03   NaN   NaN   NaN
# 2020-10-01 04:30:00                       NaN 83.74 233.17   NaN   NaN   NaN
# 2020-10-01 05:00:00                     73.95 78.94 228.08   NaN   NaN 73.18
# ...                                       ...   ...    ...   ...   ...   ...
# 2021-04-14 21:30:00                    -19.13 10.93 -83.08 41.88 13.35 61.49
# 2021-04-14 22:00:00                      6.31 -8.00 -70.69 38.73 21.73 45.06
# 2021-04-14 22:30:00                      5.24 -9.00 -59.88 45.97 17.52 26.13
# 2021-04-14 23:00:00                      8.55  5.90 -52.95 61.81 16.71 13.20
# 2021-04-14 23:30:00                      5.77 10.74 -51.36 58.98 12.95  5.24
#
# symbol                                         ...                  XRPUSD
# output                                         ...                   slowk
# candle_body                                    ... ["open", "high", "low"]
# stoch_fastk_period                             ...                      10
# stoch_slowk_period                   10        ...                      9
# stoch_slowk_matype        6     7     3     5  ...                       6
# stoch_slowd_period        3     3     3     3  ...                       3
# stoch_slowd_matype        0     0     0     0  ...                       0
# open_time                                      ...
# 2020-10-01 03:00:00     NaN   NaN   NaN   NaN  ...                     NaN  \
# 2020-10-01 03:30:00     NaN   NaN   NaN   NaN  ...                     NaN
# 2020-10-01 04:00:00     NaN   NaN   NaN   NaN  ...                     NaN
# 2020-10-01 04:30:00     NaN   NaN   NaN   NaN  ...                     NaN
# 2020-10-01 05:00:00     NaN   NaN   NaN   NaN  ...                     NaN
# ...                     ...   ...   ...   ...  ...                     ...
# 2021-04-14 21:30:00 -315.64 41.88 17.61 62.58  ...                  -30.16
# 2021-04-14 22:00:00 -309.91 38.73 24.62 52.20  ...                  -28.55
# 2021-04-14 22:30:00 -304.60 45.97 20.37 36.41  ...                  -22.98
# 2021-04-14 23:00:00 -301.32 61.81 19.21 21.91  ...                  -19.92
# 2021-04-14 23:30:00 -296.05 58.98 15.38 12.08  ...                  -14.90
#
# symbol
# output
# candle_body
# stoch_fastk_period
# stoch_slowk_period           10                        15
# stoch_slowk_matype      7     3      5      6     7     3     5     6     7
# stoch_slowd_period      3     3      3      3     3     3     3     3     3
# stoch_slowd_matype      0     0      0      0     0     0     0     0     0
# open_time
# 2020-10-01 03:00:00   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 03:30:00   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 04:00:00   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 04:30:00   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 05:00:00   NaN   NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN
# ...                   ...   ...    ...    ...   ...   ...   ...   ...   ...
# 2021-04-14 21:30:00 -0.17 36.35 -13.13 -17.66 -0.17 19.61 -7.28 -1.17 -0.17
# 2021-04-14 22:00:00 25.02 44.58  -7.18 -16.83 25.02 28.67 -4.61  0.28 25.02
# 2021-04-14 22:30:00 26.93 54.60   5.55 -14.83 26.93 39.00 -1.83  2.14 26.93
# 2021-04-14 23:00:00 49.20 64.30  21.94  -9.20 49.20 49.21  1.41  3.91 49.20
# 2021-04-14 23:30:00 51.23 77.14  37.44  -4.97 51.23 61.70  8.51  6.46 51.23
#
# [9402 rows x 1280 columns]

# %%
from_talib(
    func_name='stoch',
    price_data=prices,
    all_possible_combos=False,
    column_wise_combos=True,
    fastk_period=[1,10],
    slowk_period=[15,9],
    slowk_matype=[6,3],
)

# %%
talib_ind_info('atr')
