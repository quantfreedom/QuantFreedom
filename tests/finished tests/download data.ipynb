# %%
import quantfreedom as qf
import ccxt

# %%
exh = ccxt.bybit()

# %%
exh.load_markets()
# Out:
# {'BTC/USDT': {'id': 'BTCUSDT',
#   'symbol': 'BTC/USDT',
#   'base': 'BTC',
#   'quote': 'USDT',
#   'baseId': 'BTC',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 1e-06, 'price': 0.01},
#   'limits': {'amount': {'min': 4.8e-05, 'max': 46.13},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'BTCUSDT',
#    'baseCoin': 'BTC',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.000001',
#     'quotePrecision': '0.00000001',
#     'minOrderQty': '0.000048',
#     'maxOrderQty': '46.13',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1200000'},
#    'priceFilter': {'tickSize': '0.01'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'ETH/USDT': {'id': 'ETHUSDT',
#   'symbol': 'ETH/USDT',
#   'base': 'ETH',
#   'quote': 'USDT',
#   'baseId': 'ETH',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 1e-05, 'price': 0.01},
#   'limits': {'amount': {'min': 0.00062, 'max': 817.8286649},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'ETHUSDT',
#    'baseCoin': 'ETH',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.00001',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '0.00062',
#     'maxOrderQty': '817.8286649',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1200000'},
#    'priceFilter': {'tickSize': '0.01'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'XRP/USDT': {'id': 'XRPUSDT',
#   'symbol': 'XRP/USDT',
#   'base': 'XRP',
#   'quote': 'USDT',
#   'baseId': 'XRP',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 2.63, 'max': 2720348.20457},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1000000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'XRPUSDT',
#    'baseCoin': 'XRP',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '2.63',
#     'maxOrderQty': '2720348.20457',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1000000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'EOS/USDT': {'id': 'EOSUSDT',
#   'symbol': 'EOS/USDT',
#   'base': 'EOS',
#   'quote': 'USDT',
#   'baseId': 'EOS',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.78, 'max': 203366.56},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 235494.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'EOSUSDT',
#    'baseCoin': 'EOS',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.78',
#     'maxOrderQty': '203366.56',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '235494'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'ETH/BTC': {'id': 'ETHBTC',
#   'symbol': 'ETH/BTC',
#   'base': 'ETH',
#   'quote': 'BTC',
#   'baseId': 'ETH',
#   'quoteId': 'BTC',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 1e-06},
#   'limits': {'amount': {'min': 0.003, 'max': 178.87914405},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 0.0002, 'max': 13.91},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'ETHBTC',
#    'baseCoin': 'ETH',
#    'quoteCoin': 'BTC',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.00000001',
#     'minOrderQty': '0.003',
#     'maxOrderQty': '178.87914405',
#     'minOrderAmt': '0.0002',
#     'maxOrderAmt': '13.91'},
#    'priceFilter': {'tickSize': '0.000001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'XRP/BTC': {'id': 'XRPBTC',
#   'symbol': 'XRP/BTC',
#   'base': 'XRP',
#   'quote': 'BTC',
#   'baseId': 'XRP',
#   'quoteId': 'BTC',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.1, 'price': 1e-08},
#   'limits': {'amount': {'min': 5.0, 'max': 407862.40786241},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 0.0001, 'max': 6.64},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'XRPBTC',
#    'baseCoin': 'XRP',
#    'quoteCoin': 'BTC',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.1',
#     'quotePrecision': '0.00000001',
#     'minOrderQty': '5',
#     'maxOrderQty': '407862.40786241',
#     'minOrderAmt': '0.0001',
#     'maxOrderAmt': '6.64'},
#    'priceFilter': {'tickSize': '0.00000001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'DOT/USDT': {'id': 'DOTUSDT',
#   'symbol': 'DOT/USDT',
#   'base': 'DOT',
#   'quote': 'USDT',
#   'baseId': 'DOT',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.001},
#   'limits': {'amount': {'min': 0.107, 'max': 165316.581253},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1000000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'DOTUSDT',
#    'baseCoin': 'DOT',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.107',
#     'maxOrderQty': '165316.581253',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1000000'},
#    'priceFilter': {'tickSize': '0.001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'XLM/USDT': {'id': 'XLMUSDT',
#   'symbol': 'XLM/USDT',
#   'base': 'XLM',
#   'quote': 'USDT',
#   'baseId': 'XLM',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.1, 'price': 1e-05},
#   'limits': {'amount': {'min': 7.9, 'max': 2377273.267562},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'XLMUSDT',
#    'baseCoin': 'XLM',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.1',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '7.9',
#     'maxOrderQty': '2377273.267562',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.00001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'LTC/USDT': {'id': 'LTCUSDT',
#   'symbol': 'LTC/USDT',
#   'base': 'LTC',
#   'quote': 'USDT',
#   'baseId': 'LTC',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 1e-05, 'price': 0.01},
#   'limits': {'amount': {'min': 0.01617, 'max': 11247.3287594},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1000000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'LTCUSDT',
#    'baseCoin': 'LTC',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.00001',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '0.01617',
#     'maxOrderQty': '11247.3287594',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1000000'},
#    'priceFilter': {'tickSize': '0.01'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'DOGE/USDT': {'id': 'DOGEUSDT',
#   'symbol': 'DOGE/USDT',
#   'base': 'DOGE',
#   'quote': 'USDT',
#   'baseId': 'DOGE',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.1, 'price': 1e-05},
#   'limits': {'amount': {'min': 6.9, 'max': 13264358.668258},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1000000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'DOGEUSDT',
#    'baseCoin': 'DOGE',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.1',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '6.9',
#     'maxOrderQty': '13264358.668258',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1000000'},
#    'priceFilter': {'tickSize': '0.00001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'BIT/USDT': {'id': 'BITUSDT',
#   'symbol': 'BIT/USDT',
#   'base': 'BIT',
#   'quote': 'USDT',
#   'baseId': 'BIT',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 1.37, 'max': 1410598.96},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 280000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'BITUSDT',
#    'baseCoin': 'BIT',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '1.37',
#     'maxOrderQty': '1410598.96',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '280000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'CHZ/USDT': {'id': 'CHZUSDT',
#   'symbol': 'CHZ/USDT',
#   'base': 'CHZ',
#   'quote': 'USDT',
#   'baseId': 'CHZ',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 21.28, 'max': 1609010.458568},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'CHZUSDT',
#    'baseCoin': 'CHZ',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '21.28',
#     'maxOrderQty': '1609010.458568',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'AXS/USDT': {'id': 'AXSUSDT',
#   'symbol': 'AXS/USDT',
#   'base': 'AXS',
#   'quote': 'USDT',
#   'baseId': 'AXS',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.16, 'max': 12084.5921},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 80000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'AXSUSDT',
#    'baseCoin': 'AXS',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.16',
#     'maxOrderQty': '12084.5921',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '80000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'MANA/USDT': {'id': 'MANAUSDT',
#   'symbol': 'MANA/USDT',
#   'base': 'MANA',
#   'quote': 'USDT',
#   'baseId': 'MANA',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.93, 'max': 477099.236641},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 150000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'MANAUSDT',
#    'baseCoin': 'MANA',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.93',
#     'maxOrderQty': '477099.236641',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '150000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'DYDX/USDT': {'id': 'DYDXUSDT',
#   'symbol': 'DYDX/USDT',
#   'base': 'DYDX',
#   'quote': 'USDT',
#   'baseId': 'DYDX',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.001},
#   'limits': {'amount': {'min': 0.625, 'max': 112233.445567},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'DYDXUSDT',
#    'baseCoin': 'DYDX',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.625',
#     'maxOrderQty': '112233.445567',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'MKR/USDT': {'id': 'MKRUSDT',
#   'symbol': 'MKR/USDT',
#   'base': 'MKR',
#   'quote': 'USDT',
#   'baseId': 'MKR',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.0001, 'price': 0.1},
#   'limits': {'amount': {'min': 0.0038, 'max': 74.52},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 40000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'MKRUSDT',
#    'baseCoin': 'MKR',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.0001',
#     'quotePrecision': '0.00001',
#     'minOrderQty': '0.0038',
#     'maxOrderQty': '74.52',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '40000'},
#    'priceFilter': {'tickSize': '0.1'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'COMP/USDT': {'id': 'COMPUSDT',
#   'symbol': 'COMP/USDT',
#   'base': 'COMP',
#   'quote': 'USDT',
#   'baseId': 'COMP',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.01},
#   'limits': {'amount': {'min': 0.027, 'max': 1087.23},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 35041.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'COMPUSDT',
#    'baseCoin': 'COMP',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.00001',
#     'minOrderQty': '0.027',
#     'maxOrderQty': '1087.23',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '35041'},
#    'priceFilter': {'tickSize': '0.01'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'AAVE/USDT': {'id': 'AAVEUSDT',
#   'symbol': 'AAVE/USDT',
#   'base': 'AAVE',
#   'quote': 'USDT',
#   'baseId': 'AAVE',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.009, 'max': 1502.18},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 102123.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'AAVEUSDT',
#    'baseCoin': 'AAVE',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '0.009',
#     'maxOrderQty': '1502.18',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '102123'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'YFI/USDT': {'id': 'YFIUSDT',
#   'symbol': 'YFI/USDT',
#   'base': 'YFI',
#   'quote': 'USDT',
#   'baseId': 'YFI',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 1e-05, 'price': 0.01},
#   'limits': {'amount': {'min': 0.00025, 'max': 10.58},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 50000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'YFIUSDT',
#    'baseCoin': 'YFI',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.00001',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '0.00025',
#     'maxOrderQty': '10.58',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '50000'},
#    'priceFilter': {'tickSize': '0.01'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'LINK/USDT': {'id': 'LINKUSDT',
#   'symbol': 'LINK/USDT',
#   'base': 'LINK',
#   'quote': 'USDT',
#   'baseId': 'LINK',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.111, 'max': 29256.8753657},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'LINKUSDT',
#    'baseCoin': 'LINK',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '0.111',
#     'maxOrderQty': '29256.8753657',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'SUSHI/USDT': {'id': 'SUSHIUSDT',
#   'symbol': 'SUSHI/USDT',
#   'base': 'SUSHI',
#   'quote': 'USDT',
#   'baseId': 'SUSHI',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.001},
#   'limits': {'amount': {'min': 0.633, 'max': 62641.9},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 50000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'SUSHIUSDT',
#    'baseCoin': 'SUSHI',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.633',
#     'maxOrderQty': '62641.9',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '50000'},
#    'priceFilter': {'tickSize': '0.001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'UNI/USDT': {'id': 'UNIUSDT',
#   'symbol': 'UNI/USDT',
#   'base': 'UNI',
#   'quote': 'USDT',
#   'baseId': 'UNI',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.109, 'max': 34240.1260037},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'UNIUSDT',
#    'baseCoin': 'UNI',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '0.109',
#     'maxOrderQty': '34240.1260037',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'KSM/USDT': {'id': 'KSMUSDT',
#   'symbol': 'KSM/USDT',
#   'base': 'KSM',
#   'quote': 'USDT',
#   'baseId': 'KSM',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.042, 'max': 1041.6667},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 30000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'KSMUSDT',
#    'baseCoin': 'KSM',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '0.042',
#     'maxOrderQty': '1041.6667',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '30000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'ICP/USDT': {'id': 'ICPUSDT',
#   'symbol': 'ICP/USDT',
#   'base': 'ICP',
#   'quote': 'USDT',
#   'baseId': 'ICP',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 0.12, 'max': 36595.85369},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'ICPUSDT',
#    'baseCoin': 'ICP',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.12',
#     'maxOrderQty': '36595.85369',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'ADA/USDT': {'id': 'ADAUSDT',
#   'symbol': 'ADA/USDT',
#   'base': 'ADA',
#   'quote': 'USDT',
#   'baseId': 'ADA',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 1.86, 'max': 2969121.140143},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1000000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'ADAUSDT',
#    'baseCoin': 'ADA',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '1.86',
#     'maxOrderQty': '2969121.140143',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1000000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'ETC/USDT': {'id': 'ETCUSDT',
#   'symbol': 'ETC/USDT',
#   'base': 'ETC',
#   'quote': 'USDT',
#   'baseId': 'ETC',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.01},
#   'limits': {'amount': {'min': 0.03, 'max': 4417.2483},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 65817.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'ETCUSDT',
#    'baseCoin': 'ETC',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.0001',
#     'minOrderQty': '0.03',
#     'maxOrderQty': '4417.2483',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '65817'},
#    'priceFilter': {'tickSize': '0.01'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'KLAY/USDT': {'id': 'KLAYUSDT',
#   'symbol': 'KLAY/USDT',
#   'base': 'KLAY',
#   'quote': 'USDT',
#   'baseId': 'KLAY',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 1e-05},
#   'limits': {'amount': {'min': 5.88, 'max': 308641.97531},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 50000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'KLAYUSDT',
#    'baseCoin': 'KLAY',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '5.88',
#     'maxOrderQty': '308641.97531',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '50000'},
#    'priceFilter': {'tickSize': '0.00001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'XTZ/USDT': {'id': 'XTZUSDT',
#   'symbol': 'XTZ/USDT',
#   'base': 'XTZ',
#   'quote': 'USDT',
#   'baseId': 'XTZ',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 1.59, 'max': 63981.56028},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 45107.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'XTZUSDT',
#    'baseCoin': 'XTZ',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '1.59',
#     'maxOrderQty': '63981.56028',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '45107'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'BCH/USDT': {'id': 'BCHUSDT',
#   'symbol': 'BCH/USDT',
#   'base': 'BCH',
#   'quote': 'USDT',
#   'baseId': 'BCH',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.1},
#   'limits': {'amount': {'min': 0.017, 'max': 1605.1364},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'BCHUSDT',
#    'baseCoin': 'BCH',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.0001',
#     'minOrderQty': '0.017',
#     'maxOrderQty': '1605.1364',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.1'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'SRM/USDT': {'id': 'SRMUSDT',
#   'symbol': 'SRM/USDT',
#   'base': 'SRM',
#   'quote': 'USDT',
#   'baseId': 'SRM',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 3.75, 'max': 177514.7929},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 30000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'SRMUSDT',
#    'baseCoin': 'SRM',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '3.75',
#     'maxOrderQty': '177514.7929',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '30000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'QNT/USDT': {'id': 'QNTUSDT',
#   'symbol': 'QNT/USDT',
#   'base': 'QNT',
#   'quote': 'USDT',
#   'baseId': 'QNT',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.1},
#   'limits': {'amount': {'min': 0.009, 'max': 1652.8926},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'QNTUSDT',
#    'baseCoin': 'QNT',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.0001',
#     'minOrderQty': '0.009',
#     'maxOrderQty': '1652.8926',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.1'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'USDC/USDT': {'id': 'USDCUSDT',
#   'symbol': 'USDC/USDT',
#   'base': 'USDC',
#   'quote': 'USDT',
#   'baseId': 'USDC',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 1.0, 'max': 2496045.89},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1000000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'USDCUSDT',
#    'baseCoin': 'USDC',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '1',
#     'maxOrderQty': '2496045.89',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1000000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'GRT/USDT': {'id': 'GRTUSDT',
#   'symbol': 'GRT/USDT',
#   'base': 'GRT',
#   'quote': 'USDT',
#   'baseId': 'GRT',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 1e-05},
#   'limits': {'amount': {'min': 15.87, 'max': 1397526.3783104},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'GRTUSDT',
#    'baseCoin': 'GRT',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.0000001',
#     'minOrderQty': '15.87',
#     'maxOrderQty': '1397526.3783104',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.00001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'SOL/USDT': {'id': 'SOLUSDT',
#   'symbol': 'SOL/USDT',
#   'base': 'SOL',
#   'quote': 'USDT',
#   'baseId': 'SOL',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.01},
#   'limits': {'amount': {'min': 0.023, 'max': 47619.04762},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 1000000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'SOLUSDT',
#    'baseCoin': 'SOL',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.00001',
#     'minOrderQty': '0.023',
#     'maxOrderQty': '47619.04762',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '1000000'},
#    'priceFilter': {'tickSize': '0.01'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'FIL/USDT': {'id': 'FILUSDT',
#   'symbol': 'FIL/USDT',
#   'base': 'FIL',
#   'quote': 'USDT',
#   'baseId': 'FIL',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.001},
#   'limits': {'amount': {'min': 0.14, 'max': 32102.72873},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 200000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'FILUSDT',
#    'baseCoin': 'FIL',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.00001',
#     'minOrderQty': '0.14',
#     'maxOrderQty': '32102.72873',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '200000'},
#    'priceFilter': {'tickSize': '0.001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'OMG/USDT': {'id': 'OMGUSDT',
#   'symbol': 'OMG/USDT',
#   'base': 'OMG',
#   'quote': 'USDT',
#   'baseId': 'OMG',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.001, 'price': 0.001},
#   'limits': {'amount': {'min': 0.877, 'max': 31693.0},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 42070.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'OMGUSDT',
#    'baseCoin': 'OMG',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.001',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '0.877',
#     'maxOrderQty': '31693',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '42070'},
#    'priceFilter': {'tickSize': '0.001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'TRIBE/USDT': {'id': 'TRIBEUSDT',
#   'symbol': 'TRIBE/USDT',
#   'base': 'TRIBE',
#   'quote': 'USDT',
#   'baseId': 'TRIBE',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 10.99, 'max': 193423.597679},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 30000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'TRIBEUSDT',
#    'baseCoin': 'TRIBE',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '10.99',
#     'maxOrderQty': '193423.597679',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '30000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'BAT/USDT': {'id': 'BATUSDT',
#   'symbol': 'BAT/USDT',
#   'base': 'BAT',
#   'quote': 'USDT',
#   'baseId': 'BAT',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 9.62, 'max': 156168.662155},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 30000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'BATUSDT',
#    'baseCoin': 'BAT',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '9.62',
#     'maxOrderQty': '156168.662155',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '30000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'ZRX/USDT': {'id': 'ZRXUSDT',
#   'symbol': 'ZRX/USDT',
#   'base': 'ZRX',
#   'quote': 'USDT',
#   'baseId': 'ZRX',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 7.81, 'max': 169683.257919},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 10.0, 'max': 30000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'ZRXUSDT',
#    'baseCoin': 'ZRX',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '7.81',
#     'maxOrderQty': '169683.257919',
#     'minOrderAmt': '10',
#     'maxOrderAmt': '30000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'CRV/USDT': {'id': 'CRVUSDT',
#   'symbol': 'CRV/USDT',
#   'base': 'CRV',
#   'quote': 'USDT',
#   'baseId': 'CRV',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 1.61, 'max': 70921.98582},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 40000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'CRVUSDT',
#    'baseCoin': 'CRV',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '1.61',
#     'maxOrderQty': '70921.98582',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '40000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'AGLD/USDT': {'id': 'AGLDUSDT',
#   'symbol': 'AGLD/USDT',
#   'base': 'AGLD',
#   'quote': 'USDT',
#   'baseId': 'AGLD',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.01, 'price': 0.0001},
#   'limits': {'amount': {'min': 4.1, 'max': 111940.29851},
#    'price': {'min': None, 'max': None},
#    'cost': {'min': 1.0, 'max': 30000.0},
#    'leverage': {'min': 1.0, 'max': None}},
#   'info': {'symbol': 'AGLDUSDT',
#    'baseCoin': 'AGLD',
#    'quoteCoin': 'USDT',
#    'innovation': '0',
#    'status': 'Trading',
#    'lotSizeFilter': {'basePrecision': '0.01',
#     'quotePrecision': '0.000001',
#     'minOrderQty': '4.1',
#     'maxOrderQty': '111940.29851',
#     'minOrderAmt': '1',
#     'maxOrderAmt': '30000'},
#    'priceFilter': {'tickSize': '0.0001'}},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.001,
#   'maker': 0.001},
#  'ANKR/USDT': {'id': 'ANKRUSDT',
#   'symbol': 'ANKR/USDT',
#   'base': 'ANKR',
#   'quote': 'USDT',
#   'baseId': 'ANKR',
#   'quoteId': 'USDT',
#   'active': True,
#   'type': 'spot',
#   'linear': None,
#   'inverse': None,
#   'spot': True,
#   'swap': False,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': False,
#   'contractSize': None,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': None,
#   'settleId': None,
#   'precision': {'amount': 0.1, 'price': 1e-05},
# ...
#   'inverse': True,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'BTC',
#   'settleId': 'BTC',
#   'precision': {'amount': 1.0, 'price': 0.5},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.5, 'max': 999999.0},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 100.0}},
#   'info': {'symbol': 'BTCUSD',
#    'contractType': 'InversePerpetual',
#    'status': 'Trading',
#    'baseCoin': 'BTC',
#    'quoteCoin': 'USD',
#    'launchTime': '0',
#    'deliveryTime': '0',
#    'deliveryFeeRate': '',
#    'priceScale': '2',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '100.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.50',
#     'maxPrice': '999999.00',
#     'tickSize': '0.50'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'BTC'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'BTC/USD:BTC-230630': {'id': 'BTCUSDM23',
#   'symbol': 'BTC/USD:BTC-230630',
#   'base': 'BTC',
#   'quote': 'USD',
#   'baseId': 'BTC',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'future',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': False,
#   'future': True,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': 1688112000000,
#   'expiryDatetime': '2023-06-30T08:00:00.000Z',
#   'optionType': None,
#   'strike': None,
#   'settle': 'BTC',
#   'settleId': 'BTC',
#   'precision': {'amount': 1.0, 'price': 0.5},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.5, 'max': 999999.0},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 100.0}},
#   'info': {'symbol': 'BTCUSDM23',
#    'contractType': 'InverseFutures',
#    'status': 'Trading',
#    'baseCoin': 'BTC',
#    'quoteCoin': 'USD',
#    'launchTime': '1671667200000',
#    'deliveryTime': '1688112000000',
#    'deliveryFeeRate': '0.0005',
#    'priceScale': '2',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '100.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.50',
#     'maxPrice': '999999.00',
#     'tickSize': '0.50'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'BTC'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'BTC/USD:BTC-230929': {'id': 'BTCUSDU23',
#   'symbol': 'BTC/USD:BTC-230929',
#   'base': 'BTC',
#   'quote': 'USD',
#   'baseId': 'BTC',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'future',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': False,
#   'future': True,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': 1695974400000,
#   'expiryDatetime': '2023-09-29T08:00:00.000Z',
#   'optionType': None,
#   'strike': None,
#   'settle': 'BTC',
#   'settleId': 'BTC',
#   'precision': {'amount': 1.0, 'price': 0.5},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.5, 'max': 999999.0},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 100.0}},
#   'info': {'symbol': 'BTCUSDU23',
#    'contractType': 'InverseFutures',
#    'status': 'Trading',
#    'baseCoin': 'BTC',
#    'quoteCoin': 'USD',
#    'launchTime': '1679040000000',
#    'deliveryTime': '1695974400000',
#    'deliveryFeeRate': '0.0005',
#    'priceScale': '2',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '100.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.50',
#     'maxPrice': '999999.00',
#     'tickSize': '0.50'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'BTC'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'DOT/USD:DOT': {'id': 'DOTUSD',
#   'symbol': 'DOT/USD:DOT',
#   'base': 'DOT',
#   'quote': 'USD',
#   'baseId': 'DOT',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'swap',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'DOT',
#   'settleId': 'DOT',
#   'precision': {'amount': 1.0, 'price': 0.005},
#   'limits': {'amount': {'min': 1.0, 'max': 500000.0},
#    'price': {'min': 0.005, 'max': 9999.99},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 50.0}},
#   'info': {'symbol': 'DOTUSD',
#    'contractType': 'InversePerpetual',
#    'status': 'Trading',
#    'baseCoin': 'DOT',
#    'quoteCoin': 'USD',
#    'launchTime': '1634083200000',
#    'deliveryTime': '0',
#    'deliveryFeeRate': '',
#    'priceScale': '3',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '50.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.005',
#     'maxPrice': '9999.990',
#     'tickSize': '0.005'},
#    'lotSizeFilter': {'maxOrderQty': '500000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '2500000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'DOT'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'EOS/USD:EOS': {'id': 'EOSUSD',
#   'symbol': 'EOS/USD:EOS',
#   'base': 'EOS',
#   'quote': 'USD',
#   'baseId': 'EOS',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'swap',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'EOS',
#   'settleId': 'EOS',
#   'precision': {'amount': 1.0, 'price': 0.001},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.001, 'max': 1999.998},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 50.0}},
#   'info': {'symbol': 'EOSUSD',
#    'contractType': 'InversePerpetual',
#    'status': 'Trading',
#    'baseCoin': 'EOS',
#    'quoteCoin': 'USD',
#    'launchTime': '0',
#    'deliveryTime': '0',
#    'deliveryFeeRate': '',
#    'priceScale': '3',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '50.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.001',
#     'maxPrice': '1999.998',
#     'tickSize': '0.001'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'EOS'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'ETH/USD:ETH': {'id': 'ETHUSD',
#   'symbol': 'ETH/USD:ETH',
#   'base': 'ETH',
#   'quote': 'USD',
#   'baseId': 'ETH',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'swap',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'ETH',
#   'settleId': 'ETH',
#   'precision': {'amount': 1.0, 'price': 0.05},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.05, 'max': 99999.9},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 100.0}},
#   'info': {'symbol': 'ETHUSD',
#    'contractType': 'InversePerpetual',
#    'status': 'Trading',
#    'baseCoin': 'ETH',
#    'quoteCoin': 'USD',
#    'launchTime': '1546300800000',
#    'deliveryTime': '0',
#    'deliveryFeeRate': '',
#    'priceScale': '2',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '100.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.05',
#     'maxPrice': '99999.90',
#     'tickSize': '0.05'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'ETH'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'ETH/USD:ETH-230630': {'id': 'ETHUSDM23',
#   'symbol': 'ETH/USD:ETH-230630',
#   'base': 'ETH',
#   'quote': 'USD',
#   'baseId': 'ETH',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'future',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': False,
#   'future': True,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': 1688112000000,
#   'expiryDatetime': '2023-06-30T08:00:00.000Z',
#   'optionType': None,
#   'strike': None,
#   'settle': 'ETH',
#   'settleId': 'ETH',
#   'precision': {'amount': 1.0, 'price': 0.05},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.05, 'max': 99999.9},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 50.0}},
#   'info': {'symbol': 'ETHUSDM23',
#    'contractType': 'InverseFutures',
#    'status': 'Trading',
#    'baseCoin': 'ETH',
#    'quoteCoin': 'USD',
#    'launchTime': '1671667200000',
#    'deliveryTime': '1688112000000',
#    'deliveryFeeRate': '0.0005',
#    'priceScale': '2',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '50.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.05',
#     'maxPrice': '99999.90',
#     'tickSize': '0.05'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'ETH'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'ETH/USD:ETH-230929': {'id': 'ETHUSDU23',
#   'symbol': 'ETH/USD:ETH-230929',
#   'base': 'ETH',
#   'quote': 'USD',
#   'baseId': 'ETH',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'future',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': False,
#   'future': True,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': 1695974400000,
#   'expiryDatetime': '2023-09-29T08:00:00.000Z',
#   'optionType': None,
#   'strike': None,
#   'settle': 'ETH',
#   'settleId': 'ETH',
#   'precision': {'amount': 1.0, 'price': 0.05},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.05, 'max': 99999.9},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 50.0}},
#   'info': {'symbol': 'ETHUSDU23',
#    'contractType': 'InverseFutures',
#    'status': 'Trading',
#    'baseCoin': 'ETH',
#    'quoteCoin': 'USD',
#    'launchTime': '1679040000000',
#    'deliveryTime': '1695974400000',
#    'deliveryFeeRate': '0.0005',
#    'priceScale': '2',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '50.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.05',
#     'maxPrice': '99999.90',
#     'tickSize': '0.05'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'ETH'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'LTC/USD:LTC': {'id': 'LTCUSD',
#   'symbol': 'LTC/USD:LTC',
#   'base': 'LTC',
#   'quote': 'USD',
#   'baseId': 'LTC',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'swap',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'LTC',
#   'settleId': 'LTC',
#   'precision': {'amount': 1.0, 'price': 0.01},
#   'limits': {'amount': {'min': 1.0, 'max': 150000.0},
#    'price': {'min': 0.01, 'max': 19999.98},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 50.0}},
#   'info': {'symbol': 'LTCUSD',
#    'contractType': 'InversePerpetual',
#    'status': 'Trading',
#    'baseCoin': 'LTC',
#    'quoteCoin': 'USD',
#    'launchTime': '1648684800000',
#    'deliveryTime': '0',
#    'deliveryFeeRate': '',
#    'priceScale': '2',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '50.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.01',
#     'maxPrice': '19999.98',
#     'tickSize': '0.01'},
#    'lotSizeFilter': {'maxOrderQty': '150000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '750000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'LTC'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'MANA/USD:MANA': {'id': 'MANAUSD',
#   'symbol': 'MANA/USD:MANA',
#   'base': 'MANA',
#   'quote': 'USD',
#   'baseId': 'MANA',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'swap',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'MANA',
#   'settleId': 'MANA',
#   'precision': {'amount': 1.0, 'price': 0.0005},
#   'limits': {'amount': {'min': 1.0, 'max': 100000.0},
#    'price': {'min': 0.0005, 'max': 999.999},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 50.0}},
#   'info': {'symbol': 'MANAUSD',
#    'contractType': 'InversePerpetual',
#    'status': 'Trading',
#    'baseCoin': 'MANA',
#    'quoteCoin': 'USD',
#    'launchTime': '1648684800000',
#    'deliveryTime': '0',
#    'deliveryFeeRate': '',
#    'priceScale': '4',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '50.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.0005',
#     'maxPrice': '999.9990',
#     'tickSize': '0.0005'},
#    'lotSizeFilter': {'maxOrderQty': '100000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '500000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'MANA'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001},
#  'XRP/USD:XRP': {'id': 'XRPUSD',
#   'symbol': 'XRP/USD:XRP',
#   'base': 'XRP',
#   'quote': 'USD',
#   'baseId': 'XRP',
#   'quoteId': 'USD',
#   'active': True,
#   'type': 'swap',
#   'linear': False,
#   'inverse': True,
#   'spot': False,
#   'swap': True,
#   'future': False,
#   'option': False,
#   'margin': None,
#   'contract': True,
#   'contractSize': 1.0,
#   'expiry': None,
#   'expiryDatetime': None,
#   'optionType': None,
#   'strike': None,
#   'settle': 'XRP',
#   'settleId': 'XRP',
#   'precision': {'amount': 1.0, 'price': 0.0001},
#   'limits': {'amount': {'min': 1.0, 'max': 1000000.0},
#    'price': {'min': 0.0001, 'max': 199.9998},
#    'cost': {'min': None, 'max': None},
#    'leverage': {'min': 1.0, 'max': 50.0}},
#   'info': {'symbol': 'XRPUSD',
#    'contractType': 'InversePerpetual',
#    'status': 'Trading',
#    'baseCoin': 'XRP',
#    'quoteCoin': 'USD',
#    'launchTime': '0',
#    'deliveryTime': '0',
#    'deliveryFeeRate': '',
#    'priceScale': '4',
#    'leverageFilter': {'minLeverage': '1',
#     'maxLeverage': '50.00',
#     'leverageStep': '0.01'},
#    'priceFilter': {'minPrice': '0.0001',
#     'maxPrice': '199.9998',
#     'tickSize': '0.0001'},
#    'lotSizeFilter': {'maxOrderQty': '1000000',
#     'minOrderQty': '1',
#     'qtyStep': '1',
#     'postOnlyMaxOrderQty': '5000000'},
#    'unifiedMarginTrade': False,
#    'fundingInterval': '480',
#    'settleCoin': 'XRP'},
#   'percentage': True,
#   'feeSide': 'get',
#   'tierBased': True,
#   'taker': 0.0006,
#   'maker': 0.0001}}

# %%
exh.symbols
# Out:
# ['10000NFT/USDT:USDT',
#  '1000BONK/USDT:USDT',
#  '1000BTT/USDT:USDT',
#  '1000FLOKI/USDT:USDT',
#  '1000LUNC/USDT:USDT',
#  '1000XEC/USDT:USDT',
#  '1INCH/USDT',
#  '1INCH/USDT:USDT',
#  '1SOL/USDT',
#  '3P/USDT',
#  'AAVE/USDT',
#  'AAVE/USDT:USDT',
#  'ACA/USDT',
#  'ACH/USDT',
#  'ACH/USDT:USDT',
#  'ACM/USDT',
#  'ACS/USDT',
#  'ADA/USD:ADA',
#  'ADA/USDC',
#  'ADA/USDT',
#  'ADA/USDT:USDT',
#  'ADA2L/USDT',
#  'ADA2S/USDT',
#  'AFC/USDT',
#  'AGIX/USDT',
#  'AGIX/USDT:USDT',
#  'AGLA/USDT',
#  'AGLD/USDT',
#  'AGLD/USDT:USDT',
#  'AKRO/USDT:USDT',
#  'ALGO/BTC',
#  'ALGO/USDT',
#  'ALGO/USDT:USDT',
#  'ALICE/USDT:USDT',
#  'ALPHA/USDT:USDT',
#  'ANKR/USDT',
#  'ANKR/USDT:USDT',
#  'ANT/USDT:USDT',
#  'APE/USD:USDC-230404',
#  'APE/USDC',
#  'APE/USDT',
#  'APE/USDT:USDT',
#  'APE2L/USDT',
#  'APE2S/USDT',
#  'APEX/USDC',
#  'APEX/USDT',
#  'API3/USDT:USDT',
#  'APT/USDC',
#  'APT/USDT',
#  'APT/USDT:USDT',
#  'AR/USDT',
#  'AR/USDT:USDT',
#  'ARB/USDC',
#  'ARB/USDT',
#  'ARB/USDT:USDT',
#  'ARPA/USDT:USDT',
#  'ASTR/USDT:USDT',
#  'ATOM/USD:USDC-230404',
#  'ATOM/USDT',
#  'ATOM/USDT:USDT',
#  'ATOM2L/USDT',
#  'ATOM2S/USDT',
#  'AUDIO/USDT:USDT',
#  'AVA/USDT',
#  'AVAX/USD:USDC-230404',
#  'AVAX/USDC',
#  'AVAX/USDT',
#  'AVAX/USDT:USDT',
#  'AVAX2L/USDT',
#  'AVAX2S/USDT',
#  'AXS/USDT',
#  'AXS/USDT:USDT',
#  'AZY/USDT',
#  'BAKE/USDT:USDT',
#  'BAL/USDT:USDT',
#  'BAND/USDT:USDT',
#  'BAR/USDT',
#  'BAT/USDT',
#  'BAT/USDT:USDT',
#  'BCH/USDT',
#  'BCH/USDT:USDT',
#  'BEL/USDT',
#  'BEL/USDT:USDT',
#  'BICO/USDT',
#  'BICO/USDT:USDT',
#  'BIT/BTC',
#  'BIT/DAI',
#  'BIT/USD:BIT',
#  'BIT/USDC',
#  'BIT/USDT',
#  'BIT/USDT:USDT',
#  'BLUR/USDT',
#  'BLUR/USDT:USDT',
#  'BLZ/USDT:USDT',
#  'BNB/USD:USDC',
#  'BNB/USDT',
#  'BNB/USDT:USDT',
#  'BNT/USDT',
#  'BNX/USDT:USDT',
#  'BOBA/USDT',
#  'BOBA/USDT:USDT',
#  'BONK/USDT',
#  'BSV/USDT:USDT',
#  'BSW/USDT:USDT',
#  'BTC/DAI',
#  'BTC/USD:BTC',
#  'BTC/USD:BTC-230630',
#  'BTC/USD:BTC-230929',
#  'BTC/USD:USDC',
#  'BTC/USD:USDC-230407',
#  'BTC/USD:USDC-230414',
#  'BTC/USD:USDC-230421',
#  'BTC/USD:USDC-230428',
#  'BTC/USD:USDC-230526',
#  'BTC/USD:USDC-230630',
#  'BTC/USD:USDC-230929',
#  'BTC/USDC',
#  'BTC/USDT',
#  'BTC/USDT:USDT',
#  'BTC3L/USDT',
#  'BTC3S/USDT',
#  'BTG/USDT',
#  'BTT/USDT',
#  'BUSD/USDT',
#  'BUSD/USDT:USDT',
#  'C98/USDT',
#  'C98/USDT:USDT',
#  'CAKE/USDT',
#  'CAPS/USDT',
#  'CBX/USDT',
#  'CEEK/USDT:USDT',
#  'CEL/USDT',
#  'CELO/USDT',
#  'CELO/USDT:USDT',
#  'CELR/USDT:USDT',
#  'CFX/USDT:USDT',
#  'CHR/USDT:USDT',
#  'CHRP/USDT',
#  'CHZ/USDC',
#  'CHZ/USDT',
#  'CHZ/USDT:USDT',
#  'CITY/USDT',
#  'CKB/USDT:USDT',
#  'CMP/USDT',
#  'CO/USDT',
#  'COCOS/USDT:USDT',
#  'COMP/USDT',
#  'COMP/USDT:USDT',
#  'CORE/USDT',
#  'CORE/USDT:USDT',
#  'COT/USDT',
#  'COTI/USDT:USDT',
#  'CRAFT/USDT',
#  'CREAM/USDT:USDT',
#  'CRO/USDT:USDT',
#  'CRV/USDT',
#  'CRV/USDT:USDT',
#  'CTC/USDT',
#  'CTC/USDT:USDT',
#  'CTK/USDT:USDT',
#  'CTSI/USDT:USDT',
#  'CULT/USDT',
#  'CUSD/USDT',
#  'CVC/USDT:USDT',
#  'CVX/USDT:USDT',
#  'CWAR/USDT',
#  'DAI/USDT',
#  'DAR/USDT:USDT',
#  'DASH/USDT:USDT',
#  'DCR/USDT',
#  'DEFY/USDT',
#  'DENT/USDT:USDT',
#  'DEVT/USDT',
#  'DFI/USDT',
#  'DGB/USDT',
#  'DGB/USDT:USDT',
#  'DICE/USDT',
#  'DLC/USDT',
#  'DODO/USDT:USDT',
#  'DOGE/USDC',
#  'DOGE/USDT',
#  'DOGE/USDT:USDT',
#  'DOGE2L/USDT',
#  'DOGE2S/USDT',
#  'DOME/USDT',
#  'DOT/BTC',
#  'DOT/USD:DOT',
#  'DOT/USDC',
#  'DOT/USDT',
#  'DOT/USDT:USDT',
#  'DOT3L/USDT',
#  'DOT3S/USDT',
#  'DPX/USDT',
#  'DUSK/USDT:USDT',
#  'DYDX/USDT',
#  'DYDX/USDT:USDT',
#  'DZOO/USDT',
#  'ECOX/USDT',
#  'EGLD/USDT',
#  'EGLD/USDT:USDT',
#  'ELT/USDT',
#  'ENJ/USDT',
#  'ENJ/USDT:USDT',
#  'ENS/USDT',
#  'ENS/USDT:USDT',
#  'EOS/USD:EOS',
#  'EOS/USDC',
#  'EOS/USDT',
#  'EOS/USDT:USDT',
#  'EOS2L/USDT',
#  'EOS2S/USDT',
#  'ERTHA/USDT',
#  'ETC/USD:USDC',
#  'ETC/USDT',
#  'ETC/USDT:USDT',
#  'ETC2L/USDT',
#  'ETC2S/USDT',
#  'ETH/BTC',
#  'ETH/DAI',
#  'ETH/USD:ETH',
#  'ETH/USD:ETH-230630',
#  'ETH/USD:ETH-230929',
#  'ETH/USD:USDC',
#  'ETH/USD:USDC-230407',
#  'ETH/USD:USDC-230414',
#  'ETH/USD:USDC-230421',
#  'ETH/USD:USDC-230428',
#  'ETH/USD:USDC-230526',
#  'ETH/USD:USDC-230630',
#  'ETH/USD:USDC-230929',
#  'ETH/USDC',
#  'ETH/USDT',
#  'ETH/USDT:USDT',
#  'ETH3L/USDT',
#  'ETH3S/USDT',
#  'ETHW/USDT',
#  'ETHW/USDT:USDT',
#  'EVER/USDT',
#  'FAME/USDT',
#  'FB/USDT',
#  'FET/USDT:USDT',
#  'FIDA/USDT',
#  'FIL/USDC',
#  'FIL/USDT',
#  'FIL/USDT:USDT',
#  'FITFI/USDT',
#  'FITFI/USDT:USDT',
#  'FLM/USDT:USDT',
#  'FLOKI/USDT',
#  'FLOW/USDT',
#  'FLOW/USDT:USDT',
#  'FLR/USDT',
#  'FLR/USDT:USDT',
#  'FORT/USDT',
#  'FTM/USDT',
#  'FTM/USDT:USDT',
#  'FTM2L/USDT',
#  'FTM2S/USDT',
#  'FTT/USDT',
#  'FXS/USDT',
#  'FXS/USDT:USDT',
#  'GAL/USDT',
#  'GAL/USDT:USDT',
#  'GALA/USDT',
#  'GALA/USDT:USDT',
#  'GALFT/USDT',
#  'GCAKE/USDT',
#  'GENE/USDT',
#  'GFT/USDT:USDT',
#  'GGM/USDT',
#  'GLMR/USDT',
#  'GLMR/USDT:USDT',
#  'GM/USDT',
#  'GMT/USDC',
#  'GMT/USDT',
#  'GMT/USDT:USDT',
#  'GMT2L/USDT',
#  'GMT2S/USDT',
#  'GMX/USDT',
#  'GMX/USDT:USDT',
#  'GNS/USDT',
#  'GODS/USDT',
#  'GPT/USDT',
#  'GPT/USDT:USDT',
#  'GRT/USDT',
#  'GRT/USDT:USDT',
#  'GST/USDT',
#  'GSTS/USDT',
#  'GTC/USDT:USDT',
#  'HBAR/USDT',
#  'HBAR/USDT:USDT',
#  'HERO/USDT',
#  'HFT/USDC',
#  'HFT/USDT',
#  'HFT/USDT:USDT',
#  'HIGH/USDT:USDT',
#  'HNT/USDT',
#  'HNT/USDT:USDT',
#  'HOOK/USDT',
#  'HOOK/USDT:USDT',
#  'HOT/USDT',
#  'HOT/USDT:USDT',
#  'HVH/USDT',
#  'ICP/USDC',
#  'ICP/USDT',
#  'ICP/USDT:USDT',
#  'ICX/USDT',
#  'ICX/USDT:USDT',
#  'ID/USDT',
#  'ID/USDT:USDT',
#  'ILV/USDT:USDT',
#  'IME/USDT',
#  'IMX/USDT',
#  'IMX/USDT:USDT',
#  'INJ/USDT',
#  'INJ/USDT:USDT',
#  'INSUR/USDT',
#  'INTER/USDT',
#  'IOST/USDT:USDT',
#  'IOTA/USDT:USDT',
#  'IOTX/USDT:USDT',
#  'IZI/USDT',
#  'JASMY/USDT',
#  'JASMY/USDT:USDT',
#  'JOE/USDT:USDT',
#  'JST/USDT',
#  'JST/USDT:USDT',
#  'JUV/USDT',
#  'KASTA/USDT',
#  'KAVA/USDT:USDT',
#  'KCAL/USDT',
#  'KDA/USDT',
#  'KDA/USDT:USDT',
#  'KLAY/USDT',
#  'KLAY/USDT:USDT',
#  'KMON/USDT',
#  'KNC/USDT:USDT',
#  'KOK/USDT',
#  'KON/USDT',
#  'KRL/USDT',
#  'KSM/USDT',
#  'KSM/USDT:USDT',
#  'KUNCI/USDT',
#  'LDO/USD:USDC-230404',
#  'LDO/USDC',
#  'LDO/USDT',
#  'LDO/USDT:USDT',
#  'LFW/USDT',
#  'LGX/USDT',
#  'LINA/USDT:USDT',
#  'LING/USDT',
#  'LINK/USDC',
#  'LINK/USDT',
#  'LINK/USDT:USDT',
#  'LINK2L/USDT',
#  'LINK2S/USDT',
#  'LIS/USDT',
#  'LIT/USDT:USDT',
#  'LOOKS/USDT',
#  'LOOKS/USDT:USDT',
#  'LPT/USDT:USDT',
#  'LQTY/USDT:USDT',
#  'LRC/USDT',
#  'LRC/USDT:USDT',
#  'LTC/BTC',
#  'LTC/USD:LTC',
#  'LTC/USDC',
#  'LTC/USDT',
#  'LTC/USDT:USDT',
#  'LTC2L/USDT',
#  'LTC2S/USDT',
#  'LUNA/USDT',
#  'LUNA2/USDT:USDT',
#  'LUNC/USDC',
#  'LUNC/USDT',
#  'MAGIC/USDT',
#  'MAGIC/USDT:USDT',
#  'MANA/BTC',
#  'MANA/USD:MANA',
#  'MANA/USDC',
#  'MANA/USDT',
#  'MANA/USDT:USDT',
#  'MASK/USDT',
#  'MASK/USDT:USDT',
#  'MATIC/BTC',
#  'MATIC/USD:USDC',
#  'MATIC/USDC',
#  'MATIC/USDT',
#  'MATIC/USDT:USDT',
#  'MATIC2L/USDT',
#  'MATIC2S/USDT',
#  'MBS/USDT',
#  'MBX/USDT',
#  'MCRT/USDT',
#  'MCT/USDT',
#  'MDAO/USDT',
#  'MEE/USDT',
#  'MELOS/USDT',
#  'MIBR/USDT',
#  'MINA/USDT',
#  'MINA/USDT:USDT',
#  'MIX/USDT',
#  'MKR/USDT',
#  'MKR/USDT:USDT',
#  'MMC/USDT',
#  'MNZ/USDT',
#  'MOVEZ/USDT',
#  'MOVR/USDT',
#  'MPLX/USDT',
#  'MTK/USDT',
#  'MTL/USDT:USDT',
#  'MV/USDT',
#  'MX/USDT',
#  'NEAR/USD:USDC-230404',
#  'NEAR/USDT',
#  'NEAR/USDT:USDT',
#  'NEO/USDT:USDT',
#  'NEXO/USDT',
#  'NFT/USDT',
#  'NKN/USDT:USDT',
#  'OAS/USDT',
#  'OBX/USDT',
#  'OCEAN/USDT:USDT',
#  'OGN/USDT:USDT',
#  'OKG/USDT',
#  'OKSE/USDT',
#  'OMG/USDT',
#  'OMG/USDT:USDT',
#  'ONE/USDT',
#  'ONE/USDT:USDT',
#  'ONT/USDT:USDT',
#  'OP/USD:USDC',
#  'OP/USDC',
#  'OP/USDT',
#  'OP/USDT:USDT',
#  'ORT/USDT',
#  'PAXG/USDT',
#  'PAXG/USDT:USDT',
#  'PEOPLE/USDT',
#  'PEOPLE/USDT:USDT',
#  'PERP/USDT',
#  'PIP/USDT',
#  'PLT/USDT',
#  'PLY/USDT',
#  'POKT/USDT',
#  'PRIMAL/USDT',
#  'PRIME/USDT',
#  'PSG/USDT',
#  'PSP/USDT',
#  'PSTAKE/USDT',
#  'PTU/USDT',
#  'PUMLX/USDT',
#  'QMALL/USDT',
#  'QNT/USDT',
#  'QTUM/USDT',
#  'QTUM/USDT:USDT',
#  'RACA/USDT',
#  'RAIN/USDT',
#  'RDNT/USDT',
#  'REAL/USDT',
#  'REEF/USDT:USDT',
#  'REN/USDT',
#  'REN/USDT:USDT',
#  'REQ/USDT:USDT',
#  'RLC/USDT:USDT',
#  'RNDR/USDT',
#  'RNDR/USDT:USDT',
#  'ROND/USDT',
#  'ROSE/USDT',
#  'ROSE/USDT:USDT',
#  'RPL/USDT',
#  'RPL/USDT:USDT',
#  'RSR/USDT:USDT',
#  'RSS3/USDT',
#  'RSS3/USDT:USDT',
#  'RUNE/USDT',
#  'RUNE/USDT:USDT',
#  'RVN/USDT',
#  'RVN/USDT:USDT',
#  'SAITAMA/USDT',
#  'SAND/BTC',
#  'SAND/USDC',
#  'SAND/USDT',
#  'SAND/USDT:USDT',
#  'SAND2L/USDT',
#  'SAND2S/USDT',
#  'SC/USDT',
#  'SC/USDT:USDT',
#  'SCRT/USDT',
#  'SCRT/USDT:USDT',
#  'SD/USDT',
#  'SEOR/USDT',
#  'SFP/USDT:USDT',
#  'SFUND/USDT',
#  'SHIB/USDC',
#  'SHIB/USDT',
#  'SHIB1000/USDT:USDT',
#  'SHILL/USDT',
#  'SIDUS/USDT',
#  'SIS/USDT',
#  'SKL/USDT:USDT',
#  'SLG/USDC',
#  'SLG/USDT',
#  'SLP/USDT',
#  'SLP/USDT:USDT',
#  'SNX/USDT',
#  'SNX/USDT:USDT',
#  'SOL/BTC',
#  'SOL/USD:USDC',
#  'SOL/USDC',
#  'SOL/USDT',
#  'SOL/USDT:USDT',
#  'SOLO/USDT',
#  'SON/USDT',
#  'SOS/USDT',
#  'SPELL/USDT',
#  'SPELL/USDT:USDT',
#  'SRM/USDT',
#  'SSV/USDT',
#  'SSV/USDT:USDT',
#  'STAT/USDT',
#  'STETH/USDT',
#  'STG/USDT',
#  'STG/USDT:USDT',
#  'STMX/USDT:USDT',
#  'STORJ/USDT:USDT',
#  'STRM/USDT',
#  'STX/USDT',
#  'STX/USDT:USDT',
#  'SUN/USDT',
#  'SUN/USDT:USDT',
#  'SUSHI/USDT',
#  'SUSHI/USDT:USDT',
#  'SWEAT/USDT',
#  'SWEAT/USDT:USDT',
#  'SXP/USDT:USDT',
#  'SYNR/USDT',
#  'T/USDT',
#  'T/USDT:USDT',
#  'TAP/USDT',
#  'TEL/USDT',
#  'THETA/USDT',
#  'THETA/USDT:USDT',
#  'THN/USDT',
#  'TIME/USDT',
#  'TLM/USDT:USDT',
#  'TOMO/USDT:USDT',
#  'TON/USDT',
#  'TRB/USDT:USDT',
#  'TRIBE/USDT',
#  'TRU/USDT:USDT',
#  'TRVL/USDT',
#  'TRX/USDC',
#  'TRX/USDT',
#  'TRX/USDT:USDT',
#  'TWT/USDT',
#  'TWT/USDT:USDT',
#  'UMA/USDT',
#  'UNFI/USDT:USDT',
#  'UNI/USDT',
#  'UNI/USDT:USDT',
#  'USDC/USDT',
#  'USDC/USDT:USDT',
#  'USDD/USDT',
#  'USDT/EUR',
#  'USTC/USDT',
#  'VET/USDT:USDT',
#  'VINU/USDT',
#  'VPAD/USDT',
#  'VRA/USDT',
#  'WAVES/USDT',
#  'WAVES/USDT:USDT',
#  'WAXP/USDT',
#  'WBTC/BTC',
#  'WBTC/USDT',
#  'WEMIX/USDT',
#  'WLKN/USDT',
#  'WOO/USDT',
#  'WOO/USDT:USDT',
#  'WWY/USDT',
#  'XAVA/USDT',
#  'XCAD/USDT',
#  'XCN/USDT:USDT',
#  'XDC/USDT',
#  'XEC/USDT',
#  'XEM/USDT',
#  'XEM/USDT:USDT',
#  'XETA/USDT',
#  'XLM/BTC',
#  'XLM/USDC',
#  'XLM/USDT',
#  'XLM/USDT:USDT',
#  'XMR/USDT:USDT',
#  'XNO/USDT:USDT',
#  'XRP/BTC',
#  'XRP/USD:USDC',
#  'XRP/USD:XRP',
#  'XRP/USDC',
#  'XRP/USDT',
#  'XRP/USDT:USDT',
#  'XRP3L/USDT',
#  'XRP3S/USDT',
#  'XTZ/USDT',
#  'XTZ/USDT:USDT',
#  'XWG/USDT',
#  'XYM/USDT',
#  'YFI/USDT',
#  'YFI/USDT:USDT',
#  'YGG/USDT:USDT',
#  'ZAM/USDT',
#  'ZBC/USDT',
#  'ZEC/USDT:USDT',
#  'ZEN/USDT',
#  'ZEN/USDT:USDT',
#  'ZIL/USDT',
#  'ZIL/USDT:USDT',
#  'ZRX/USDT',
#  'ZRX/USDT:USDT']

# %%
qf.CCXTData.data_download(
    exchange='bybit',
    start='2005-01-01T00:00:00Z',
    end='2023-02-01T00:00:00Z',
    symbol='XRPUSDT',
    timeframe='4h'
)
# Out:
#                      open  high  low  close        volume
# open_time
# 2021-05-13 08:00:00  1.30  1.31 1.22   1.29  1,200,784.00
# 2021-05-13 12:00:00  1.29  1.37 1.28   1.30  3,465,858.00
# 2021-05-13 16:00:00  1.30  1.34 1.23   1.26  2,903,976.00
# 2021-05-13 20:00:00  1.26  1.36 1.25   1.36  2,017,440.00
# 2021-05-14 00:00:00  1.36  1.37 1.33   1.33  1,534,092.00
# ...                   ...   ...  ...    ...           ...
# 2023-01-31 04:00:00  0.39  0.40 0.39   0.40 37,042,347.00
# 2023-01-31 08:00:00  0.40  0.40 0.39   0.40 72,877,248.00
# 2023-01-31 12:00:00  0.40  0.40 0.40   0.40 50,019,997.00
# 2023-01-31 16:00:00  0.40  0.41 0.40   0.41 45,987,766.00
# 2023-01-31 20:00:00  0.41  0.41 0.40   0.41 69,162,584.00
#
# [3772 rows x 5 columns]
