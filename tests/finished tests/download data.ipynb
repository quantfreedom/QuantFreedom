# %%
import quantfreedom as qf
import pandas as pd

# %%
qf.CCXTData.data_download(
    exchange='bybit',
    # start='2020-10-01T00:00:00Z',
    # end='2021-04-01T00:00:00Z',
    start='2022-08-01T00:00:00Z',
    end='2023-01-03T00:00:00Z',
    symbols=['BTCUSDT', 'XRPUSDT'],
    timeframe='4h',
    drop_volume=True,
)
# Out:
# Loading exchange data
# Total rows of data to be download: 930
# Total candles to be download: 1860
# Downloading XRPUSDT: 100%|██████████| 12/12 [00:06<00:00,  1.87it/s]
# symbol                BTCUSDT                               XRPUSDT            \
# candle_info              open      high       low     close    open high  low
# open_time
# 2022-08-01 00:00:00 23,290.50 23,453.50 23,250.00 23,369.50    0.38 0.39 0.38
# 2022-08-01 04:00:00 23,369.50 23,400.00 23,108.00 23,308.50    0.38 0.38 0.38
# 2022-08-01 08:00:00 23,308.50 23,377.50 22,930.00 23,213.00    0.38 0.38 0.37
# 2022-08-01 12:00:00 23,213.00 23,490.00 22,939.00 23,320.00    0.38 0.38 0.37
# 2022-08-01 16:00:00 23,320.00 23,341.00 22,825.00 22,948.00    0.38 0.38 0.37
# ...                       ...       ...       ...       ...     ...  ...  ...
# 2023-01-02 08:00:00 16,717.50 16,768.50 16,702.00 16,731.00    0.34 0.35 0.34
# 2023-01-02 12:00:00 16,731.00 16,749.50 16,666.00 16,731.50    0.34 0.35 0.34
# 2023-01-02 16:00:00 16,731.50 16,736.50 16,700.50 16,734.50    0.35 0.36 0.35
# 2023-01-02 20:00:00 16,734.50 16,799.00 16,651.00 16,668.00    0.35 0.35 0.35
# 2023-01-03 00:00:00 16,668.00 16,703.50 16,644.50 16,691.00    0.35 0.35 0.34
#
# symbol
# candle_info         close
# open_time
# 2022-08-01 00:00:00  0.38
# 2022-08-01 04:00:00  0.38
# 2022-08-01 08:00:00  0.38
# 2022-08-01 12:00:00  0.38
# 2022-08-01 16:00:00  0.38
# ...                   ...
# 2023-01-02 08:00:00  0.34
# 2023-01-02 12:00:00  0.35
# 2023-01-02 16:00:00  0.35
# 2023-01-02 20:00:00  0.35
# 2023-01-03 00:00:00  0.34
#
# [930 rows x 8 columns]

# %%
asdf = [234]
if asdf:
    print('hey')

# %%
data.to_hdf('test.hd5', key='data')

# %%
pd.read_hdf('test.hd5')

# %%
data.to_dict()
