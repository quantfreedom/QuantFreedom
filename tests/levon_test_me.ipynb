# %%
import numpy as np
import pandas as pd
from quantfreedom import generate_candles
from quantfreedom.indicators.test_talib import from_talib_test

# %%
price_data = pd.read_hdf('../tests/data/prices.hd5')

# %%
rsi_data = from_talib_test(
     func_name="rsi",
     price_data=price_data,
    timeperiod=[15, 30, 40],
    plot_results=False,
    # price="low",
)
rsi_ema_ind = from_talib_test(
    func_name='ema',
    indicator_data=rsi_data.data,
    cart_product=False,
    combos=False,
    timeperiod=[25, 45]
)
rsi_data.is_below(user_args=[30,45])
rsi_ema_ind.data
rsi_data.is_below(indicator_data=rsi_ema_ind.data)
rsi_data.combined_data_frame(['is_below0', 'is_below1'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 18
#      16 rsi_ema_ind.data
#      17 rsi_data.is_below(indicator_data=rsi_ema_ind.data)
# ---> 18 rsi_data.combined_data_frame(['is_below0', 'is_below1'])
#
# File e:\coding\backtesters\quantfreedom\quantfreedom\indicators\indicators_cls.py:33, in Indicator.combined_data_frame(self, eval_names)
#      31             b[symbol] = curr_val
#      32         else:
# ---> 33              b[symbol] = b[symbol] & curr_val
#      34 return b
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\frame.py:7586, in DataFrame._arith_method(self, other, op)
#    7585 def _arith_method(self, other, op):
# -> 7586     if ops.should_reindex_frame_op(self, other, op, 1, 1, None, None):
#    7587         return ops.frame_arith_method_with_reindex(self, other, op)
#    7589     axis = 1  # only relevant for Series other case
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\ops\__init__.py:336, in should_reindex_frame_op(left, right, op, axis, default_axis, fill_value, level)
#     334 left_uniques = left.columns.unique()
#     335 right_uniques = right.columns.unique()
# --> 336 cols = left_uniques.intersection(right_uniques)
#     337 if len(cols) and not (
#     338     len(cols) == len(left_uniques) and len(cols) == len(right_uniques)
#     339 ):
#     340     # TODO: is there a shortcut available when len(cols) == 0?
#     341     return True
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\indexes\base.py:3514, in Index.intersection(self, other, sort)
#    3511     return this.intersection(other, sort=sort)
#    3513 result = self._intersection(other, sort=sort)
# -> 3514 return self._wrap_intersection_result(other, result)
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\indexes\multi.py:3682, in MultiIndex._wrap_intersection_result(self, other, result)
#    3679 _, result_names = self._convert_can_do_setop(other)
#    3681 if len(result) == 0:
# -> 3682     return MultiIndex(
#    3683         levels=self.levels,
#    3684         codes=[[]] * self.nlevels,
#    3685         names=result_names,
#    3686         verify_integrity=False,
#    3687     )
#    3688 else:
#    3689     return MultiIndex.from_arrays(zip(*result), sortorder=0, names=result_names)
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\indexes\multi.py:334, in MultiIndex.__new__(cls, levels, codes, sortorder, names, dtype, copy, name, verify_integrity)
#     331 result._names = [None] * len(levels)
#     332 if names is not None:
#     333     # handles name validation
# --> 334     result._set_names(names)
#     336 if sortorder is not None:
#     337     result.sortorder = int(sortorder)
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\indexes\multi.py:1474, in MultiIndex._set_names(self, names, level, validate)
#    1472         raise ValueError("Length of names must match length of level.")
#    1473     if level is None and len(names) != self.nlevels:
# -> 1474         raise ValueError(
#    1475             "Length of names must match number of levels in MultiIndex."
#    1476         )
#    1478 if level is None:
#    1479     level = range(self.nlevels)
#
# ValueError: Length of names must match number of levels in MultiIndex.

# %%
rsi_ema_ind.data

# %%
rsi_data.is_below(indicator_data=rsi_ema_ind.data)

# %%
print(rsi_data.combined_data_frame(['is_below0', 'is_below1']))
