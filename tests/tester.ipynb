# %%
import quantfreedom as qf
import pandas as pd

# %%
price_data = pd.read_hdf('data/prices.hd5')
price_data
# Out:
# symbol                BTCUSDT                               EOSUSD
# candle_info              open      high       low     close   open high  low
# open_time
# 2020-10-01 00:00:00 10,759.00 10,817.50 10,759.00 10,790.00   2.58 2.58 2.58  \
# 2020-10-01 00:30:00 10,790.00 10,790.50 10,775.00 10,777.00   2.58 2.58 2.58
# 2020-10-01 01:00:00 10,777.00 10,793.00 10,777.00 10,793.00   2.58 2.59 2.58
# 2020-10-01 01:30:00 10,793.00 10,836.00 10,792.50 10,822.00   2.59 2.59 2.59
# 2020-10-01 02:00:00 10,822.00 10,841.50 10,808.00 10,808.50   2.59 2.60 2.59
# ...                       ...       ...       ...       ...    ...  ...  ...
# 2021-04-14 21:30:00 62,703.50 62,812.50 62,615.50 62,795.00   7.58 7.62 7.54
# 2021-04-14 22:00:00 62,795.00 62,825.00 62,591.00 62,680.00   7.61 7.73 7.55
# 2021-04-14 22:30:00 62,680.00 62,993.00 62,680.00 62,849.50   7.65 7.77 7.65
# 2021-04-14 23:00:00 62,849.50 62,999.00 62,750.00 62,999.00   7.71 7.79 7.67
# ...

# %%
btc_prices = pd.DataFrame().join(price_data[['BTCUSDT']])
btc_prices
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 btc_prices = pd.DataFrame().join(price_data[['BTCUSDT']])
#       2 btc_prices
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\pandas\core\frame.py:9729, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9566 def join(
#    9567     self,
#    9568     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9574     validate: str | None = None,
#    9575 ) -> DataFrame:
#    9576     """
#    9577     Join columns of another DataFrame.
#    9578
#    (...)
#    9727     5  K1  A5   B1
#    9728     """
# -> 9729     return self._join_compat(
#    9730         other,
#    9731         on=on,
#    9732         how=how,
#    9733         lsuffix=lsuffix,
#    9734         rsuffix=rsuffix,
#    9735         sort=sort,
# ...

# %%
price_data[price_data['BTCUSDT'] == price_data['BTCUSDT']]
# Out:
# symbol                BTCUSDT                               EOSUSD            \
# candle_info              open      high       low     close   open high  low
# open_time
# 2020-10-01 00:00:00 10,759.00 10,817.50 10,759.00 10,790.00   2.58 2.58 2.58
# 2020-10-01 00:30:00 10,790.00 10,790.50 10,775.00 10,777.00   2.58 2.58 2.58
# 2020-10-01 01:00:00 10,777.00 10,793.00 10,777.00 10,793.00   2.58 2.59 2.58
# 2020-10-01 01:30:00 10,793.00 10,836.00 10,792.50 10,822.00   2.59 2.59 2.59
# 2020-10-01 02:00:00 10,822.00 10,841.50 10,808.00 10,808.50   2.59 2.60 2.59
# ...                       ...       ...       ...       ...    ...  ...  ...
# 2021-04-14 21:30:00 62,703.50 62,812.50 62,615.50 62,795.00   7.58 7.62 7.54
# 2021-04-14 22:00:00 62,795.00 62,825.00 62,591.00 62,680.00   7.61 7.73 7.55
# 2021-04-14 22:30:00 62,680.00 62,993.00 62,680.00 62,849.50   7.65 7.77 7.65
# 2021-04-14 23:00:00 62,849.50 62,999.00 62,750.00 62,999.00   7.71 7.79 7.67
# ...

# %%
price_data.copy()
# Out:
# symbol              EOSUSD                   ETHUSD                    \
# candle_info           open high  low close     open     high      low
# open_time
# 2020-10-01 00:00:00   2.58 2.58 2.58  2.58   359.85   361.45   358.85
# 2020-10-01 00:30:00   2.58 2.58 2.58  2.58   358.95   359.75   358.95
# 2020-10-01 01:00:00   2.58 2.59 2.58  2.59   359.25   359.80   358.80
# 2020-10-01 01:30:00   2.59 2.59 2.59  2.59   359.75   361.40   359.75
# 2020-10-01 02:00:00   2.59 2.60 2.59  2.59   361.20   364.05   361.20
# ...                    ...  ...  ...   ...      ...      ...      ...
# 2021-04-14 21:30:00   7.58 7.62 7.54  7.61 2,406.20 2,440.00 2,397.20
# 2021-04-14 22:00:00   7.61 7.73 7.55  7.65 2,434.05 2,445.00 2,418.65
# 2021-04-14 22:30:00   7.65 7.77 7.65  7.71 2,427.00 2,438.60 2,423.50
# 2021-04-14 23:00:00   7.71 7.79 7.67  7.78 2,431.30 2,450.00 2,431.30
# 2021-04-14 23:30:00   7.78 7.78 7.63  7.68 2,445.95 2,445.95 2,417.40
#
# ...

# %%
price_data.columns.levels
# Out:
# FrozenList([['BTCUSDT', 'EOSUSD', 'ETHUSD', 'LTCUSDT', 'XRPUSD'], ['close', 'high', 'low', 'open']])

# %%
qf.from_talib(
    func_name="rsi",
    price_data=price_data,
    timeperiod=20,
    plot_results=False,
    # price="low",
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 qf.from_talib(
#       2     func_name="rsi",
#       3     price_data=price_data,
#       4     timeperiod=20,
#       5     plot_results=False,
#       6     # price="low",
#       7 )
#
# File e:\coding\backtesters\quantfreedom\quantfreedom\indicators\talib_ind.py:256, in from_talib(func_name, price_data, indicator_data, all_possible_combos, column_wise_combos, plot_results, plot_on_data, **kwargs)
#     252 temp_price_data_tuple = ()
#     254 for input_name in input_names:
#     255     temp_price_data_tuple = temp_price_data_tuple + (
# --> 256         price_data[symbol][input_name].values,
#     257     )
#     259 for c in range(ind_setings_len):
#     260     # x is the array object in the tuple (x,x)
#     261     for x in final_user_args:
#
# ...
