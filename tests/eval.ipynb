# %%
import quantfreedom as qf
import pandas as pd
from quantfreedom.indicators.talib_ind import *
from quantfreedom.evaluators.evaluators import _is_below

# %load_ext autoreload
# %autoreload 2

prices = pd.read_hdf('data/prices.hd5')

# %%
prices
# Out:
# symbol                BTCUSDT                               EOSUSD
# candle_info              open      high       low     close   open high  low
# open_time
# 2020-10-01 00:00:00 10,759.00 10,817.50 10,759.00 10,790.00   2.58 2.58 2.58  \
# 2020-10-01 00:30:00 10,790.00 10,790.50 10,775.00 10,777.00   2.58 2.58 2.58
# 2020-10-01 01:00:00 10,777.00 10,793.00 10,777.00 10,793.00   2.58 2.59 2.58
# 2020-10-01 01:30:00 10,793.00 10,836.00 10,792.50 10,822.00   2.59 2.59 2.59
# 2020-10-01 02:00:00 10,822.00 10,841.50 10,808.00 10,808.50   2.59 2.60 2.59
# ...                       ...       ...       ...       ...    ...  ...  ...
# 2021-04-14 21:30:00 62,703.50 62,812.50 62,615.50 62,795.00   7.58 7.62 7.54
# 2021-04-14 22:00:00 62,795.00 62,825.00 62,591.00 62,680.00   7.61 7.73 7.55
# 2021-04-14 22:30:00 62,680.00 62,993.00 62,680.00 62,849.50   7.65 7.77 7.65
# 2021-04-14 23:00:00 62,849.50 62,999.00 62,750.00 62,999.00   7.71 7.79 7.67
# 2021-04-14 23:30:00 62,999.00 62,999.00 62,606.00 62,921.00   7.78 7.78 7.63
#
# symbol                      ETHUSD                            LTCUSDT
# candle_info         close     open     high      low    close    open   high
# open_time
# 2020-10-01 00:00:00  2.58   359.85   361.45   358.85   358.95     NaN    NaN  \
# 2020-10-01 00:30:00  2.58   358.95   359.75   358.95   359.25     NaN    NaN
# 2020-10-01 01:00:00  2.59   359.25   359.80   358.80   359.75     NaN    NaN
# 2020-10-01 01:30:00  2.59   359.75   361.40   359.75   361.20     NaN    NaN
# 2020-10-01 02:00:00  2.59   361.20   364.05   361.20   362.95     NaN    NaN
# ...                   ...      ...      ...      ...      ...     ...    ...
# 2021-04-14 21:30:00  7.61 2,406.20 2,440.00 2,397.20 2,434.05  269.26 281.37
# 2021-04-14 22:00:00  7.65 2,434.05 2,445.00 2,418.65 2,427.00  280.82 282.02
# 2021-04-14 22:30:00  7.71 2,427.00 2,438.60 2,423.50 2,431.30  278.49 281.31
# 2021-04-14 23:00:00  7.78 2,431.30 2,450.00 2,431.30 2,445.95  277.50 280.17
# 2021-04-14 23:30:00  7.68 2,445.95 2,445.95 2,417.40 2,438.20  279.05 280.95
#
# symbol                            XRPUSD
# candle_info            low  close   open high  low close
# open_time
# 2020-10-01 00:00:00    NaN    NaN   0.24 0.24 0.24  0.24
# 2020-10-01 00:30:00    NaN    NaN   0.24 0.24 0.24  0.24
# 2020-10-01 01:00:00    NaN    NaN   0.24 0.24 0.24  0.24
# 2020-10-01 01:30:00    NaN    NaN   0.24 0.24 0.24  0.24
# 2020-10-01 02:00:00    NaN    NaN   0.24 0.24 0.24  0.24
# ...                    ...    ...    ...  ...  ...   ...
# 2021-04-14 21:30:00 269.11 280.82   1.78 1.82 1.77  1.82
# 2021-04-14 22:00:00 278.24 278.49   1.82 1.82 1.77  1.78
# 2021-04-14 22:30:00 276.64 277.50   1.78 1.82 1.78  1.80
# 2021-04-14 23:00:00 277.46 279.05   1.80 1.84 1.79  1.83
# 2021-04-14 23:30:00 277.95 279.41   1.83 1.85 1.82  1.84
#
# [9408 rows x 20 columns]

# %%
rsi = from_talib(
    func_name='rsi',
    price_data=prices,
    input_names = ['open'],
    parameters = {'timeperiod': [15, 20, 25, 30]}
)

# %%
ema = from_talib(
    func_name='ema',
    price_data=prices,
    input_names = ['close'],
    parameters = {'timeperiod': [100,200,300]}
)

# %%
from_talib(
    func_name='ema',
    indicator_data=rsi.data,
    parameters = {'timeperiod': [50, 70, 90]}
).data
# Out:
# symbol               BTCUSDT
# output                  real
# candle_body         ["open"]
# rsi_timeperiod            15                20                25
# ema_timeperiod            50    70    90    50    70    90    50    70    90
# open_time
# 2020-10-01 00:00:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  \
# 2020-10-01 00:30:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 01:00:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 01:30:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 02:00:00      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                      ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2021-04-14 21:30:00    51.48 53.47 54.46 52.86 54.53 55.31 53.86 55.26 55.88
# 2021-04-14 22:00:00    51.24 53.24 54.26 52.58 54.29 55.11 53.58 55.03 55.68
# 2021-04-14 22:30:00    50.95 52.97 54.03 52.27 54.02 54.88 53.28 54.77 55.47
# 2021-04-14 23:00:00    50.77 52.79 53.87 52.06 53.81 54.70 53.05 54.56 55.29
# 2021-04-14 23:30:00    50.70 52.68 53.75 51.91 53.66 54.56 52.89 54.40 55.15
#
# symbol                     ...   XRPUSD
# output                     ...     real
# candle_body                ... ["open"]
# rsi_timeperiod         30  ...       15    20                25
# ema_timeperiod         50  ...       90    50    70    90    50    70    90
# open_time                  ...
# 2020-10-01 00:00:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN  \
# 2020-10-01 00:30:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 01:00:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 01:30:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2020-10-01 02:00:00   NaN  ...      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                   ...  ...      ...   ...   ...   ...   ...   ...   ...
# 2021-04-14 21:30:00 54.57  ...    55.11 52.98 54.80 55.84 53.87 55.49 56.38
# 2021-04-14 22:00:00 54.31  ...    55.13 53.04 54.79 55.81 53.88 55.45 56.33
# 2021-04-14 22:30:00 54.02  ...    55.07 52.98 54.70 55.72 53.79 55.34 56.23
# 2021-04-14 23:00:00 53.79  ...    55.04 52.97 54.65 55.65 53.74 55.26 56.15
# 2021-04-14 23:30:00 53.62  ...    55.08 53.06 54.66 55.64 53.77 55.24 56.11
#
# symbol
# output
# candle_body
# rsi_timeperiod         30
# ema_timeperiod         50    70    90
# open_time
# 2020-10-01 00:00:00   NaN   NaN   NaN
# 2020-10-01 00:30:00   NaN   NaN   NaN
# 2020-10-01 01:00:00   NaN   NaN   NaN
# 2020-10-01 01:30:00   NaN   NaN   NaN
# 2020-10-01 02:00:00   NaN   NaN   NaN
# ...                   ...   ...   ...
# 2021-04-14 21:30:00 54.56 56.00 56.78
# 2021-04-14 22:00:00 54.53 55.94 56.71
# 2021-04-14 22:30:00 54.43 55.83 56.61
# 2021-04-14 23:00:00 54.36 55.74 56.52
# 2021-04-14 23:30:00 54.36 55.70 56.47
#
# [9408 rows x 60 columns]

# %%
_is_below(
    want_to_evaluate=rsi.data,
    user_args=[50,60],
)
# Out:
# symbol               BTCUSDT
# output                  real
# candle_body         ["open"]
# rsi_timeperiod            15            20            25            30
# output_is_below           50     60     50     60     50     60     50     60
# open_time
# 2020-10-01 00:00:00    False  False  False  False  False  False  False  False  \
# 2020-10-01 00:30:00    False  False  False  False  False  False  False  False
# 2020-10-01 01:00:00    False  False  False  False  False  False  False  False
# 2020-10-01 01:30:00    False  False  False  False  False  False  False  False
# 2020-10-01 02:00:00    False  False  False  False  False  False  False  False
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# 2021-04-14 21:30:00     True   True   True   True   True   True   True   True
# 2021-04-14 22:00:00     True   True   True   True   True   True   True   True
# 2021-04-14 22:30:00     True   True   True   True   True   True   True   True
# 2021-04-14 23:00:00     True   True   True   True   True   True   True   True
# 2021-04-14 23:30:00     True   True   True   True   True   True   True   True
#
# symbol                EOSUSD         ...  LTCUSDT          XRPUSD
# output                  real         ...     real            real
# candle_body         ["open"]         ... ["open"]        ["open"]
# rsi_timeperiod            15         ...       30              15
# output_is_below           50     60  ...       50     60       50     60
# open_time                            ...
# 2020-10-01 00:00:00    False  False  ...    False  False    False  False  \
# 2020-10-01 00:30:00    False  False  ...    False  False    False  False
# 2020-10-01 01:00:00    False  False  ...    False  False    False  False
# 2020-10-01 01:30:00    False  False  ...    False  False    False  False
# 2020-10-01 02:00:00    False  False  ...    False  False    False  False
# ...                      ...    ...  ...      ...    ...      ...    ...
# 2021-04-14 21:30:00    False   True  ...    False   True    False   True
# 2021-04-14 22:00:00    False   True  ...    False   True    False   True
# 2021-04-14 22:30:00    False   True  ...    False   True    False   True
# 2021-04-14 23:00:00    False   True  ...    False   True    False   True
# 2021-04-14 23:30:00    False   True  ...    False   True    False   True
#
# symbol
# output
# candle_body
# rsi_timeperiod          20            25            30
# output_is_below         50     60     50     60     50     60
# open_time
# 2020-10-01 00:00:00  False  False  False  False  False  False
# 2020-10-01 00:30:00  False  False  False  False  False  False
# 2020-10-01 01:00:00  False  False  False  False  False  False
# 2020-10-01 01:30:00  False  False  False  False  False  False
# 2020-10-01 02:00:00  False  False  False  False  False  False
# ...                    ...    ...    ...    ...    ...    ...
# 2021-04-14 21:30:00  False   True  False   True  False   True
# 2021-04-14 22:00:00  False   True  False   True  False   True
# 2021-04-14 22:30:00  False   True  False   True  False   True
# 2021-04-14 23:00:00  False   True  False   True  False   True
# 2021-04-14 23:30:00  False   True  False   True  False   True
#
# [9408 rows x 40 columns]
