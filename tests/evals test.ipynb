# %%
import pandas as pd
import numpy as np
from quantfreedom.utils import clear_cache
from quantfreedom.backtester.indicators.talib_ind import from_talib
from quantfreedom.backtester.evaluators.evaluators import eval_is_below, eval_is_above, combine_evals
prices = pd.read_csv('30min.csv', index_col='time')

# %%
rsi_ind = from_talib(
    func_name='rsi',
    df_prices=prices,
    cart_product=False,
    combos=False,
    timeperiod=[15, 30],
)
rsi_ind
# Out:
# RSI_timeperiod              15         30
# time
# 2020-10-01 00:00:00        NaN        NaN
# 2020-10-01 00:30:00        NaN        NaN
# 2020-10-01 01:00:00        NaN        NaN
# 2020-10-01 01:30:00        NaN        NaN
# 2020-10-01 02:00:00        NaN        NaN
# ...                        ...        ...
# 2021-02-22 21:30:00  55.516071  49.668702
# 2021-02-22 22:00:00  51.496913  47.611461
# 2021-02-22 22:30:00  49.684656  46.671107
# 2021-02-22 23:00:00  45.834489  44.639194
# 2021-02-22 23:30:00  49.724145  46.868962
#
# [6960 rows x 2 columns]

# %%
rsi_eval = eval_is_below(
    rsi_ind,
    np.arange(30, 51, 10),
)

# %%
ema_ind = from_talib(
    func_name='ema',
    df_prices=prices,
    cart_product=False,
    combos=False,
    timeperiod=[200, 400, 600]
)

# %%
ema_eval = eval_is_above(
    ind_data=ema_ind,
    df_prices=prices,
    cand_ohlc='close',
)

# %%
combine_evals(
    bigger_df=rsi_eval,
    smaller_df=ema_eval,
)
# Out:
# RSI_timeperiod          15                                                   \
# RSI_is_below            30                   40                   50
# EMA_timeperiod         200    400    600    200    400    600    200    400
# EMA_is_above         close  close  close  close  close  close  close  close
# time
# 2020-10-01 00:00:00  False  False  False  False  False  False  False  False
# 2020-10-01 00:30:00  False  False  False  False  False  False  False  False
# 2020-10-01 01:00:00  False  False  False  False  False  False  False  False
# 2020-10-01 01:30:00  False  False  False  False  False  False  False  False
# 2020-10-01 02:00:00  False  False  False  False  False  False  False  False
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2021-02-22 21:30:00  False  False  False  False  False  False  False  False
# 2021-02-22 22:00:00  False  False  False  False  False  False   True  False
# 2021-02-22 22:30:00  False  False  False  False  False  False   True  False
# 2021-02-22 23:00:00  False  False  False  False  False  False   True  False
# 2021-02-22 23:30:00  False  False  False  False  False  False   True  False
#
# RSI_timeperiod                 30                                            \
# RSI_is_below                   30                   40                   50
# EMA_timeperiod         600    200    400    600    200    400    600    200
# EMA_is_above         close  close  close  close  close  close  close  close
# time
# 2020-10-01 00:00:00  False  False  False  False  False  False  False  False
# 2020-10-01 00:30:00  False  False  False  False  False  False  False  False
# 2020-10-01 01:00:00  False  False  False  False  False  False  False  False
# 2020-10-01 01:30:00  False  False  False  False  False  False  False  False
# 2020-10-01 02:00:00  False  False  False  False  False  False  False  False
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2021-02-22 21:30:00  False  False  False  False  False  False  False  False
# 2021-02-22 22:00:00  False  False  False  False  False  False  False  False
# 2021-02-22 22:30:00  False  False  False  False  False  False  False  False
# 2021-02-22 23:00:00  False  False  False  False  False  False  False  False
# 2021-02-22 23:30:00  False  False  False  False  False  False  False  False
#
# RSI_timeperiod
# RSI_is_below
# EMA_timeperiod         400    600
# EMA_is_above         close  close
# time
# 2020-10-01 00:00:00  False  False
# 2020-10-01 00:30:00  False  False
# 2020-10-01 01:00:00  False  False
# 2020-10-01 01:30:00  False  False
# 2020-10-01 02:00:00  False  False
# ...                    ...    ...
# 2021-02-22 21:30:00  False  False
# 2021-02-22 22:00:00  False  False
# 2021-02-22 22:30:00  False  False
# 2021-02-22 23:00:00  False  False
# 2021-02-22 23:30:00  False  False
#
# [6960 rows x 18 columns]
