# %%
import os
# import sys

# sys.dont_write_bytecode = True
# os.environ["NUMBA_DISABLE_JIT"] = "1"
os.environ["NUMBA_DEBUG"] = "1"
os.environ["NUMBA_DEBUGINFO"] = "1"
os.environ["NUMBA_DEBUG_TYPEINFER"] = "1"

import numpy as np
import pandas as pd
from quantfreedom.base.strategy_maker_cls import StrategyMaker
from quantfreedom.enums.enums import (
    CandleBody,
    LeverageMode,
    OrderType,
    SizeType,
    OrderSettingsArrays,
    StaticVariables,
)

np.set_printoptions(formatter={"float_kind": "{:.2f}".format})
pd.options.display.float_format = "{:,.2f}".format

# prices = data_download_from_ccxt(
#     exchange='bybit',
#     start='2020-10-01T00:00:00Z',
#     end='2021-04-15T00:00:00Z',
#     symbols=['BTCUSDT', 'ETHUSD'],
#     timeframe='30m',
# )
sm = StrategyMaker()
price_data = pd.read_hdf("../tests/data/prices.hd5")
rsi_ind = sm.from_talib(
    func_name="rsi",
    price_data=price_data,
    cart_product=False,
    combos=False,
    timeperiod=[15, 30],
)
entries = rsi_ind.is_below(
    user_args=[40, 50],
    candle_ohlc="close",
)
entries = sm.combined_data_frame()
# Out:
# ================================================================================
# --------------------------FUNCTION OPTIMIZED DUMP nrt---------------------------
# ; ModuleID = 'nrt'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# @.const.picklebuf.1249260741632 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([102 x i8], [102 x i8]* @.const.pickledata.1249260741632, i32 0, i32 0), i32 102, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.1249260741632.sha1, i32 0, i32 0) }
# @.const.pickledata.1249260741632 = internal constant [102 x i8] c"\80\04\95[\00\00\00\00\00\00\00\8C\08builtins\94\8C\0CRuntimeError\94\93\94\8C6numba jitted function aborted due to unresolved symbol\94\85\94N\87\94."
# @.const.pickledata.1249260741632.sha1 = internal constant [20 x i8] c"\97\BE\DC\DF\EC\8E\80\B7\09>P\CE%\EDV\F7r\0E\0C\9C"
#
# define i64 @nrt_atomic_add(i64* %.1) {
# .3:
#   %.4 = atomicrmw add i64* %.1, i64 1 monotonic
#   %.5 = add i64 %.4, 1
#   ret i64 %.5
# }
#
# define i64 @nrt_atomic_sub(i64* %.1) {
# .3:
#   %.4 = atomicrmw sub i64* %.1, i64 1 monotonic
#   %.5 = sub i64 %.4, 1
#   ret i64 %.5
# }
#
# define i32 @nrt_atomic_cas(i64* %.1, i64 %.2, i64 %.3, i64* %.4) {
# .6:
#   %.7 = cmpxchg i64* %.1, i64 %.2, i64 %.3 monotonic monotonic
#   %.8 = extractvalue { i64, i1 } %.7, 0
#   %.9 = extractvalue { i64, i1 } %.7, 1
#   store i64 %.8, i64* %.4, align 8
#   %.11 = zext i1 %.9 to i32
#   ret i32 %.11
# }
#
# define i8* @NRT_MemInfo_data_fast(i8* %.1) {
# .3:
#   %.4 = bitcast i8* %.1 to { i64, i8*, i8*, i8*, i64 }*
#   %.5 = getelementptr { i64, i8*, i8*, i8*, i64 }, { i64, i8*, i8*, i8*, i64 }* %.4, i32 0, i32 3
#   %.6 = load i8*, i8** %.5, align 8
#   ret i8* %.6
# }
#
# ; Function Attrs: noinline
# define void @NRT_incref(i8* %.1) #0 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   %.7 = bitcast i8* %.1 to i64*
#   %.8 = call i64 @nrt_atomic_add(i64* %.7)
#   ret void
# }
#
# ; Function Attrs: noinline
# define void @NRT_decref(i8* %.1) #0 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3.endif, %.3.endif.if, %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.9 = call i64 @nrt_atomic_sub(i64* %.8)
#   %.10 = icmp eq i64 %.9, 0
#   br i1 %.10, label %.3.endif.if, label %.3.if, !prof !0
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   call void @NRT_MemInfo_call_dtor(i8* %.1)
#   br label %.3.if
# }
#
# declare void @NRT_MemInfo_call_dtor(i8*)
#
# define i32 @nrt_unresolved_abort(i8** %.1, { i8*, i32, i8* }** %.2) {
# .4:
#   store { i8*, i32, i8* }* @.const.picklebuf.1249260741632, { i8*, i32, i8* }** %.2, align 8
#   ret i32 1, !ret_is_raise !1
# }
#
# attributes #0 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{i1 true}
#
# ================================================================================
# ================================================================================
# -------------------------------OPTIMIZED DUMP nrt-------------------------------
# ; ModuleID = 'nrt'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# @.const.picklebuf.1249260741632 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([102 x i8], [102 x i8]* @.const.pickledata.1249260741632, i32 0, i32 0), i32 102, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.1249260741632.sha1, i32 0, i32 0) }
# @.const.pickledata.1249260741632 = internal constant [102 x i8] c"\80\04\95[\00\00\00\00\00\00\00\8C\08builtins\94\8C\0CRuntimeError\94\93\94\8C6numba jitted function aborted due to unresolved symbol\94\85\94N\87\94."
# @.const.pickledata.1249260741632.sha1 = internal constant [20 x i8] c"\97\BE\DC\DF\EC\8E\80\B7\09>P\CE%\EDV\F7r\0E\0C\9C"
#
# ; Function Attrs: nofree norecurse nounwind
# define i64 @nrt_atomic_add(i64* nocapture %.1) local_unnamed_addr #0 {
# .3:
#   %.4 = atomicrmw add i64* %.1, i64 1 monotonic
#   %.5 = add i64 %.4, 1
#   ret i64 %.5
# }
#
# ; Function Attrs: nofree norecurse nounwind
# define i64 @nrt_atomic_sub(i64* nocapture %.1) local_unnamed_addr #0 {
# .3:
#   %.4 = atomicrmw sub i64* %.1, i64 1 monotonic
#   %.5 = add i64 %.4, -1
#   ret i64 %.5
# }
#
# ; Function Attrs: nofree norecurse nounwind
# define i32 @nrt_atomic_cas(i64* nocapture %.1, i64 %.2, i64 %.3, i64* nocapture %.4) local_unnamed_addr #0 {
# .6:
#   %.7 = cmpxchg i64* %.1, i64 %.2, i64 %.3 monotonic monotonic
#   %.8 = extractvalue { i64, i1 } %.7, 0
#   %.9 = extractvalue { i64, i1 } %.7, 1
#   store i64 %.8, i64* %.4, align 8
#   %.11 = zext i1 %.9 to i32
#   ret i32 %.11
# }
#
# ; Function Attrs: norecurse nounwind readonly
# define i8* @NRT_MemInfo_data_fast(i8* nocapture readonly %.1) local_unnamed_addr #1 {
# .3:
#   %.5 = getelementptr i8, i8* %.1, i64 24
#   %0 = bitcast i8* %.5 to i8**
#   %.6 = load i8*, i8** %0, align 8
#   ret i8* %.6
# }
#
# ; Function Attrs: nofree noinline norecurse nounwind
# define void @NRT_incref(i8* %.1) local_unnamed_addr #2 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   %.7 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw add i64* %.7, i64 1 monotonic
#   ret void
# }
#
# ; Function Attrs: noinline
# define void @NRT_decref(i8* %.1) local_unnamed_addr #3 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3.endif, %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw sub i64* %.8, i64 1 monotonic
#   %.10 = icmp eq i64 %.4.i, 1
#   br i1 %.10, label %.3.endif.if, label %.3.if, !prof !0
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   tail call void @NRT_MemInfo_call_dtor(i8* nonnull %.1)
#   ret void
# }
#
# declare void @NRT_MemInfo_call_dtor(i8*) local_unnamed_addr
#
# ; Function Attrs: nofree norecurse nounwind writeonly
# define i32 @nrt_unresolved_abort(i8** nocapture readnone %.1, { i8*, i32, i8* }** nocapture %.2) local_unnamed_addr #4 {
# .4:
#   store { i8*, i32, i8* }* @.const.picklebuf.1249260741632, { i8*, i32, i8* }** %.2, align 8
#   ret i32 1, !ret_is_raise !1
# }
#
# ; Function Attrs: nounwind
# declare void @llvm.stackprotector(i8*, i8**) #5
#
# attributes #0 = { nofree norecurse nounwind }
# attributes #1 = { norecurse nounwind readonly }
# attributes #2 = { nofree noinline norecurse nounwind }
# attributes #3 = { noinline }
# attributes #4 = { nofree norecurse nounwind writeonly }
# attributes #5 = { nounwind }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{i1 true}
#
# ================================================================================
# ================================================================================
# ----------------------------------ASSEMBLY nrt----------------------------------
# 	.text
# 	.file	"<string>"
# 	.globl	nrt_atomic_add
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_add,@function
# nrt_atomic_add:
# 	movl	$1, %eax
# 	lock		xaddq	%rax, (%rcx)
# 	incq	%rax
# 	retq
# .Lfunc_end0:
# 	.size	nrt_atomic_add, .Lfunc_end0-nrt_atomic_add
#
# 	.globl	nrt_atomic_sub
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_sub,@function
# nrt_atomic_sub:
# 	movq	$-1, %rax
# 	lock		xaddq	%rax, (%rcx)
# 	decq	%rax
# 	retq
# .Lfunc_end1:
# 	.size	nrt_atomic_sub, .Lfunc_end1-nrt_atomic_sub
#
# 	.globl	nrt_atomic_cas
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_cas,@function
# nrt_atomic_cas:
# 	movq	%rdx, %rax
# 	xorl	%edx, %edx
# 	lock		cmpxchgq	%r8, (%rcx)
# 	sete	%dl
# 	movq	%rax, (%r9)
# 	movl	%edx, %eax
# 	retq
# .Lfunc_end2:
# 	.size	nrt_atomic_cas, .Lfunc_end2-nrt_atomic_cas
#
# 	.globl	NRT_MemInfo_data_fast
# 	.p2align	4, 0x90
# 	.type	NRT_MemInfo_data_fast,@function
# NRT_MemInfo_data_fast:
# 	movq	24(%rcx), %rax
# 	retq
# .Lfunc_end3:
# 	.size	NRT_MemInfo_data_fast, .Lfunc_end3-NRT_MemInfo_data_fast
#
# 	.globl	NRT_incref
# 	.p2align	4, 0x90
# 	.type	NRT_incref,@function
# NRT_incref:
# 	testq	%rcx, %rcx
# 	je	.LBB4_1
# 	lock		incq	(%rcx)
# 	retq
# .LBB4_1:
# 	retq
# .Lfunc_end4:
# 	.size	NRT_incref, .Lfunc_end4-NRT_incref
#
# 	.globl	NRT_decref
# 	.p2align	4, 0x90
# 	.type	NRT_decref,@function
# NRT_decref:
# 	.cfi_startproc
# 	testq	%rcx, %rcx
# 	je	.LBB5_2
# 	#MEMBARRIER
# 	lock		decq	(%rcx)
# 	je	.LBB5_3
# .LBB5_2:
# 	retq
# .LBB5_3:
# 	#MEMBARRIER
# 	movabsq	$NRT_MemInfo_call_dtor, %rax
# 	rex64 jmpq	*%rax
# .Lfunc_end5:
# 	.size	NRT_decref, .Lfunc_end5-NRT_decref
# 	.cfi_endproc
#
# 	.globl	nrt_unresolved_abort
# 	.p2align	4, 0x90
# 	.type	nrt_unresolved_abort,@function
# nrt_unresolved_abort:
# 	movabsq	$.const.picklebuf.1249260741632, %rax
# 	movq	%rax, (%rdx)
# 	movl	$1, %eax
# 	retq
# .Lfunc_end6:
# 	.size	nrt_unresolved_abort, .Lfunc_end6-nrt_unresolved_abort
#
# 	.type	.const.picklebuf.1249260741632,@object
# 	.section	.rodata,"a",@progbits
# 	.p2align	4
# .const.picklebuf.1249260741632:
# 	.quad	.const.pickledata.1249260741632
# 	.long	102
# 	.zero	4
# 	.quad	.const.pickledata.1249260741632.sha1
# 	.size	.const.picklebuf.1249260741632, 24
#
# 	.type	.const.pickledata.1249260741632,@object
# 	.p2align	4
# .const.pickledata.1249260741632:
# 	.ascii	"\200\004\225[\000\000\000\000\000\000\000\214\bbuiltins\224\214\fRuntimeError\224\223\224\2146numba jitted function aborted due to unresolved symbol\224\205\224N\207\224."
# 	.size	.const.pickledata.1249260741632, 102
#
# 	.type	.const.pickledata.1249260741632.sha1,@object
# 	.p2align	4
# .const.pickledata.1249260741632.sha1:
# 	.ascii	"\227\276\334\337\354\216\200\267\t>P\316%\355V\367r\016\f\234"
# 	.size	.const.pickledata.1249260741632.sha1, 20
#
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================

# %%
static_vars = StaticVariables(
    equity=1000.,
    lev_mode=LeverageMode.LeastFreeCashUsed,
    order_type=OrderType.LongEntry,
    size_type=SizeType.RiskPercentOfAccount,
)
order_settings = OrderSettingsArrays(
    max_equity_risk_pct=6.,
    risk_reward=5,
    size_pct=1.,
    sl_based_on=CandleBody.low,
    sl_based_on_lookback=30,
    sl_based_on_add_pct=.2,
)

# %%
strat_results_df, settings_results_df = sm.backtest_df(
    price_data=price_data,
    static_variables_tuple=static_vars,
    order_settings_arrays_tuple=order_settings,
)
# Out:
# Checking static variables for errors or conflicts.
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.static_var_checker_nb-18.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.static_var_checker_nb-18.py310.1.nbc'
# ================================================================================
# ----------------------OPTIMIZED DUMP static_var_checker_nb----------------------
# ; ModuleID = 'static_var_checker_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# -------------------------ASSEMBLY static_var_checker_nb-------------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Turning all variables into arrays.
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.all_os_as_1d_arrays_nb-112.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.all_os_as_1d_arrays_nb-112.py310.1.nbc'
# ================================================================================
# ---------------------OPTIMIZED DUMP all_os_as_1d_arrays_nb----------------------
# ; ModuleID = 'all_os_as_1d_arrays_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# ------------------------ASSEMBLY all_os_as_1d_arrays_nb-------------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Checking arrays for errors or conflicts ... the backtest will begin shortly, please hold.
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.check_os_1d_arrays_nb-232.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.check_os_1d_arrays_nb-232.py310.1.nbc'
# ================================================================================
# ----------------------OPTIMIZED DUMP check_os_1d_arrays_nb----------------------
# ; ModuleID = 'check_os_1d_arrays_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# -------------------------ASSEMBLY check_os_1d_arrays_nb-------------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Creating cartesian product ... after this the backtest will start, I promise :).
#
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.create_os_cart_product_nb-490.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.create_os_cart_product_nb-490.py310.1.nbc'
# ================================================================================
# --------------------OPTIMIZED DUMP create_os_cart_product_nb--------------------
# ; ModuleID = 'create_os_cart_product_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# -----------------------ASSEMBLY create_os_cart_product_nb-----------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Starting the backtest now ... and also here are some stats for your backtest.
#
# Total symbols: 5
# Total indicator settings per symbol: 4
# Total indicator settings to test: 20
# Total order settings per symbol: 1
# Total order settings to test: 5
# Total candles per symbol: 9,408
# Total candles to test: 188,160
#
# Total combinations to test: 20
# --------------------------IR DUMP: backtest_df_only_nb--------------------------
# label 0:
#     num_of_symbols = arg(0, name=num_of_symbols) ['num_of_symbols']
#     total_indicator_settings = arg(1, name=total_indicator_settings) ['total_indicator_settings']
#     total_order_settings = arg(2, name=total_order_settings) ['total_order_settings']
#     total_bars = arg(3, name=total_bars)     ['total_bars']
#     entries = arg(4, name=entries)           ['entries']
#     price_data = arg(5, name=price_data)     ['price_data']
#     static_variables_tuple = arg(6, name=static_variables_tuple) ['static_variables_tuple']
#     os_cart_arrays_tuple = arg(7, name=os_cart_arrays_tuple) ['os_cart_arrays_tuple']
#     $2load_global.0 = global(int: <class 'int'>) ['$2load_global.0']
#     $8binary_multiply.3 = num_of_symbols * total_indicator_settings ['$8binary_multiply.3', 'num_of_symbols', 'total_indicator_settings']
#     $12binary_multiply.5 = $8binary_multiply.3 * total_order_settings ['$12binary_multiply.5', '$8binary_multiply.3', 'total_order_settings']
#     $16load_attr.7 = getattr(value=static_variables_tuple, attr=divide_records_array_size_by) ['$16load_attr.7', 'static_variables_tuple']
#     $18binary_true_divide.8 = $12binary_multiply.5 / $16load_attr.7 ['$12binary_multiply.5', '$16load_attr.7', '$18binary_true_divide.8']
#     array_size = call $2load_global.0($18binary_true_divide.8, func=$2load_global.0, args=[Var($18binary_true_divide.8, simulate.py:43)], kws=(), vararg=None, varkwarg=None, target=None) ['$18binary_true_divide.8', '$2load_global.0', 'array_size']
#     $24load_global.10 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$24load_global.10']
#     $26load_attr.11 = getattr(value=$24load_global.10, attr=empty) ['$24load_global.10', '$26load_attr.11']
#     $30load_global.13 = global(strat_df_array_dt: {'names': ['symbol', 'entries_col', 'or_set', 'total_trades', 'gains_pct', 'win_rate', 'to_the_upside', 'total_pnl', 'ending_eq'], 'formats': ['<i4', '<i4', '<i4', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8'], 'offsets': [0, 4, 8, 16, 24, 32, 40, 48, 56], 'itemsize': 64, 'aligned': True}) ['$30load_global.13']
#     strategy_result_records = call $26load_attr.11(array_size, func=$26load_attr.11, args=[Var(array_size, simulate.py:42)], kws=[('dtype', Var($30load_global.13, simulate.py:51))], vararg=None, varkwarg=None, target=None) ['$26load_attr.11', '$30load_global.13', 'array_size', 'strategy_result_records']
#     $38load_global.16 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$38load_global.16']
#     $40load_attr.17 = getattr(value=$38load_global.16, attr=empty) ['$38load_global.16', '$40load_attr.17']
#     $44load_global.19 = global(order_settings_array_dt: {'names': ['symbol', 'entries_col', 'leverage', 'max_equity_risk_pct', 'max_equity_risk_value', 'risk_reward', 'size_pct', 'size_value', 'sl_based_on', 'sl_based_on_add_pct', 'sl_based_on_lookback', 'sl_pct', 'sl_to_be_based_on', 'sl_to_be_when_pct_from_avg_entry', 'sl_to_be_zero_or_entry', 'tp_pct', 'trail_sl_based_on', 'trail_sl_by_pct', 'trail_sl_when_pct_from_avg_entry'], 'formats': ['<i4', '<i4', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8'], 'offsets': [0, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136], 'itemsize': 144, 'aligned': True}) ['$44load_global.19']
#     order_settings_result_records = call $40load_attr.17(array_size, func=$40load_attr.17, args=[Var(array_size, simulate.py:42)], kws=[('dtype', Var($44load_global.19, simulate.py:55))], vararg=None, varkwarg=None, target=None) ['$40load_attr.17', '$44load_global.19', 'array_size', 'order_settings_result_records']
#     result_records_filled = const(int, 0)    ['result_records_filled']
#     $56load_global.23 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$56load_global.23']
#     $58load_attr.24 = getattr(value=$56load_global.23, attr=empty) ['$56load_global.23', '$58load_attr.24']
#     $60load_global.25 = global(int: <class 'int'>) ['$60load_global.25']
#     $const64.27 = const(int, 3)              ['$const64.27']
#     $66binary_true_divide.28 = total_bars / $const64.27 ['$66binary_true_divide.28', '$const64.27', 'total_bars']
#     $68call_function.29 = call $60load_global.25($66binary_true_divide.28, func=$60load_global.25, args=[Var($66binary_true_divide.28, simulate.py:59)], kws=(), vararg=None, varkwarg=None, target=None) ['$60load_global.25', '$66binary_true_divide.28', '$68call_function.29']
#     $70load_global.30 = global(strat_records_dt: {'names': ['symbol', 'entries_col', 'or_set', 'real_pnl', 'equity'], 'formats': ['<i4', '<i4', '<i4', '<f8', '<f8'], 'offsets': [0, 4, 8, 16, 24], 'itemsize': 32, 'aligned': True}) ['$70load_global.30']
#     strat_records = call $58load_attr.24($68call_function.29, func=$58load_attr.24, args=[Var($68call_function.29, simulate.py:59)], kws=[('dtype', Var($70load_global.30, simulate.py:59))], vararg=None, varkwarg=None, target=None) ['$58load_attr.24', '$68call_function.29', '$70load_global.30', 'strat_records']
#     $78load_global.33 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$78load_global.33']
#     $80load_method.34 = getattr(value=$78load_global.33, attr=array) ['$78load_global.33', '$80load_method.34']
#     $const82.35 = const(int, 0)              ['$const82.35']
#     $84build_list.36 = build_list(items=[Var($const82.35, simulate.py:60)]) ['$84build_list.36', '$const82.35']
#     strat_records_filled = call $80load_method.34($84build_list.36, func=$80load_method.34, args=[Var($84build_list.36, simulate.py:60)], kws=(), vararg=None, varkwarg=None, target=None) ['$80load_method.34', '$84build_list.36', 'strat_records_filled']
#     prices_start = const(int, 0)             ['prices_start']
#     $94load_global.39 = global(int: <class 'int'>) ['$94load_global.39']
#     $98load_attr.41 = getattr(value=entries, attr=shape) ['$98load_attr.41', 'entries']
#     $const100.42 = const(int, 1)             ['$const100.42']
#     $102binary_subscr.43 = getitem(value=$98load_attr.41, index=$const100.42, fn=<built-in function getitem>) ['$102binary_subscr.43', '$98load_attr.41', '$const100.42']
#     $106binary_true_divide.45 = $102binary_subscr.43 / num_of_symbols ['$102binary_subscr.43', '$106binary_true_divide.45', 'num_of_symbols']
#     entries_per_symbol = call $94load_global.39($106binary_true_divide.45, func=$94load_global.39, args=[Var($106binary_true_divide.45, simulate.py:63)], kws=(), vararg=None, varkwarg=None, target=None) ['$106binary_true_divide.45', '$94load_global.39', 'entries_per_symbol']
#     entries_start = const(int, 0)            ['entries_start']
#     entries_end = entries_per_symbol         ['entries_end', 'entries_per_symbol']
#     entries_col = const(int, 0)              ['entries_col']
#     $124load_global.50 = global(range: <class 'range'>) ['$124load_global.50']
#     $128call_function.52 = call $124load_global.50(num_of_symbols, func=$124load_global.50, args=[Var(num_of_symbols, simulate.py:42)], kws=(), vararg=None, varkwarg=None, target=None) ['$124load_global.50', '$128call_function.52', 'num_of_symbols']
#     $130get_iter.53 = getiter(value=$128call_function.52) ['$128call_function.52', '$130get_iter.53']
#     $phi132.0 = $130get_iter.53              ['$130get_iter.53', '$phi132.0']
#     jump 132                                 []
# label 132:
#     $132for_iter.1 = iternext(value=$phi132.0) ['$132for_iter.1', '$phi132.0']
#     $132for_iter.2 = pair_first(value=$132for_iter.1) ['$132for_iter.1', '$132for_iter.2']
#     $132for_iter.3 = pair_second(value=$132for_iter.1) ['$132for_iter.1', '$132for_iter.3']
#     $phi136.1 = $132for_iter.2               ['$132for_iter.2', '$phi136.1']
#     branch $132for_iter.3, 136, 1288         ['$132for_iter.3']
# label 136:
#     symbol_counter = $phi136.1               ['$phi136.1', 'symbol_counter']
#     $const140.3 = const(NoneType, None)      ['$const140.3']
#     $const142.4 = const(NoneType, None)      ['$const142.4']
#     $144build_slice.5 = global(slice: <class 'slice'>) ['$144build_slice.5']
#     $144build_slice.6 = call $144build_slice.5($const140.3, $const142.4, func=$144build_slice.5, args=(Var($const140.3, simulate.py:69), Var($const142.4, simulate.py:69)), kws=(), vararg=None, varkwarg=None, target=None) ['$144build_slice.5', '$144build_slice.6', '$const140.3', '$const142.4']
#     $148build_tuple.8 = build_tuple(items=[Var($144build_slice.6, simulate.py:69), Var(prices_start, simulate.py:62)]) ['$144build_slice.6', '$148build_tuple.8', 'prices_start']
#     open_prices = getitem(value=price_data, index=$148build_tuple.8, fn=<built-in function getitem>) ['$148build_tuple.8', 'open_prices', 'price_data']
#     $const156.11 = const(NoneType, None)     ['$const156.11']
#     $const158.12 = const(NoneType, None)     ['$const158.12']
#     $160build_slice.13 = global(slice: <class 'slice'>) ['$160build_slice.13']
#     $160build_slice.14 = call $160build_slice.13($const156.11, $const158.12, func=$160build_slice.13, args=(Var($const156.11, simulate.py:70), Var($const158.12, simulate.py:70)), kws=(), vararg=None, varkwarg=None, target=None) ['$160build_slice.13', '$160build_slice.14', '$const156.11', '$const158.12']
#     $const164.16 = const(int, 1)             ['$const164.16']
#     $166binary_add.17 = prices_start + $const164.16 ['$166binary_add.17', '$const164.16', 'prices_start']
#     $168build_tuple.18 = build_tuple(items=[Var($160build_slice.14, simulate.py:70), Var($166binary_add.17, simulate.py:70)]) ['$160build_slice.14', '$166binary_add.17', '$168build_tuple.18']
#     high_prices = getitem(value=price_data, index=$168build_tuple.18, fn=<built-in function getitem>) ['$168build_tuple.18', 'high_prices', 'price_data']
#     $const176.21 = const(NoneType, None)     ['$const176.21']
#     $const178.22 = const(NoneType, None)     ['$const178.22']
#     $180build_slice.23 = global(slice: <class 'slice'>) ['$180build_slice.23']
#     $180build_slice.24 = call $180build_slice.23($const176.21, $const178.22, func=$180build_slice.23, args=(Var($const176.21, simulate.py:71), Var($const178.22, simulate.py:71)), kws=(), vararg=None, varkwarg=None, target=None) ['$180build_slice.23', '$180build_slice.24', '$const176.21', '$const178.22']
#     $const184.26 = const(int, 2)             ['$const184.26']
#     $186binary_add.27 = prices_start + $const184.26 ['$186binary_add.27', '$const184.26', 'prices_start']
#     $188build_tuple.28 = build_tuple(items=[Var($180build_slice.24, simulate.py:71), Var($186binary_add.27, simulate.py:71)]) ['$180build_slice.24', '$186binary_add.27', '$188build_tuple.28']
#     low_prices = getitem(value=price_data, index=$188build_tuple.28, fn=<built-in function getitem>) ['$188build_tuple.28', 'low_prices', 'price_data']
#     $const196.31 = const(NoneType, None)     ['$const196.31']
#     $const198.32 = const(NoneType, None)     ['$const198.32']
#     $200build_slice.33 = global(slice: <class 'slice'>) ['$200build_slice.33']
#     $200build_slice.34 = call $200build_slice.33($const196.31, $const198.32, func=$200build_slice.33, args=(Var($const196.31, simulate.py:72), Var($const198.32, simulate.py:72)), kws=(), vararg=None, varkwarg=None, target=None) ['$200build_slice.33', '$200build_slice.34', '$const196.31', '$const198.32']
#     $const204.36 = const(int, 3)             ['$const204.36']
#     $206binary_add.37 = prices_start + $const204.36 ['$206binary_add.37', '$const204.36', 'prices_start']
#     $208build_tuple.38 = build_tuple(items=[Var($200build_slice.34, simulate.py:72), Var($206binary_add.37, simulate.py:72)]) ['$200build_slice.34', '$206binary_add.37', '$208build_tuple.38']
#     close_prices = getitem(value=price_data, index=$208build_tuple.38, fn=<built-in function getitem>) ['$208build_tuple.38', 'close_prices', 'price_data']
#     $const216.41 = const(int, 4)             ['$const216.41']
#     $218inplace_add.42 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=prices_start, rhs=$const216.41, static_lhs=Undefined, static_rhs=Undefined) ['$218inplace_add.42', '$const216.41', 'prices_start']
#     prices_start = $218inplace_add.42        ['$218inplace_add.42', 'prices_start']
#     $const224.44 = const(NoneType, None)     ['$const224.44']
#     $const226.45 = const(NoneType, None)     ['$const226.45']
#     $228build_slice.46 = global(slice: <class 'slice'>) ['$228build_slice.46']
#     $228build_slice.47 = call $228build_slice.46($const224.44, $const226.45, func=$228build_slice.46, args=(Var($const224.44, simulate.py:76), Var($const226.45, simulate.py:76)), kws=(), vararg=None, varkwarg=None, target=None) ['$228build_slice.46', '$228build_slice.47', '$const224.44', '$const226.45']
#     $234build_slice.50 = global(slice: <class 'slice'>) ['$234build_slice.50']
#     $234build_slice.51 = call $234build_slice.50(entries_start, entries_end, func=$234build_slice.50, args=(Var(entries_start, simulate.py:64), Var(entries_end, simulate.py:65)), kws=(), vararg=None, varkwarg=None, target=None) ['$234build_slice.50', '$234build_slice.51', 'entries_end', 'entries_start']
#     $236build_tuple.52 = build_tuple(items=[Var($228build_slice.47, simulate.py:76), Var($234build_slice.51, simulate.py:76)]) ['$228build_slice.47', '$234build_slice.51', '$236build_tuple.52']
#     symbol_entries = getitem(value=entries, index=$236build_tuple.52, fn=<built-in function getitem>) ['$236build_tuple.52', 'entries', 'symbol_entries']
#     entries_start = entries_end              ['entries_end', 'entries_start']
#     $250inplace_add.57 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=entries_end, rhs=entries_per_symbol, static_lhs=Undefined, static_rhs=Undefined) ['$250inplace_add.57', 'entries_end', 'entries_per_symbol']
#     entries_end = $250inplace_add.57         ['$250inplace_add.57', 'entries_end']
#     $254load_global.58 = global(range: <class 'range'>) ['$254load_global.58']
#     $258call_function.60 = call $254load_global.58(entries_per_symbol, func=$254load_global.58, args=[Var(entries_per_symbol, simulate.py:63)], kws=(), vararg=None, varkwarg=None, target=None) ['$254load_global.58', '$258call_function.60', 'entries_per_symbol']
#     $260get_iter.61 = getiter(value=$258call_function.60) ['$258call_function.60', '$260get_iter.61']
#     $phi262.1 = $260get_iter.61              ['$260get_iter.61', '$phi262.1']
#     jump 262                                 []
# label 262:
#     $262for_iter.2 = iternext(value=$phi262.1) ['$262for_iter.2', '$phi262.1']
#     $262for_iter.3 = pair_first(value=$262for_iter.2) ['$262for_iter.2', '$262for_iter.3']
#     $262for_iter.4 = pair_second(value=$262for_iter.2) ['$262for_iter.2', '$262for_iter.4']
#     $phi266.2 = $262for_iter.3               ['$262for_iter.3', '$phi266.2']
#     branch $262for_iter.4, 266, 1286         ['$262for_iter.4']
# label 266:
#     indicator_settings_counter = $phi266.2   ['$phi266.2', 'indicator_settings_counter']
#     $const270.4 = const(NoneType, None)      ['$const270.4']
#     $const272.5 = const(NoneType, None)      ['$const272.5']
#     $274build_slice.6 = global(slice: <class 'slice'>) ['$274build_slice.6']
#     $274build_slice.7 = call $274build_slice.6($const270.4, $const272.5, func=$274build_slice.6, args=(Var($const270.4, simulate.py:82), Var($const272.5, simulate.py:82)), kws=(), vararg=None, varkwarg=None, target=None) ['$274build_slice.6', '$274build_slice.7', '$const270.4', '$const272.5']
#     $278build_tuple.9 = build_tuple(items=[Var($274build_slice.7, simulate.py:82), Var(indicator_settings_counter, simulate.py:81)]) ['$274build_slice.7', '$278build_tuple.9', 'indicator_settings_counter']
#     current_indicator_entries = getitem(value=symbol_entries, index=$278build_tuple.9, fn=<built-in function getitem>) ['$278build_tuple.9', 'current_indicator_entries', 'symbol_entries']
#     $284load_global.11 = global(range: <class 'range'>) ['$284load_global.11']
#     $288call_function.13 = call $284load_global.11(total_order_settings, func=$284load_global.11, args=[Var(total_order_settings, simulate.py:42)], kws=(), vararg=None, varkwarg=None, target=None) ['$284load_global.11', '$288call_function.13', 'total_order_settings']
#     $290get_iter.14 = getiter(value=$288call_function.13) ['$288call_function.13', '$290get_iter.14']
#     $phi292.2 = $290get_iter.14              ['$290get_iter.14', '$phi292.2']
#     jump 292                                 []
# label 292:
#     $292for_iter.3 = iternext(value=$phi292.2) ['$292for_iter.3', '$phi292.2']
#     $292for_iter.4 = pair_first(value=$292for_iter.3) ['$292for_iter.3', '$292for_iter.4']
#     $292for_iter.5 = pair_second(value=$292for_iter.3) ['$292for_iter.3', '$292for_iter.5']
#     $phi296.3 = $292for_iter.4               ['$292for_iter.4', '$phi296.3']
#     branch $292for_iter.5, 296, 1276         ['$292for_iter.5']
# label 296:
#     order_settings_counter = $phi296.3       ['$phi296.3', 'order_settings_counter']
#     $298load_global.4 = global(OrderSettings: <class 'quantfreedom.enums.enums.OrderSettings'>) ['$298load_global.4']
#     $const304.7 = const(str, leverage)       ['$const304.7']
#     $308load_attr.9 = getattr(value=os_cart_arrays_tuple, attr=leverage) ['$308load_attr.9', 'os_cart_arrays_tuple']
#     $312binary_subscr.11 = getitem(value=$308load_attr.9, index=order_settings_counter, fn=<built-in function getitem>) ['$308load_attr.9', '$312binary_subscr.11', 'order_settings_counter']
#     $const316.14 = const(str, max_equity_risk_pct) ['$const316.14']
#     $320load_attr.16 = getattr(value=os_cart_arrays_tuple, attr=max_equity_risk_pct) ['$320load_attr.16', 'os_cart_arrays_tuple']
#     $324binary_subscr.18 = getitem(value=$320load_attr.16, index=order_settings_counter, fn=<built-in function getitem>) ['$320load_attr.16', '$324binary_subscr.18', 'order_settings_counter']
#     $const328.21 = const(str, max_equity_risk_value) ['$const328.21']
#     $332load_attr.23 = getattr(value=os_cart_arrays_tuple, attr=max_equity_risk_value) ['$332load_attr.23', 'os_cart_arrays_tuple']
#     $336binary_subscr.25 = getitem(value=$332load_attr.23, index=order_settings_counter, fn=<built-in function getitem>) ['$332load_attr.23', '$336binary_subscr.25', 'order_settings_counter']
#     $const340.28 = const(str, risk_reward)   ['$const340.28']
#     $344load_attr.30 = getattr(value=os_cart_arrays_tuple, attr=risk_reward) ['$344load_attr.30', 'os_cart_arrays_tuple']
#     $348binary_subscr.32 = getitem(value=$344load_attr.30, index=order_settings_counter, fn=<built-in function getitem>) ['$344load_attr.30', '$348binary_subscr.32', 'order_settings_counter']
#     $const352.35 = const(str, size_pct)      ['$const352.35']
#     $356load_attr.37 = getattr(value=os_cart_arrays_tuple, attr=size_pct) ['$356load_attr.37', 'os_cart_arrays_tuple']
#     $360binary_subscr.39 = getitem(value=$356load_attr.37, index=order_settings_counter, fn=<built-in function getitem>) ['$356load_attr.37', '$360binary_subscr.39', 'order_settings_counter']
#     $const364.42 = const(str, size_value)    ['$const364.42']
#     $368load_attr.44 = getattr(value=os_cart_arrays_tuple, attr=size_value) ['$368load_attr.44', 'os_cart_arrays_tuple']
#     $372binary_subscr.46 = getitem(value=$368load_attr.44, index=order_settings_counter, fn=<built-in function getitem>) ['$368load_attr.44', '$372binary_subscr.46', 'order_settings_counter']
#     $const376.49 = const(str, sl_based_on)   ['$const376.49']
#     $380load_attr.51 = getattr(value=os_cart_arrays_tuple, attr=sl_based_on) ['$380load_attr.51', 'os_cart_arrays_tuple']
#     $384binary_subscr.53 = getitem(value=$380load_attr.51, index=order_settings_counter, fn=<built-in function getitem>) ['$380load_attr.51', '$384binary_subscr.53', 'order_settings_counter']
#     $const388.56 = const(str, sl_based_on_add_pct) ['$const388.56']
#     $392load_attr.58 = getattr(value=os_cart_arrays_tuple, attr=sl_based_on_add_pct) ['$392load_attr.58', 'os_cart_arrays_tuple']
#     $396binary_subscr.60 = getitem(value=$392load_attr.58, index=order_settings_counter, fn=<built-in function getitem>) ['$392load_attr.58', '$396binary_subscr.60', 'order_settings_counter']
#     $const400.63 = const(str, sl_based_on_lookback) ['$const400.63']
#     $404load_attr.65 = getattr(value=os_cart_arrays_tuple, attr=sl_based_on_lookback) ['$404load_attr.65', 'os_cart_arrays_tuple']
#     $408binary_subscr.67 = getitem(value=$404load_attr.65, index=order_settings_counter, fn=<built-in function getitem>) ['$404load_attr.65', '$408binary_subscr.67', 'order_settings_counter']
#     $const412.70 = const(str, sl_pct)        ['$const412.70']
#     $416load_attr.72 = getattr(value=os_cart_arrays_tuple, attr=sl_pct) ['$416load_attr.72', 'os_cart_arrays_tuple']
#     $420binary_subscr.74 = getitem(value=$416load_attr.72, index=order_settings_counter, fn=<built-in function getitem>) ['$416load_attr.72', '$420binary_subscr.74', 'order_settings_counter']
#     $const424.77 = const(str, sl_to_be_based_on) ['$const424.77']
#     $428load_attr.79 = getattr(value=os_cart_arrays_tuple, attr=sl_to_be_based_on) ['$428load_attr.79', 'os_cart_arrays_tuple']
#     $432binary_subscr.81 = getitem(value=$428load_attr.79, index=order_settings_counter, fn=<built-in function getitem>) ['$428load_attr.79', '$432binary_subscr.81', 'order_settings_counter']
#     $const436.84 = const(str, sl_to_be_zero_or_entry) ['$const436.84']
#     $440load_attr.86 = getattr(value=os_cart_arrays_tuple, attr=sl_to_be_zero_or_entry) ['$440load_attr.86', 'os_cart_arrays_tuple']
#     $444binary_subscr.88 = getitem(value=$440load_attr.86, index=order_settings_counter, fn=<built-in function getitem>) ['$440load_attr.86', '$444binary_subscr.88', 'order_settings_counter']
#     $const448.91 = const(str, sl_to_be_when_pct_from_avg_entry) ['$const448.91']
#     $452load_attr.93 = getattr(value=os_cart_arrays_tuple, attr=sl_to_be_when_pct_from_avg_entry) ['$452load_attr.93', 'os_cart_arrays_tuple']
#     $456binary_subscr.95 = getitem(value=$452load_attr.93, index=order_settings_counter, fn=<built-in function getitem>) ['$452load_attr.93', '$456binary_subscr.95', 'order_settings_counter']
#     $const460.98 = const(str, tp_pct)        ['$const460.98']
#     $464load_attr.100 = getattr(value=os_cart_arrays_tuple, attr=tp_pct) ['$464load_attr.100', 'os_cart_arrays_tuple']
#     $468binary_subscr.102 = getitem(value=$464load_attr.100, index=order_settings_counter, fn=<built-in function getitem>) ['$464load_attr.100', '$468binary_subscr.102', 'order_settings_counter']
#     $const472.105 = const(str, trail_sl_based_on) ['$const472.105']
#     $476load_attr.107 = getattr(value=os_cart_arrays_tuple, attr=trail_sl_based_on) ['$476load_attr.107', 'os_cart_arrays_tuple']
#     $480binary_subscr.109 = getitem(value=$476load_attr.107, index=order_settings_counter, fn=<built-in function getitem>) ['$476load_attr.107', '$480binary_subscr.109', 'order_settings_counter']
#     $const484.112 = const(str, trail_sl_by_pct) ['$const484.112']
#     $488load_attr.114 = getattr(value=os_cart_arrays_tuple, attr=trail_sl_by_pct) ['$488load_attr.114', 'os_cart_arrays_tuple']
#     $492binary_subscr.116 = getitem(value=$488load_attr.114, index=order_settings_counter, fn=<built-in function getitem>) ['$488load_attr.114', '$492binary_subscr.116', 'order_settings_counter']
#     $const496.119 = const(str, trail_sl_when_pct_from_avg_entry) ['$const496.119']
#     $500load_attr.121 = getattr(value=os_cart_arrays_tuple, attr=trail_sl_when_pct_from_avg_entry) ['$500load_attr.121', 'os_cart_arrays_tuple']
#     $504binary_subscr.123 = getitem(value=$500load_attr.121, index=order_settings_counter, fn=<built-in function getitem>) ['$500load_attr.121', '$504binary_subscr.123', 'order_settings_counter']
#     order_settings = call $298load_global.4(func=$298load_global.4, args=[], kws=[('leverage', Var($312binary_subscr.11, simulate.py:86)), ('max_equity_risk_pct', Var($324binary_subscr.18, simulate.py:87)), ('max_equity_risk_value', Var($336binary_subscr.25, simulate.py:90)), ('risk_reward', Var($348binary_subscr.32, simulate.py:93)), ('size_pct', Var($360binary_subscr.39, simulate.py:96)), ('size_value', Var($372binary_subscr.46, simulate.py:97)), ('sl_based_on', Var($384binary_subscr.53, simulate.py:98)), ('sl_based_on_add_pct', Var($396binary_subscr.60, simulate.py:101)), ('sl_based_on_lookback', Var($408binary_subscr.67, simulate.py:104)), ('sl_pct', Var($420binary_subscr.74, simulate.py:107)), ('sl_to_be_based_on', Var($432binary_subscr.81, simulate.py:108)), ('sl_to_be_zero_or_entry', Var($444binary_subscr.88, simulate.py:111)), ('sl_to_be_when_pct_from_avg_entry', Var($456binary_subscr.95, simulate.py:114)), ('tp_pct', Var($468binary_subscr.102, simulate.py:117)), ('trail_sl_based_on', Var($480binary_subscr.109, simulate.py:118)), ('trail_sl_by_pct', Var($492binary_subscr.116, simulate.py:121)), ('trail_sl_when_pct_from_avg_entry', Var($504binary_subscr.123, simulate.py:124))], vararg=None, varkwarg=None, target=None) ['$298load_global.4', '$312binary_subscr.11', '$324binary_subscr.18', '$336binary_subscr.25', '$348binary_subscr.32', '$360binary_subscr.39', '$372binary_subscr.46', '$384binary_subscr.53', '$396binary_subscr.60', '$408binary_subscr.67', '$420binary_subscr.74', '$432binary_subscr.81', '$444binary_subscr.88', '$456binary_subscr.95', '$468binary_subscr.102', '$480binary_subscr.109', '$492binary_subscr.116', '$504binary_subscr.123', 'order_settings']
#     $512load_global.127 = global(AccountState: <class 'quantfreedom.enums.enums.AccountState'>) ['$512load_global.127']
#     $516load_attr.129 = getattr(value=static_variables_tuple, attr=equity) ['$516load_attr.129', 'static_variables_tuple']
#     $const518.130 = const(float, 0.0)        ['$const518.130']
#     $const520.131 = const(float, 0.0)        ['$const520.131']
#     $524load_attr.133 = getattr(value=static_variables_tuple, attr=equity) ['$524load_attr.133', 'static_variables_tuple']
#     account_state = call $512load_global.127(func=$512load_global.127, args=[], kws=[('available_balance', Var($516load_attr.129, simulate.py:130)), ('cash_borrowed', Var($const518.130, simulate.py:131)), ('cash_used', Var($const520.131, simulate.py:132)), ('equity', Var($524load_attr.133, simulate.py:133))], vararg=None, varkwarg=None, target=None) ['$512load_global.127', '$516load_attr.129', '$524load_attr.133', '$const518.130', '$const520.131', 'account_state']
#     $532load_global.136 = global(OrderResult: <class 'quantfreedom.enums.enums.OrderResult'>) ['$532load_global.136']
#     $const538.139 = const(str, average_entry) ['$const538.139']
#     $const540.140 = const(float, 0.0)        ['$const540.140']
#     $const544.143 = const(str, fees_paid)    ['$const544.143']
#     $const546.144 = const(float, 0.0)        ['$const546.144']
#     $const550.147 = const(str, leverage)     ['$const550.147']
#     $const552.148 = const(float, 0.0)        ['$const552.148']
#     $const556.151 = const(str, liq_price)    ['$const556.151']
#     $558load_global.152 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$558load_global.152']
#     $560load_attr.153 = getattr(value=$558load_global.152, attr=nan) ['$558load_global.152', '$560load_attr.153']
#     $const564.156 = const(str, moved_sl_to_be) ['$const564.156']
#     $const566.157 = const(bool, False)       ['$const566.157']
#     $const570.160 = const(str, order_status) ['$const570.160']
#     $const572.161 = const(int, 0)            ['$const572.161']
#     $const576.164 = const(str, order_status_info) ['$const576.164']
#     $const578.165 = const(int, 0)            ['$const578.165']
#     $const582.168 = const(str, order_type)   ['$const582.168']
#     $586load_attr.170 = getattr(value=static_variables_tuple, attr=order_type) ['$586load_attr.170', 'static_variables_tuple']
#     $const590.173 = const(str, pct_chg_trade) ['$const590.173']
#     $const592.174 = const(float, 0.0)        ['$const592.174']
#     $const596.177 = const(str, position)     ['$const596.177']
#     $const598.178 = const(float, 0.0)        ['$const598.178']
#     $const602.181 = const(str, price)        ['$const602.181']
#     $const604.182 = const(float, 0.0)        ['$const604.182']
#     $const608.185 = const(str, realized_pnl) ['$const608.185']
#     $const610.186 = const(float, 0.0)        ['$const610.186']
#     $const614.189 = const(str, size_value)   ['$const614.189']
#     $const616.190 = const(float, 0.0)        ['$const616.190']
#     $const620.193 = const(str, sl_pct)       ['$const620.193']
#     $const622.194 = const(float, 0.0)        ['$const622.194']
#     $const626.197 = const(str, sl_price)     ['$const626.197']
#     $const628.198 = const(float, 0.0)        ['$const628.198']
#     $const632.201 = const(str, tp_pct)       ['$const632.201']
#     $const634.202 = const(float, 0.0)        ['$const634.202']
#     $const638.205 = const(str, tp_price)     ['$const638.205']
#     $const640.206 = const(float, 0.0)        ['$const640.206']
#     order_result = call $532load_global.136(func=$532load_global.136, args=[], kws=[('average_entry', Var($const540.140, simulate.py:138)), ('fees_paid', Var($const546.144, simulate.py:139)), ('leverage', Var($const552.148, simulate.py:140)), ('liq_price', Var($560load_attr.153, simulate.py:141)), ('moved_sl_to_be', Var($const566.157, simulate.py:142)), ('order_status', Var($const572.161, simulate.py:143)), ('order_status_info', Var($const578.165, simulate.py:144)), ('order_type', Var($586load_attr.170, simulate.py:145)), ('pct_chg_trade', Var($const592.174, simulate.py:146)), ('position', Var($const598.178, simulate.py:147)), ('price', Var($const604.182, simulate.py:148)), ('realized_pnl', Var($const610.186, simulate.py:149)), ('size_value', Var($const616.190, simulate.py:150)), ('sl_pct', Var($const622.194, simulate.py:151)), ('sl_price', Var($const628.198, simulate.py:152)), ('tp_pct', Var($const634.202, simulate.py:153)), ('tp_price', Var($const640.206, simulate.py:154))], vararg=None, varkwarg=None, target=None) ['$532load_global.136', '$560load_attr.153', '$586load_attr.170', '$const540.140', '$const546.144', '$const552.148', '$const566.157', '$const572.161', '$const578.165', '$const592.174', '$const598.178', '$const604.182', '$const610.186', '$const616.190', '$const622.194', '$const628.198', '$const634.202', '$const640.206', 'order_result']
#     $const648.210 = const(int, 0)            ['$const648.210']
#     $const652.212 = const(int, 0)            ['$const652.212']
#     strat_records_filled[$const652.212] = $const648.210 ['$const648.210', '$const652.212', 'strat_records_filled']
#     $656load_global.213 = global(range: <class 'range'>) ['$656load_global.213']
#     $660call_function.215 = call $656load_global.213(total_bars, func=$656load_global.213, args=[Var(total_bars, simulate.py:42)], kws=(), vararg=None, varkwarg=None, target=None) ['$656load_global.213', '$660call_function.215', 'total_bars']
#     $662get_iter.216 = getiter(value=$660call_function.215) ['$660call_function.215', '$662get_iter.216']
#     $phi664.3 = $662get_iter.216             ['$662get_iter.216', '$phi664.3']
#     jump 664                                 []
# label 664:
#     $664for_iter.4 = iternext(value=$phi664.3) ['$664for_iter.4', '$phi664.3']
#     $664for_iter.5 = pair_first(value=$664for_iter.4) ['$664for_iter.4', '$664for_iter.5']
#     $664for_iter.6 = pair_second(value=$664for_iter.4) ['$664for_iter.4', '$664for_iter.6']
#     $phi666.4 = $664for_iter.5               ['$664for_iter.5', '$phi666.4']
#     branch $664for_iter.6, 666, 1096         ['$664for_iter.6']
# label 666:
#     bar = $phi666.4                          ['$phi666.4', 'bar']
#     $670load_attr.6 = getattr(value=account_state, attr=available_balance) ['$670load_attr.6', 'account_state']
#     $const672.7 = const(int, 5)              ['$const672.7']
#     $674compare_op.8 = $670load_attr.6 < $const672.7 ['$670load_attr.6', '$674compare_op.8', '$const672.7']
#     bool676 = global(bool: <class 'bool'>)   ['bool676']
#     $676pred = call bool676($674compare_op.8, func=bool676, args=(Var($674compare_op.8, simulate.py:160),), kws=(), vararg=None, varkwarg=None, target=None) ['$674compare_op.8', '$676pred', 'bool676']
#     branch $676pred, 680, 684                ['$676pred']
# label 680:
#     jump 1096                                []
# label 684:
#     $688binary_subscr.6 = getitem(value=current_indicator_entries, index=bar, fn=<built-in function getitem>) ['$688binary_subscr.6', 'bar', 'current_indicator_entries']
#     bool690 = global(bool: <class 'bool'>)   ['bool690']
#     $690pred = call bool690($688binary_subscr.6, func=bool690, args=(Var($688binary_subscr.6, simulate.py:163),), kws=(), vararg=None, varkwarg=None, target=None) ['$688binary_subscr.6', '$690pred', 'bool690']
#     branch $690pred, 694, 960                ['$690pred']
# label 694:
#     $694load_global.4 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$694load_global.4']
#     $696load_method.5 = getattr(value=$694load_global.4, attr=isnan) ['$694load_global.4', '$696load_method.5']
#     $700load_attr.7 = getattr(value=order_settings, attr=sl_based_on) ['$700load_attr.7', 'order_settings']
#     $702call_method.8 = call $696load_method.5($700load_attr.7, func=$696load_method.5, args=[Var($700load_attr.7, simulate.py:164)], kws=(), vararg=None, varkwarg=None, target=None) ['$696load_method.5', '$700load_attr.7', '$702call_method.8']
#     bool704 = global(bool: <class 'bool'>)   ['bool704']
#     $704pred = call bool704($702call_method.8, func=bool704, args=(Var($702call_method.8, simulate.py:164),), kws=(), vararg=None, varkwarg=None, target=None) ['$702call_method.8', '$704pred', 'bool704']
#     branch $704pred, 876, 708                ['$704pred']
# label 708:
#     $708load_global.4 = global(int: <class 'int'>) ['$708load_global.4']
#     $714load_attr.7 = getattr(value=order_settings, attr=sl_based_on_lookback) ['$714load_attr.7', 'order_settings']
#     $716binary_subtract.8 = bar - $714load_attr.7 ['$714load_attr.7', '$716binary_subtract.8', 'bar']
#     lb = call $708load_global.4($716binary_subtract.8, func=$708load_global.4, args=[Var($716binary_subtract.8, simulate.py:165)], kws=(), vararg=None, varkwarg=None, target=None) ['$708load_global.4', '$716binary_subtract.8', 'lb']
#     $const724.11 = const(int, 0)             ['$const724.11']
#     $726compare_op.12 = lb < $const724.11    ['$726compare_op.12', '$const724.11', 'lb']
#     bool728 = global(bool: <class 'bool'>)   ['bool728']
#     $728pred = call bool728($726compare_op.12, func=bool728, args=(Var($726compare_op.12, simulate.py:166),), kws=(), vararg=None, varkwarg=None, target=None) ['$726compare_op.12', '$728pred', 'bool728']
#     branch $728pred, 732, 804                ['$728pred']
# label 732:
#     $732load_global.4 = global(PriceTuple: <class 'quantfreedom.enums.enums.PriceTuple'>) ['$732load_global.4']
#     $738binary_subscr.7 = getitem(value=open_prices, index=bar, fn=<built-in function getitem>) ['$738binary_subscr.7', 'bar', 'open_prices']
#     $const742.9 = const(int, 0)              ['$const742.9']
#     $const746.11 = const(int, 1)             ['$const746.11']
#     $748binary_add.12 = bar + $const746.11   ['$748binary_add.12', '$const746.11', 'bar']
#     $750build_slice.13 = global(slice: <class 'slice'>) ['$750build_slice.13']
#     $750build_slice.14 = call $750build_slice.13($const742.9, $748binary_add.12, func=$750build_slice.13, args=(Var($const742.9, simulate.py:169), Var($748binary_add.12, simulate.py:169)), kws=(), vararg=None, varkwarg=None, target=None) ['$748binary_add.12', '$750build_slice.13', '$750build_slice.14', '$const742.9']
#     $752binary_subscr.15 = getitem(value=open_prices, index=$750build_slice.14, fn=<built-in function getitem>) ['$750build_slice.14', '$752binary_subscr.15', 'open_prices']
#     $const756.17 = const(int, 0)             ['$const756.17']
#     $const760.19 = const(int, 1)             ['$const760.19']
#     $762binary_add.20 = bar + $const760.19   ['$762binary_add.20', '$const760.19', 'bar']
#     $764build_slice.21 = global(slice: <class 'slice'>) ['$764build_slice.21']
#     $764build_slice.22 = call $764build_slice.21($const756.17, $762binary_add.20, func=$764build_slice.21, args=(Var($const756.17, simulate.py:170), Var($762binary_add.20, simulate.py:170)), kws=(), vararg=None, varkwarg=None, target=None) ['$762binary_add.20', '$764build_slice.21', '$764build_slice.22', '$const756.17']
#     $766binary_subscr.23 = getitem(value=high_prices, index=$764build_slice.22, fn=<built-in function getitem>) ['$764build_slice.22', '$766binary_subscr.23', 'high_prices']
#     $const770.25 = const(int, 0)             ['$const770.25']
#     $const774.27 = const(int, 1)             ['$const774.27']
#     $776binary_add.28 = bar + $const774.27   ['$776binary_add.28', '$const774.27', 'bar']
#     $778build_slice.29 = global(slice: <class 'slice'>) ['$778build_slice.29']
#     $778build_slice.30 = call $778build_slice.29($const770.25, $776binary_add.28, func=$778build_slice.29, args=(Var($const770.25, simulate.py:171), Var($776binary_add.28, simulate.py:171)), kws=(), vararg=None, varkwarg=None, target=None) ['$776binary_add.28', '$778build_slice.29', '$778build_slice.30', '$const770.25']
#     $780binary_subscr.31 = getitem(value=low_prices, index=$778build_slice.30, fn=<built-in function getitem>) ['$778build_slice.30', '$780binary_subscr.31', 'low_prices']
#     $const784.33 = const(int, 0)             ['$const784.33']
#     $const788.35 = const(int, 1)             ['$const788.35']
#     $790binary_add.36 = bar + $const788.35   ['$790binary_add.36', '$const788.35', 'bar']
#     $792build_slice.37 = global(slice: <class 'slice'>) ['$792build_slice.37']
#     $792build_slice.38 = call $792build_slice.37($const784.33, $790binary_add.36, func=$792build_slice.37, args=(Var($const784.33, simulate.py:172), Var($790binary_add.36, simulate.py:172)), kws=(), vararg=None, varkwarg=None, target=None) ['$790binary_add.36', '$792build_slice.37', '$792build_slice.38', '$const784.33']
#     $794binary_subscr.39 = getitem(value=close_prices, index=$792build_slice.38, fn=<built-in function getitem>) ['$792build_slice.38', '$794binary_subscr.39', 'close_prices']
#     prices = call $732load_global.4(func=$732load_global.4, args=[], kws=[('entry', Var($738binary_subscr.7, simulate.py:168)), ('open', Var($752binary_subscr.15, simulate.py:169)), ('high', Var($766binary_subscr.23, simulate.py:170)), ('low', Var($780binary_subscr.31, simulate.py:171)), ('close', Var($794binary_subscr.39, simulate.py:172))], vararg=None, varkwarg=None, target=None) ['$732load_global.4', '$738binary_subscr.7', '$752binary_subscr.15', '$766binary_subscr.23', '$780binary_subscr.31', '$794binary_subscr.39', 'prices']
#     jump 914                                 []
# label 804:
#     $804load_global.4 = global(PriceTuple: <class 'quantfreedom.enums.enums.PriceTuple'>) ['$804load_global.4']
#     $810binary_subscr.7 = getitem(value=open_prices, index=bar, fn=<built-in function getitem>) ['$810binary_subscr.7', 'bar', 'open_prices']
#     $const818.11 = const(int, 1)             ['$const818.11']
#     $820binary_add.12 = bar + $const818.11   ['$820binary_add.12', '$const818.11', 'bar']
#     $822build_slice.13 = global(slice: <class 'slice'>) ['$822build_slice.13']
#     $822build_slice.14 = call $822build_slice.13(lb, $820binary_add.12, func=$822build_slice.13, args=(Var(lb, simulate.py:165), Var($820binary_add.12, simulate.py:177)), kws=(), vararg=None, varkwarg=None, target=None) ['$820binary_add.12', '$822build_slice.13', '$822build_slice.14', 'lb']
#     $824binary_subscr.15 = getitem(value=open_prices, index=$822build_slice.14, fn=<built-in function getitem>) ['$822build_slice.14', '$824binary_subscr.15', 'open_prices']
#     $const832.19 = const(int, 1)             ['$const832.19']
#     $834binary_add.20 = bar + $const832.19   ['$834binary_add.20', '$const832.19', 'bar']
#     $836build_slice.21 = global(slice: <class 'slice'>) ['$836build_slice.21']
#     $836build_slice.22 = call $836build_slice.21(lb, $834binary_add.20, func=$836build_slice.21, args=(Var(lb, simulate.py:165), Var($834binary_add.20, simulate.py:178)), kws=(), vararg=None, varkwarg=None, target=None) ['$834binary_add.20', '$836build_slice.21', '$836build_slice.22', 'lb']
#     $838binary_subscr.23 = getitem(value=high_prices, index=$836build_slice.22, fn=<built-in function getitem>) ['$836build_slice.22', '$838binary_subscr.23', 'high_prices']
#     $const846.27 = const(int, 1)             ['$const846.27']
#     $848binary_add.28 = bar + $const846.27   ['$848binary_add.28', '$const846.27', 'bar']
#     $850build_slice.29 = global(slice: <class 'slice'>) ['$850build_slice.29']
#     $850build_slice.30 = call $850build_slice.29(lb, $848binary_add.28, func=$850build_slice.29, args=(Var(lb, simulate.py:165), Var($848binary_add.28, simulate.py:179)), kws=(), vararg=None, varkwarg=None, target=None) ['$848binary_add.28', '$850build_slice.29', '$850build_slice.30', 'lb']
#     $852binary_subscr.31 = getitem(value=low_prices, index=$850build_slice.30, fn=<built-in function getitem>) ['$850build_slice.30', '$852binary_subscr.31', 'low_prices']
#     $const860.35 = const(int, 1)             ['$const860.35']
#     $862binary_add.36 = bar + $const860.35   ['$862binary_add.36', '$const860.35', 'bar']
#     $864build_slice.37 = global(slice: <class 'slice'>) ['$864build_slice.37']
#     $864build_slice.38 = call $864build_slice.37(lb, $862binary_add.36, func=$864build_slice.37, args=(Var(lb, simulate.py:165), Var($862binary_add.36, simulate.py:180)), kws=(), vararg=None, varkwarg=None, target=None) ['$862binary_add.36', '$864build_slice.37', '$864build_slice.38', 'lb']
#     $866binary_subscr.39 = getitem(value=close_prices, index=$864build_slice.38, fn=<built-in function getitem>) ['$864build_slice.38', '$866binary_subscr.39', 'close_prices']
#     prices = call $804load_global.4(func=$804load_global.4, args=[], kws=[('entry', Var($810binary_subscr.7, simulate.py:176)), ('open', Var($824binary_subscr.15, simulate.py:177)), ('high', Var($838binary_subscr.23, simulate.py:178)), ('low', Var($852binary_subscr.31, simulate.py:179)), ('close', Var($866binary_subscr.39, simulate.py:180))], vararg=None, varkwarg=None, target=None) ['$804load_global.4', '$810binary_subscr.7', '$824binary_subscr.15', '$838binary_subscr.23', '$852binary_subscr.31', '$866binary_subscr.39', 'prices']
#     jump 914                                 []
# label 876:
#     $876load_global.4 = global(PriceTuple: <class 'quantfreedom.enums.enums.PriceTuple'>) ['$876load_global.4']
#     $882binary_subscr.7 = getitem(value=open_prices, index=bar, fn=<built-in function getitem>) ['$882binary_subscr.7', 'bar', 'open_prices']
#     $888binary_subscr.10 = getitem(value=open_prices, index=bar, fn=<built-in function getitem>) ['$888binary_subscr.10', 'bar', 'open_prices']
#     $894binary_subscr.13 = getitem(value=high_prices, index=bar, fn=<built-in function getitem>) ['$894binary_subscr.13', 'bar', 'high_prices']
#     $900binary_subscr.16 = getitem(value=low_prices, index=bar, fn=<built-in function getitem>) ['$900binary_subscr.16', 'bar', 'low_prices']
#     $906binary_subscr.19 = getitem(value=close_prices, index=bar, fn=<built-in function getitem>) ['$906binary_subscr.19', 'bar', 'close_prices']
# ...
#  $748binary_add.12 := int64,
#  $750build_slice.13 := Function(<class 'slice'>),
#  $750build_slice.14 := slice<a:b>,
#  $752binary_subscr.15 := array(float64, 1d, F),
#  $762binary_add.20 := int64,
#  $764build_slice.21 := Function(<class 'slice'>),
#  $764build_slice.22 := slice<a:b>,
#  $766binary_subscr.23 := array(float64, 1d, F),
#  $776binary_add.28 := int64,
#  $778build_slice.29 := Function(<class 'slice'>),
#  $778build_slice.30 := slice<a:b>,
#  $780binary_subscr.31 := array(float64, 1d, F),
#  $78load_global.33 := Module(<module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>),
#  $790binary_add.36 := int64,
#  $792build_slice.37 := Function(<class 'slice'>),
#  $792build_slice.38 := slice<a:b>,
#  $794binary_subscr.39 := array(float64, 1d, F),
#  $804load_global.4 := class(<class 'quantfreedom.enums.enums.PriceTuple'>),
#  $80load_method.34 := Function(<built-in function array>),
#  $810binary_subscr.7 := float64,
#  $820binary_add.12 := int64,
#  $822build_slice.13 := Function(<class 'slice'>),
#  $822build_slice.14 := slice<a:b>,
#  $824binary_subscr.15 := array(float64, 1d, F),
#  $834binary_add.20 := int64,
#  $836build_slice.21 := Function(<class 'slice'>),
#  $836build_slice.22 := slice<a:b>,
#  $838binary_subscr.23 := array(float64, 1d, F),
#  $848binary_add.28 := int64,
#  $84build_list.36 := list(int64)<iv=[0]>,
#  $850build_slice.29 := Function(<class 'slice'>),
#  $850build_slice.30 := slice<a:b>,
#  $852binary_subscr.31 := array(float64, 1d, F),
#  $862binary_add.36 := int64,
#  $864build_slice.37 := Function(<class 'slice'>),
#  $864build_slice.38 := slice<a:b>,
#  $866binary_subscr.39 := array(float64, 1d, F),
#  $876load_global.4 := class(<class 'quantfreedom.enums.enums.PriceTuple'>),
#  $882binary_subscr.7 := float64,
#  $888binary_subscr.10 := float64,
#  $894binary_subscr.13 := float64,
#  $8binary_multiply.3 := int64,
#  $900binary_subscr.16 := float64,
#  $906binary_subscr.19 := float64,
#  $914load_global.4 := type(CPUDispatcher(<function process_order_nb at 0x00000122DDC391B0>)),
#  $930load_attr.12 := int64,
#  $946binary_subscr.20 := int64,
#  $948binary_subscr.21 := Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],or_set[type=int32;offset=8],real_pnl[type=float64;offset=16],equity[type=float64;offset=24];32;True),
#  $94load_global.39 := Function(<class 'int'>),
#  $952call_function_kw.23 := <undecided>,
#  $954unpack_sequence.24 := <undecided>,
#  $954unpack_sequence.25 := <undecided>,
#  $954unpack_sequence.26 := <undecided>,
#  $962load_attr.5 := float64,
#  $966compare_op.7 := bool,
#  $968pred := bool,
#  $972load_global.4 := class(<class 'quantfreedom.enums.enums.PriceTuple'>),
#  $978binary_subscr.7 := float64,
#  $984binary_subscr.10 := float64,
#  $98load_attr.41 := UniTuple(int64 x 2),
#  $990binary_subscr.13 := float64,
#  $996binary_subscr.16 := float64,
#  $const100.42 := Literal[int](1),
#  $const1076.19 := Literal[int](0),
#  $const1112.11 := Literal[int](100),
#  $const1132.4 := Literal[int](0),
#  $const1136.6 := Literal[int](0),
#  $const1148.12 := Literal[str](real_pnl),
#  $const1158.17 := Literal[str](real_pnl),
#  $const1188.5 := Literal[int](0),
#  $const1268.25 := Literal[int](1),
#  $const1278.3 := Literal[int](1),
#  $const1290.1 := none,
#  $const1300.7 := none,
#  $const140.3 := none,
#  $const142.4 := none,
#  $const156.11 := none,
#  $const158.12 := none,
#  $const164.16 := Literal[int](1),
#  $const176.21 := none,
#  $const178.22 := none,
#  $const184.26 := Literal[int](2),
#  $const196.31 := none,
#  $const198.32 := none,
#  $const204.36 := Literal[int](3),
#  $const216.41 := Literal[int](4),
#  $const224.44 := none,
#  $const226.45 := none,
#  $const270.4 := none,
#  $const272.5 := none,
#  $const304.7 := Literal[str](leverage),
#  $const316.14 := Literal[str](max_equity_risk_pct),
#  $const328.21 := Literal[str](max_equity_risk_value),
#  $const340.28 := Literal[str](risk_reward),
#  $const352.35 := Literal[str](size_pct),
#  $const364.42 := Literal[str](size_value),
#  $const376.49 := Literal[str](sl_based_on),
#  $const388.56 := Literal[str](sl_based_on_add_pct),
#  $const400.63 := Literal[str](sl_based_on_lookback),
#  $const412.70 := Literal[str](sl_pct),
#  $const424.77 := Literal[str](sl_to_be_based_on),
#  $const436.84 := Literal[str](sl_to_be_zero_or_entry),
#  $const448.91 := Literal[str](sl_to_be_when_pct_from_avg_entry),
#  $const460.98 := Literal[str](tp_pct),
#  $const472.105 := Literal[str](trail_sl_based_on),
#  $const484.112 := Literal[str](trail_sl_by_pct),
#  $const496.119 := Literal[str](trail_sl_when_pct_from_avg_entry),
#  $const518.130 := float64,
#  $const520.131 := float64,
#  $const538.139 := Literal[str](average_entry),
#  $const540.140 := float64,
#  $const544.143 := Literal[str](fees_paid),
#  $const546.144 := float64,
#  $const550.147 := Literal[str](leverage),
#  $const552.148 := float64,
#  $const556.151 := Literal[str](liq_price),
#  $const564.156 := Literal[str](moved_sl_to_be),
#  $const566.157 := Literal[bool](False),
#  $const570.160 := Literal[str](order_status),
#  $const572.161 := Literal[int](0),
#  $const576.164 := Literal[str](order_status_info),
#  $const578.165 := Literal[int](0),
#  $const582.168 := Literal[str](order_type),
#  $const590.173 := Literal[str](pct_chg_trade),
#  $const592.174 := float64,
#  $const596.177 := Literal[str](position),
#  $const598.178 := float64,
#  $const602.181 := Literal[str](price),
#  $const604.182 := float64,
#  $const608.185 := Literal[str](realized_pnl),
#  $const610.186 := float64,
#  $const614.189 := Literal[str](size_value),
#  $const616.190 := float64,
#  $const620.193 := Literal[str](sl_pct),
#  $const622.194 := float64,
#  $const626.197 := Literal[str](sl_price),
#  $const628.198 := float64,
#  $const632.201 := Literal[str](tp_pct),
#  $const634.202 := float64,
#  $const638.205 := Literal[str](tp_price),
#  $const64.27 := Literal[int](3),
#  $const640.206 := float64,
#  $const648.210 := Literal[int](0),
#  $const652.212 := Literal[int](0),
#  $const672.7 := Literal[int](5),
#  $const724.11 := Literal[int](0),
#  $const742.9 := Literal[int](0),
#  $const746.11 := Literal[int](1),
#  $const756.17 := Literal[int](0),
#  $const760.19 := Literal[int](1),
#  $const770.25 := Literal[int](0),
#  $const774.27 := Literal[int](1),
#  $const784.33 := Literal[int](0),
#  $const788.35 := Literal[int](1),
#  $const818.11 := Literal[int](1),
#  $const82.35 := Literal[int](0),
#  $const832.19 := Literal[int](1),
#  $const846.27 := Literal[int](1),
#  $const860.35 := Literal[int](1),
#  $const944.19 := Literal[int](0),
#  $const964.6 := Literal[int](0),
#  $phi132.0 := range_iter_int64,
#  $phi136.1 := int64,
#  $phi262.1 := range_iter_int64,
#  $phi266.2 := int64,
#  $phi292.2 := range_iter_int64,
#  $phi296.3 := int64,
#  $phi664.3 := range_iter_int64,
#  $phi666.4 := int64,
#  account_state := AccountState(float64 x 4),
#  account_state.1 := <undecided>,
#  account_state.2 := <undecided>,
#  account_state.3 := AccountState(float64 x 4),
#  account_state.4 := AccountState(float64 x 4),
#  account_state.5 := AccountState(float64 x 4),
#  arg.entries := array(bool, 2d, C),
#  arg.num_of_symbols := int64,
#  arg.os_cart_arrays_tuple := OrderSettingsArrays(array(float64, 1d, C) x 17),
#  arg.price_data := array(float64, 2d, F),
#  arg.static_variables_tuple := StaticVariables(float64, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64, int64, float64),
#  arg.total_bars := int64,
#  arg.total_indicator_settings := int64,
#  arg.total_order_settings := int64,
#  array_size := int64,
#  bar := int64,
#  bool1042 := Function(<class 'bool'>),
#  bool1126 := Function(<class 'bool'>),
#  bool1180 := Function(<class 'bool'>),
#  bool1216 := Function(<class 'bool'>),
#  bool676 := Function(<class 'bool'>),
#  bool690 := Function(<class 'bool'>),
#  bool704 := Function(<class 'bool'>),
#  bool728 := Function(<class 'bool'>),
#  bool968 := Function(<class 'bool'>),
#  close_prices := array(float64, 1d, F),
#  current_indicator_entries := array(bool, 1d, A),
#  entries := array(bool, 2d, C),
#  entries_col := Literal[int](0),
#  entries_col.1 := int64,
#  entries_col.2 := int64,
#  entries_col.3 := int64,
#  entries_end := int64,
#  entries_end.1 := int64,
#  entries_end.2 := int64,
#  entries_per_symbol := int64,
#  entries_start := Literal[int](0),
#  entries_start.1 := int64,
#  entries_start.2 := int64,
#  gains_pct := float64,
#  high_prices := array(float64, 1d, F),
#  indicator_settings_counter := int64,
#  lb := int64,
#  low_prices := array(float64, 1d, F),
#  num_of_symbols := int64,
#  open_prices := array(float64, 1d, F),
#  order_result := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.1 := <undecided>,
#  order_result.2 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.3 := <undecided>,
#  order_result.4 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.5 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.6 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_settings := OrderSettings(float64 x 17),
#  order_settings_counter := int64,
#  order_settings_result_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],leverage[type=float64;offset=8],max_equity_risk_pct[type=float64;offset=16],max_equity_risk_value[type=float64;offset=24],risk_reward[type=float64;offset=32],size_pct[type=float64;offset=40],size_value[type=float64;offset=48],sl_based_on[type=float64;offset=56],sl_based_on_add_pct[type=float64;offset=64],sl_based_on_lookback[type=float64;offset=72],sl_pct[type=float64;offset=80],sl_to_be_based_on[type=float64;offset=88],sl_to_be_when_pct_from_avg_entry[type=float64;offset=96],sl_to_be_zero_or_entry[type=float64;offset=104],tp_pct[type=float64;offset=112],trail_sl_based_on[type=float64;offset=120],trail_sl_by_pct[type=float64;offset=128],trail_sl_when_pct_from_avg_entry[type=float64;offset=136];144;True), 1d, C),
#  os_cart_arrays_tuple := OrderSettingsArrays(array(float64, 1d, C) x 17),
#  price_data := array(float64, 2d, F),
#  prices := PriceTuple(float64, array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F)),
#  prices.1 := PriceTuple(float64, array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F)),
#  prices.2 := PriceTuple(float64 x 5),
#  prices.3 := PriceTuple(float64 x 5),
#  prices.4 := PriceTuple(float64 x 5),
#  prices_start := Literal[int](0),
#  prices_start.1 := int64,
#  prices_start.2 := int64,
#  result_records_filled := Literal[int](0),
#  result_records_filled.1 := int64,
#  result_records_filled.2 := int64,
#  result_records_filled.3 := int64,
#  result_records_filled.4 := int64,
#  result_records_filled.5 := int64,
#  static_variables_tuple := StaticVariables(float64, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64, int64, float64),
#  strat_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],or_set[type=int32;offset=8],real_pnl[type=float64;offset=16],equity[type=float64;offset=24];32;True), 1d, C),
#  strat_records_filled := array(int64, 1d, C),
#  strategy_result_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],or_set[type=int32;offset=8],total_trades[type=float64;offset=16],gains_pct[type=float64;offset=24],win_rate[type=float64;offset=32],to_the_upside[type=float64;offset=40],total_pnl[type=float64;offset=48],ending_eq[type=float64;offset=56];64;True), 1d, C),
#  symbol_counter := int64,
#  symbol_entries := array(bool, 2d, A),
#  temp_strat_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],or_set[type=int32;offset=8],real_pnl[type=float64;offset=16],equity[type=float64;offset=24];32;True), 1d, C),
#  to_the_upside := float64,
#  total_bars := int64,
#  total_indicator_settings := int64,
#  total_order_settings := int64,
#  wins_and_losses_array := array(float64, 1d, C),
#  wins_and_losses_array_no_be := array(float64, 1d, C)]
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 strat_results_df, settings_results_df = sm.backtest_df(
#       2     price_data=price_data,
#       3     static_variables_tuple=static_vars,
#       4     order_settings_arrays_tuple=order_settings,
#       5 )
#
# File e:\coding\backtesters\quantfreedom\quantfreedom\base\strategy_maker_cls.py:130, in StrategyMaker.backtest_df(self, price_data, static_variables_tuple, order_settings_arrays_tuple)
#     127 self.price_data = price_data
#     128 self.static_vars = static_variables_tuple
# --> 130 self.strat_results_df, self.settings_results_df = backtest_df_only(
#     131     price_data=price_data,
#     132     entries=entries,
#     133     static_variables_tuple=static_variables_tuple,
#     134     order_settings_arrays_tuple=order_settings_arrays_tuple,
#     135 )
#     136 return self.strat_results_df, self.settings_results_df
#
# File e:\coding\backtesters\quantfreedom\quantfreedom\base\base.py:79, in backtest_df_only(price_data, entries, static_variables_tuple, order_settings_arrays_tuple)
#      72 print(
#      73     f"Total candles to test: {total_indicator_settings * total_order_settings * total_bars:,}"
#      74 )
#      75 print(
#      76     f"\nTotal combinations to test: {total_indicator_settings * total_order_settings:,}"
#      77 )
# ---> 79 strat_array, settings_array = backtest_df_only_nb(
#      80     entries=entries.values,
#      81     num_of_symbols=num_of_symbols,
#      82     os_cart_arrays_tuple=os_cart_arrays_tuple,
#      83     price_data=price_data.values,
#      84     static_variables_tuple=static_variables_tuple,
#      85     total_bars=total_bars,
#      86     total_indicator_settings=total_indicator_settings,
#      87     total_order_settings=total_order_settings,
#      88 )
#      90 strat_results_df = pd.DataFrame(strat_array).sort_values(
#      91     by=["to_the_upside", "gains_pct"], ascending=False
#      92 )
#      94 symbols = list(price_data.columns.levels[0])
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\numba\core\dispatcher.py:468, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     464         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     465                f"by the following argument(s):\n{args_str}\n")
#     466         e.patch_message(msg)
# --> 468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
#     471     error_rewrite(e, 'unsupported_error')
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\numba\core\dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Cannot unify PriceTuple(float64 x 5) and PriceTuple(float64, array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F)) for 'prices.4', defined at e:\coding\backtesters\quantfreedom\quantfreedom\nb\simulate.py (191)
#
# File "..\quantfreedom\nb\simulate.py", line 191:
# def backtest_df_only_nb(
#     <source elided>
#                         # Process Order nb
#                         account_state, order_result = process_order_nb(
#                         ^
#
# During: typing of assignment at e:\coding\backtesters\quantfreedom\quantfreedom\nb\simulate.py (191)
#
# File "..\quantfreedom\nb\simulate.py", line 191:
# def backtest_df_only_nb(
#     <source elided>
#                         # Process Order nb
#                         account_state, order_result = process_order_nb(
#                         ^

# %%
sm.strategy_dashboard([1,18, 8, 6])
