# %%
# import os
# import sys

# sys.dont_write_bytecode = True
# os.environ["NUMBA_DISABLE_JIT"] = "1"

import os
os.environ["NUMBA_DEBUG"] = "1"
# os.environ["NUMBA_DEBUGINFO"] = "1"
os.environ["NUMBA_DEBUG_TYPEINFER"] = "1"

import numpy as np
import pandas as pd
from quantfreedom.base.strategy_maker_cls import StrategyMaker
from quantfreedom.enums.enums import (
    CandleBody,
    LeverageMode,
    OrderType,
    SizeType,
    OrderSettingsArrays,
    StaticVariables,
)

np.set_printoptions(formatter={"float_kind": "{:.2f}".format})
pd.options.display.float_format = "{:,.2f}".format

# prices = data_download_from_ccxt(
#     exchange='bybit',
#     start='2020-10-01T00:00:00Z',
#     end='2021-04-15T00:00:00Z',
#     symbols=['BTCUSDT', 'ETHUSD'],
#     timeframe='30m',
# )
sm = StrategyMaker()
price_data = pd.read_hdf("../tests/data/prices.hd5")
rsi_ind = sm.from_talib(
    func_name="rsi",
    price_data=price_data,
    cart_product=False,
    combos=False,
    timeperiod=[15, 30],
)
entries = rsi_ind.is_below(
    user_args=[40, 50],
    candle_ohlc="close",
)
entries = sm.combined_data_frame()
# Out:
# ================================================================================
# --------------------------FUNCTION OPTIMIZED DUMP nrt---------------------------
# ; ModuleID = 'nrt'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# @.const.picklebuf.2089768183168 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([102 x i8], [102 x i8]* @.const.pickledata.2089768183168, i32 0, i32 0), i32 102, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.2089768183168.sha1, i32 0, i32 0) }
# @.const.pickledata.2089768183168 = internal constant [102 x i8] c"\80\04\95[\00\00\00\00\00\00\00\8C\08builtins\94\8C\0CRuntimeError\94\93\94\8C6numba jitted function aborted due to unresolved symbol\94\85\94N\87\94."
# @.const.pickledata.2089768183168.sha1 = internal constant [20 x i8] c"\97\BE\DC\DF\EC\8E\80\B7\09>P\CE%\EDV\F7r\0E\0C\9C"
#
# define i64 @nrt_atomic_add(i64* %.1) {
# .3:
#   %.4 = atomicrmw add i64* %.1, i64 1 monotonic
#   %.5 = add i64 %.4, 1
#   ret i64 %.5
# }
#
# define i64 @nrt_atomic_sub(i64* %.1) {
# .3:
#   %.4 = atomicrmw sub i64* %.1, i64 1 monotonic
#   %.5 = sub i64 %.4, 1
#   ret i64 %.5
# }
#
# define i32 @nrt_atomic_cas(i64* %.1, i64 %.2, i64 %.3, i64* %.4) {
# .6:
#   %.7 = cmpxchg i64* %.1, i64 %.2, i64 %.3 monotonic monotonic
#   %.8 = extractvalue { i64, i1 } %.7, 0
#   %.9 = extractvalue { i64, i1 } %.7, 1
#   store i64 %.8, i64* %.4, align 8
#   %.11 = zext i1 %.9 to i32
#   ret i32 %.11
# }
#
# define i8* @NRT_MemInfo_data_fast(i8* %.1) {
# .3:
#   %.4 = bitcast i8* %.1 to { i64, i8*, i8*, i8*, i64 }*
#   %.5 = getelementptr { i64, i8*, i8*, i8*, i64 }, { i64, i8*, i8*, i8*, i64 }* %.4, i32 0, i32 3
#   %.6 = load i8*, i8** %.5, align 8
#   ret i8* %.6
# }
#
# ; Function Attrs: noinline
# define void @NRT_incref(i8* %.1) #0 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   %.7 = bitcast i8* %.1 to i64*
#   %.8 = call i64 @nrt_atomic_add(i64* %.7)
#   ret void
# }
#
# ; Function Attrs: noinline
# define void @NRT_decref(i8* %.1) #0 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3.endif, %.3.endif.if, %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.9 = call i64 @nrt_atomic_sub(i64* %.8)
#   %.10 = icmp eq i64 %.9, 0
#   br i1 %.10, label %.3.endif.if, label %.3.if, !prof !0
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   call void @NRT_MemInfo_call_dtor(i8* %.1)
#   br label %.3.if
# }
#
# declare void @NRT_MemInfo_call_dtor(i8*)
#
# define i32 @nrt_unresolved_abort(i8** %.1, { i8*, i32, i8* }** %.2) {
# .4:
#   store { i8*, i32, i8* }* @.const.picklebuf.2089768183168, { i8*, i32, i8* }** %.2, align 8
#   ret i32 1, !ret_is_raise !1
# }
#
# attributes #0 = { noinline }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{i1 true}
#
# ================================================================================
# ================================================================================
# -------------------------------OPTIMIZED DUMP nrt-------------------------------
# ; ModuleID = 'nrt'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# @.const.picklebuf.2089768183168 = internal constant { i8*, i32, i8* } { i8* getelementptr inbounds ([102 x i8], [102 x i8]* @.const.pickledata.2089768183168, i32 0, i32 0), i32 102, i8* getelementptr inbounds ([20 x i8], [20 x i8]* @.const.pickledata.2089768183168.sha1, i32 0, i32 0) }
# @.const.pickledata.2089768183168 = internal constant [102 x i8] c"\80\04\95[\00\00\00\00\00\00\00\8C\08builtins\94\8C\0CRuntimeError\94\93\94\8C6numba jitted function aborted due to unresolved symbol\94\85\94N\87\94."
# @.const.pickledata.2089768183168.sha1 = internal constant [20 x i8] c"\97\BE\DC\DF\EC\8E\80\B7\09>P\CE%\EDV\F7r\0E\0C\9C"
#
# ; Function Attrs: nofree norecurse nounwind
# define i64 @nrt_atomic_add(i64* nocapture %.1) local_unnamed_addr #0 {
# .3:
#   %.4 = atomicrmw add i64* %.1, i64 1 monotonic
#   %.5 = add i64 %.4, 1
#   ret i64 %.5
# }
#
# ; Function Attrs: nofree norecurse nounwind
# define i64 @nrt_atomic_sub(i64* nocapture %.1) local_unnamed_addr #0 {
# .3:
#   %.4 = atomicrmw sub i64* %.1, i64 1 monotonic
#   %.5 = add i64 %.4, -1
#   ret i64 %.5
# }
#
# ; Function Attrs: nofree norecurse nounwind
# define i32 @nrt_atomic_cas(i64* nocapture %.1, i64 %.2, i64 %.3, i64* nocapture %.4) local_unnamed_addr #0 {
# .6:
#   %.7 = cmpxchg i64* %.1, i64 %.2, i64 %.3 monotonic monotonic
#   %.8 = extractvalue { i64, i1 } %.7, 0
#   %.9 = extractvalue { i64, i1 } %.7, 1
#   store i64 %.8, i64* %.4, align 8
#   %.11 = zext i1 %.9 to i32
#   ret i32 %.11
# }
#
# ; Function Attrs: norecurse nounwind readonly
# define i8* @NRT_MemInfo_data_fast(i8* nocapture readonly %.1) local_unnamed_addr #1 {
# .3:
#   %.5 = getelementptr i8, i8* %.1, i64 24
#   %0 = bitcast i8* %.5 to i8**
#   %.6 = load i8*, i8** %0, align 8
#   ret i8* %.6
# }
#
# ; Function Attrs: nofree noinline norecurse nounwind
# define void @NRT_incref(i8* %.1) local_unnamed_addr #2 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   %.7 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw add i64* %.7, i64 1 monotonic
#   ret void
# }
#
# ; Function Attrs: noinline
# define void @NRT_decref(i8* %.1) local_unnamed_addr #3 {
# .3:
#   %.4 = icmp eq i8* %.1, null
#   br i1 %.4, label %.3.if, label %.3.endif, !prof !0
#
# .3.if:                                            ; preds = %.3.endif, %.3
#   ret void
#
# .3.endif:                                         ; preds = %.3
#   fence release
#   %.8 = bitcast i8* %.1 to i64*
#   %.4.i = atomicrmw sub i64* %.8, i64 1 monotonic
#   %.10 = icmp eq i64 %.4.i, 1
#   br i1 %.10, label %.3.endif.if, label %.3.if, !prof !0
#
# .3.endif.if:                                      ; preds = %.3.endif
#   fence acquire
#   tail call void @NRT_MemInfo_call_dtor(i8* nonnull %.1)
#   ret void
# }
#
# declare void @NRT_MemInfo_call_dtor(i8*) local_unnamed_addr
#
# ; Function Attrs: nofree norecurse nounwind writeonly
# define i32 @nrt_unresolved_abort(i8** nocapture readnone %.1, { i8*, i32, i8* }** nocapture %.2) local_unnamed_addr #4 {
# .4:
#   store { i8*, i32, i8* }* @.const.picklebuf.2089768183168, { i8*, i32, i8* }** %.2, align 8
#   ret i32 1, !ret_is_raise !1
# }
#
# ; Function Attrs: nounwind
# declare void @llvm.stackprotector(i8*, i8**) #5
#
# attributes #0 = { nofree norecurse nounwind }
# attributes #1 = { norecurse nounwind readonly }
# attributes #2 = { nofree noinline norecurse nounwind }
# attributes #3 = { noinline }
# attributes #4 = { nofree norecurse nounwind writeonly }
# attributes #5 = { nounwind }
#
# !0 = !{!"branch_weights", i32 1, i32 99}
# !1 = !{i1 true}
#
# ================================================================================
# ================================================================================
# ----------------------------------ASSEMBLY nrt----------------------------------
# 	.text
# 	.file	"<string>"
# 	.globl	nrt_atomic_add
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_add,@function
# nrt_atomic_add:
# 	movl	$1, %eax
# 	lock		xaddq	%rax, (%rcx)
# 	incq	%rax
# 	retq
# .Lfunc_end0:
# 	.size	nrt_atomic_add, .Lfunc_end0-nrt_atomic_add
#
# 	.globl	nrt_atomic_sub
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_sub,@function
# nrt_atomic_sub:
# 	movq	$-1, %rax
# 	lock		xaddq	%rax, (%rcx)
# 	decq	%rax
# 	retq
# .Lfunc_end1:
# 	.size	nrt_atomic_sub, .Lfunc_end1-nrt_atomic_sub
#
# 	.globl	nrt_atomic_cas
# 	.p2align	4, 0x90
# 	.type	nrt_atomic_cas,@function
# nrt_atomic_cas:
# 	movq	%rdx, %rax
# 	xorl	%edx, %edx
# 	lock		cmpxchgq	%r8, (%rcx)
# 	sete	%dl
# 	movq	%rax, (%r9)
# 	movl	%edx, %eax
# 	retq
# .Lfunc_end2:
# 	.size	nrt_atomic_cas, .Lfunc_end2-nrt_atomic_cas
#
# 	.globl	NRT_MemInfo_data_fast
# 	.p2align	4, 0x90
# 	.type	NRT_MemInfo_data_fast,@function
# NRT_MemInfo_data_fast:
# 	movq	24(%rcx), %rax
# 	retq
# .Lfunc_end3:
# 	.size	NRT_MemInfo_data_fast, .Lfunc_end3-NRT_MemInfo_data_fast
#
# 	.globl	NRT_incref
# 	.p2align	4, 0x90
# 	.type	NRT_incref,@function
# NRT_incref:
# 	testq	%rcx, %rcx
# 	je	.LBB4_1
# 	lock		incq	(%rcx)
# 	retq
# .LBB4_1:
# 	retq
# .Lfunc_end4:
# 	.size	NRT_incref, .Lfunc_end4-NRT_incref
#
# 	.globl	NRT_decref
# 	.p2align	4, 0x90
# 	.type	NRT_decref,@function
# NRT_decref:
# 	.cfi_startproc
# 	testq	%rcx, %rcx
# 	je	.LBB5_2
# 	#MEMBARRIER
# 	lock		decq	(%rcx)
# 	je	.LBB5_3
# .LBB5_2:
# 	retq
# .LBB5_3:
# 	#MEMBARRIER
# 	movabsq	$NRT_MemInfo_call_dtor, %rax
# 	rex64 jmpq	*%rax
# .Lfunc_end5:
# 	.size	NRT_decref, .Lfunc_end5-NRT_decref
# 	.cfi_endproc
#
# 	.globl	nrt_unresolved_abort
# 	.p2align	4, 0x90
# 	.type	nrt_unresolved_abort,@function
# nrt_unresolved_abort:
# 	movabsq	$.const.picklebuf.2089768183168, %rax
# 	movq	%rax, (%rdx)
# 	movl	$1, %eax
# 	retq
# .Lfunc_end6:
# 	.size	nrt_unresolved_abort, .Lfunc_end6-nrt_unresolved_abort
#
# 	.type	.const.picklebuf.2089768183168,@object
# 	.section	.rodata,"a",@progbits
# 	.p2align	4
# .const.picklebuf.2089768183168:
# 	.quad	.const.pickledata.2089768183168
# 	.long	102
# 	.zero	4
# 	.quad	.const.pickledata.2089768183168.sha1
# 	.size	.const.picklebuf.2089768183168, 24
#
# 	.type	.const.pickledata.2089768183168,@object
# 	.p2align	4
# .const.pickledata.2089768183168:
# 	.ascii	"\200\004\225[\000\000\000\000\000\000\000\214\bbuiltins\224\214\fRuntimeError\224\223\224\2146numba jitted function aborted due to unresolved symbol\224\205\224N\207\224."
# 	.size	.const.pickledata.2089768183168, 102
#
# 	.type	.const.pickledata.2089768183168.sha1,@object
# 	.p2align	4
# .const.pickledata.2089768183168.sha1:
# 	.ascii	"\227\276\334\337\354\216\200\267\t>P\316%\355V\367r\016\f\234"
# 	.size	.const.pickledata.2089768183168.sha1, 20
#
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================

# %%
static_vars = StaticVariables(
    equity=1000.,
    lev_mode=LeverageMode.LeastFreeCashUsed,
    order_type=OrderType.LongEntry,
    size_type=SizeType.RiskPercentOfAccount,
)
order_settings = OrderSettingsArrays(
    max_equity_risk_pct=6.,
    risk_reward=5,
    size_pct=1.,
    sl_based_on=CandleBody.low,
    sl_based_on_lookback=30,
    sl_based_on_add_pct=.2,
)

# %%
strat_results_df, settings_results_df = sm.backtest_df(
    price_data=price_data,
    static_variables_tuple=static_vars,
    order_settings_arrays_tuple=order_settings,
)
# Out:
# Checking static variables for errors or conflicts.
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.static_var_checker_nb-18.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.static_var_checker_nb-18.py310.1.nbc'
# ================================================================================
# ----------------------OPTIMIZED DUMP static_var_checker_nb----------------------
# ; ModuleID = 'static_var_checker_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# -------------------------ASSEMBLY static_var_checker_nb-------------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Turning all variables into arrays.
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.all_os_as_1d_arrays_nb-112.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.all_os_as_1d_arrays_nb-112.py310.1.nbc'
# ================================================================================
# ---------------------OPTIMIZED DUMP all_os_as_1d_arrays_nb----------------------
# ; ModuleID = 'all_os_as_1d_arrays_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# ------------------------ASSEMBLY all_os_as_1d_arrays_nb-------------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Checking arrays for errors or conflicts ... the backtest will begin shortly, please hold.
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.check_os_1d_arrays_nb-232.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.check_os_1d_arrays_nb-232.py310.1.nbc'
# ================================================================================
# ----------------------OPTIMIZED DUMP check_os_1d_arrays_nb----------------------
# ; ModuleID = 'check_os_1d_arrays_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# -------------------------ASSEMBLY check_os_1d_arrays_nb-------------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Creating cartesian product ... after this the backtest will start, I promise :).
#
# [cache] index loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.create_os_cart_product_nb-490.py310.nbi'
# [cache] data loaded from 'numba_cache\\nb_d94e70215aa65c44fd8182fb4183945fa7dcdef9\\helper_funcs.create_os_cart_product_nb-490.py310.1.nbc'
# ================================================================================
# --------------------OPTIMIZED DUMP create_os_cart_product_nb--------------------
# ; ModuleID = 'create_os_cart_product_nb'
# source_filename = "<string>"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-pc-windows-msvc"
#
# ================================================================================
# ================================================================================
# -----------------------ASSEMBLY create_os_cart_product_nb-----------------------
# 	.text
# 	.file	"<string>"
# 	.section	".note.GNU-stack","",@progbits
#
# ================================================================================
# Starting the backtest now ... and also here are some stats for your backtest.
#
# Total symbols: 5
# Total indicator settings per symbol: 4
# Total indicator settings to test: 20
# Total order settings per symbol: 1
# Total order settings to test: 5
# Total candles per symbol: 9,408
# Total candles to test: 188,160
#
# Total combinations to test: 20
# --------------------------IR DUMP: backtest_df_only_nb--------------------------
# label 0:
#     num_of_symbols = arg(0, name=num_of_symbols) ['num_of_symbols']
#     total_indicator_settings = arg(1, name=total_indicator_settings) ['total_indicator_settings']
#     total_order_settings = arg(2, name=total_order_settings) ['total_order_settings']
#     total_bars = arg(3, name=total_bars)     ['total_bars']
#     entries = arg(4, name=entries)           ['entries']
#     price_data = arg(5, name=price_data)     ['price_data']
#     static_variables_tuple = arg(6, name=static_variables_tuple) ['static_variables_tuple']
#     os_cart_arrays_tuple = arg(7, name=os_cart_arrays_tuple) ['os_cart_arrays_tuple']
#     $2load_global.0 = global(int: <class 'int'>) ['$2load_global.0']
#     $8binary_multiply.3 = num_of_symbols * total_indicator_settings ['$8binary_multiply.3', 'num_of_symbols', 'total_indicator_settings']
#     $12binary_multiply.5 = $8binary_multiply.3 * total_order_settings ['$12binary_multiply.5', '$8binary_multiply.3', 'total_order_settings']
#     $16load_attr.7 = getattr(value=static_variables_tuple, attr=divide_records_array_size_by) ['$16load_attr.7', 'static_variables_tuple']
#     $18binary_true_divide.8 = $12binary_multiply.5 / $16load_attr.7 ['$12binary_multiply.5', '$16load_attr.7', '$18binary_true_divide.8']
#     array_size = call $2load_global.0($18binary_true_divide.8, func=$2load_global.0, args=[Var($18binary_true_divide.8, simulate.py:44)], kws=(), vararg=None, varkwarg=None, target=None) ['$18binary_true_divide.8', '$2load_global.0', 'array_size']
#     $24load_global.10 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$24load_global.10']
#     $26load_attr.11 = getattr(value=$24load_global.10, attr=empty) ['$24load_global.10', '$26load_attr.11']
#     $30load_global.13 = global(strat_df_array_dt: {'names': ['symbol', 'entries_col', 'or_set', 'total_trades', 'gains_pct', 'win_rate', 'to_the_upside', 'total_pnl', 'ending_eq'], 'formats': ['<i4', '<i4', '<i4', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8'], 'offsets': [0, 4, 8, 16, 24, 32, 40, 48, 56], 'itemsize': 64, 'aligned': True}) ['$30load_global.13']
#     strategy_result_records = call $26load_attr.11(array_size, func=$26load_attr.11, args=[Var(array_size, simulate.py:43)], kws=[('dtype', Var($30load_global.13, simulate.py:52))], vararg=None, varkwarg=None, target=None) ['$26load_attr.11', '$30load_global.13', 'array_size', 'strategy_result_records']
#     $38load_global.16 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$38load_global.16']
#     $40load_attr.17 = getattr(value=$38load_global.16, attr=empty) ['$38load_global.16', '$40load_attr.17']
#     $44load_global.19 = global(order_settings_array_dt: {'names': ['symbol', 'entries_col', 'leverage', 'max_equity_risk_pct', 'max_equity_risk_value', 'risk_reward', 'size_pct', 'size_value', 'sl_based_on', 'sl_based_on_add_pct', 'sl_based_on_lookback', 'sl_pct', 'sl_to_be_based_on', 'sl_to_be_when_pct_from_avg_entry', 'sl_to_be_zero_or_entry', 'tp_pct', 'trail_sl_based_on', 'trail_sl_by_pct', 'trail_sl_when_pct_from_avg_entry'], 'formats': ['<i4', '<i4', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8', '<f8'], 'offsets': [0, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136], 'itemsize': 144, 'aligned': True}) ['$44load_global.19']
#     order_settings_result_records = call $40load_attr.17(array_size, func=$40load_attr.17, args=[Var(array_size, simulate.py:43)], kws=[('dtype', Var($44load_global.19, simulate.py:56))], vararg=None, varkwarg=None, target=None) ['$40load_attr.17', '$44load_global.19', 'array_size', 'order_settings_result_records']
#     result_records_filled = const(int, 0)    ['result_records_filled']
#     $56load_global.23 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$56load_global.23']
#     $58load_attr.24 = getattr(value=$56load_global.23, attr=empty) ['$56load_global.23', '$58load_attr.24']
#     $60load_global.25 = global(int: <class 'int'>) ['$60load_global.25']
#     $const64.27 = const(int, 3)              ['$const64.27']
#     $66binary_true_divide.28 = total_bars / $const64.27 ['$66binary_true_divide.28', '$const64.27', 'total_bars']
#     $68call_function.29 = call $60load_global.25($66binary_true_divide.28, func=$60load_global.25, args=[Var($66binary_true_divide.28, simulate.py:60)], kws=(), vararg=None, varkwarg=None, target=None) ['$60load_global.25', '$66binary_true_divide.28', '$68call_function.29']
#     $70load_global.30 = global(strat_records_dt: {'names': ['symbol', 'entries_col', 'or_set', 'real_pnl', 'equity'], 'formats': ['<i4', '<i4', '<i4', '<f8', '<f8'], 'offsets': [0, 4, 8, 16, 24], 'itemsize': 32, 'aligned': True}) ['$70load_global.30']
#     strat_records = call $58load_attr.24($68call_function.29, func=$58load_attr.24, args=[Var($68call_function.29, simulate.py:60)], kws=[('dtype', Var($70load_global.30, simulate.py:60))], vararg=None, varkwarg=None, target=None) ['$58load_attr.24', '$68call_function.29', '$70load_global.30', 'strat_records']
#     $78load_global.33 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$78load_global.33']
#     $80load_method.34 = getattr(value=$78load_global.33, attr=array) ['$78load_global.33', '$80load_method.34']
#     $const82.35 = const(int, 0)              ['$const82.35']
#     $84build_list.36 = build_list(items=[Var($const82.35, simulate.py:61)]) ['$84build_list.36', '$const82.35']
#     strat_records_filled = call $80load_method.34($84build_list.36, func=$80load_method.34, args=[Var($84build_list.36, simulate.py:61)], kws=(), vararg=None, varkwarg=None, target=None) ['$80load_method.34', '$84build_list.36', 'strat_records_filled']
#     prices_start = const(int, 0)             ['prices_start']
#     $94load_global.39 = global(int: <class 'int'>) ['$94load_global.39']
#     $98load_attr.41 = getattr(value=entries, attr=shape) ['$98load_attr.41', 'entries']
#     $const100.42 = const(int, 1)             ['$const100.42']
#     $102binary_subscr.43 = getitem(value=$98load_attr.41, index=$const100.42, fn=<built-in function getitem>) ['$102binary_subscr.43', '$98load_attr.41', '$const100.42']
#     $106binary_true_divide.45 = $102binary_subscr.43 / num_of_symbols ['$102binary_subscr.43', '$106binary_true_divide.45', 'num_of_symbols']
#     entries_per_symbol = call $94load_global.39($106binary_true_divide.45, func=$94load_global.39, args=[Var($106binary_true_divide.45, simulate.py:64)], kws=(), vararg=None, varkwarg=None, target=None) ['$106binary_true_divide.45', '$94load_global.39', 'entries_per_symbol']
#     entries_start = const(int, 0)            ['entries_start']
#     entries_end = entries_per_symbol         ['entries_end', 'entries_per_symbol']
#     entries_col = const(int, 0)              ['entries_col']
#     prices = const(int, 0)                   ['prices']
#     $128load_global.51 = global(range: <class 'range'>) ['$128load_global.51']
#     $132call_function.53 = call $128load_global.51(num_of_symbols, func=$128load_global.51, args=[Var(num_of_symbols, simulate.py:43)], kws=(), vararg=None, varkwarg=None, target=None) ['$128load_global.51', '$132call_function.53', 'num_of_symbols']
#     $134get_iter.54 = getiter(value=$132call_function.53) ['$132call_function.53', '$134get_iter.54']
#     $phi136.0 = $134get_iter.54              ['$134get_iter.54', '$phi136.0']
#     jump 136                                 []
# label 136:
#     $136for_iter.1 = iternext(value=$phi136.0) ['$136for_iter.1', '$phi136.0']
#     $136for_iter.2 = pair_first(value=$136for_iter.1) ['$136for_iter.1', '$136for_iter.2']
#     $136for_iter.3 = pair_second(value=$136for_iter.1) ['$136for_iter.1', '$136for_iter.3']
#     $phi140.1 = $136for_iter.2               ['$136for_iter.2', '$phi140.1']
#     branch $136for_iter.3, 140, 1308         ['$136for_iter.3']
# label 140:
#     symbol_counter = $phi140.1               ['$phi140.1', 'symbol_counter']
#     $const144.3 = const(NoneType, None)      ['$const144.3']
#     $const146.4 = const(NoneType, None)      ['$const146.4']
#     $148build_slice.5 = global(slice: <class 'slice'>) ['$148build_slice.5']
#     $148build_slice.6 = call $148build_slice.5($const144.3, $const146.4, func=$148build_slice.5, args=(Var($const144.3, simulate.py:71), Var($const146.4, simulate.py:71)), kws=(), vararg=None, varkwarg=None, target=None) ['$148build_slice.5', '$148build_slice.6', '$const144.3', '$const146.4']
#     $152build_tuple.8 = build_tuple(items=[Var($148build_slice.6, simulate.py:71), Var(prices_start, simulate.py:63)]) ['$148build_slice.6', '$152build_tuple.8', 'prices_start']
#     open_prices = getitem(value=price_data, index=$152build_tuple.8, fn=<built-in function getitem>) ['$152build_tuple.8', 'open_prices', 'price_data']
#     $const160.11 = const(NoneType, None)     ['$const160.11']
#     $const162.12 = const(NoneType, None)     ['$const162.12']
#     $164build_slice.13 = global(slice: <class 'slice'>) ['$164build_slice.13']
#     $164build_slice.14 = call $164build_slice.13($const160.11, $const162.12, func=$164build_slice.13, args=(Var($const160.11, simulate.py:72), Var($const162.12, simulate.py:72)), kws=(), vararg=None, varkwarg=None, target=None) ['$164build_slice.13', '$164build_slice.14', '$const160.11', '$const162.12']
#     $const168.16 = const(int, 1)             ['$const168.16']
#     $170binary_add.17 = prices_start + $const168.16 ['$170binary_add.17', '$const168.16', 'prices_start']
#     $172build_tuple.18 = build_tuple(items=[Var($164build_slice.14, simulate.py:72), Var($170binary_add.17, simulate.py:72)]) ['$164build_slice.14', '$170binary_add.17', '$172build_tuple.18']
#     high_prices = getitem(value=price_data, index=$172build_tuple.18, fn=<built-in function getitem>) ['$172build_tuple.18', 'high_prices', 'price_data']
#     $const180.21 = const(NoneType, None)     ['$const180.21']
#     $const182.22 = const(NoneType, None)     ['$const182.22']
#     $184build_slice.23 = global(slice: <class 'slice'>) ['$184build_slice.23']
#     $184build_slice.24 = call $184build_slice.23($const180.21, $const182.22, func=$184build_slice.23, args=(Var($const180.21, simulate.py:73), Var($const182.22, simulate.py:73)), kws=(), vararg=None, varkwarg=None, target=None) ['$184build_slice.23', '$184build_slice.24', '$const180.21', '$const182.22']
#     $const188.26 = const(int, 2)             ['$const188.26']
#     $190binary_add.27 = prices_start + $const188.26 ['$190binary_add.27', '$const188.26', 'prices_start']
#     $192build_tuple.28 = build_tuple(items=[Var($184build_slice.24, simulate.py:73), Var($190binary_add.27, simulate.py:73)]) ['$184build_slice.24', '$190binary_add.27', '$192build_tuple.28']
#     low_prices = getitem(value=price_data, index=$192build_tuple.28, fn=<built-in function getitem>) ['$192build_tuple.28', 'low_prices', 'price_data']
#     $const200.31 = const(NoneType, None)     ['$const200.31']
#     $const202.32 = const(NoneType, None)     ['$const202.32']
#     $204build_slice.33 = global(slice: <class 'slice'>) ['$204build_slice.33']
#     $204build_slice.34 = call $204build_slice.33($const200.31, $const202.32, func=$204build_slice.33, args=(Var($const200.31, simulate.py:74), Var($const202.32, simulate.py:74)), kws=(), vararg=None, varkwarg=None, target=None) ['$204build_slice.33', '$204build_slice.34', '$const200.31', '$const202.32']
#     $const208.36 = const(int, 3)             ['$const208.36']
#     $210binary_add.37 = prices_start + $const208.36 ['$210binary_add.37', '$const208.36', 'prices_start']
#     $212build_tuple.38 = build_tuple(items=[Var($204build_slice.34, simulate.py:74), Var($210binary_add.37, simulate.py:74)]) ['$204build_slice.34', '$210binary_add.37', '$212build_tuple.38']
#     close_prices = getitem(value=price_data, index=$212build_tuple.38, fn=<built-in function getitem>) ['$212build_tuple.38', 'close_prices', 'price_data']
#     $const220.41 = const(int, 4)             ['$const220.41']
#     $222inplace_add.42 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=prices_start, rhs=$const220.41, static_lhs=Undefined, static_rhs=Undefined) ['$222inplace_add.42', '$const220.41', 'prices_start']
#     prices_start = $222inplace_add.42        ['$222inplace_add.42', 'prices_start']
#     $const228.44 = const(NoneType, None)     ['$const228.44']
#     $const230.45 = const(NoneType, None)     ['$const230.45']
#     $232build_slice.46 = global(slice: <class 'slice'>) ['$232build_slice.46']
#     $232build_slice.47 = call $232build_slice.46($const228.44, $const230.45, func=$232build_slice.46, args=(Var($const228.44, simulate.py:78), Var($const230.45, simulate.py:78)), kws=(), vararg=None, varkwarg=None, target=None) ['$232build_slice.46', '$232build_slice.47', '$const228.44', '$const230.45']
#     $238build_slice.50 = global(slice: <class 'slice'>) ['$238build_slice.50']
#     $238build_slice.51 = call $238build_slice.50(entries_start, entries_end, func=$238build_slice.50, args=(Var(entries_start, simulate.py:65), Var(entries_end, simulate.py:66)), kws=(), vararg=None, varkwarg=None, target=None) ['$238build_slice.50', '$238build_slice.51', 'entries_end', 'entries_start']
#     $240build_tuple.52 = build_tuple(items=[Var($232build_slice.47, simulate.py:78), Var($238build_slice.51, simulate.py:78)]) ['$232build_slice.47', '$238build_slice.51', '$240build_tuple.52']
#     symbol_entries = getitem(value=entries, index=$240build_tuple.52, fn=<built-in function getitem>) ['$240build_tuple.52', 'entries', 'symbol_entries']
#     entries_start = entries_end              ['entries_end', 'entries_start']
#     $254inplace_add.57 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=entries_end, rhs=entries_per_symbol, static_lhs=Undefined, static_rhs=Undefined) ['$254inplace_add.57', 'entries_end', 'entries_per_symbol']
#     entries_end = $254inplace_add.57         ['$254inplace_add.57', 'entries_end']
#     $258load_global.58 = global(range: <class 'range'>) ['$258load_global.58']
#     $262call_function.60 = call $258load_global.58(entries_per_symbol, func=$258load_global.58, args=[Var(entries_per_symbol, simulate.py:64)], kws=(), vararg=None, varkwarg=None, target=None) ['$258load_global.58', '$262call_function.60', 'entries_per_symbol']
#     $264get_iter.61 = getiter(value=$262call_function.60) ['$262call_function.60', '$264get_iter.61']
#     $phi266.1 = $264get_iter.61              ['$264get_iter.61', '$phi266.1']
#     jump 266                                 []
# label 266:
#     $266for_iter.2 = iternext(value=$phi266.1) ['$266for_iter.2', '$phi266.1']
#     $266for_iter.3 = pair_first(value=$266for_iter.2) ['$266for_iter.2', '$266for_iter.3']
#     $266for_iter.4 = pair_second(value=$266for_iter.2) ['$266for_iter.2', '$266for_iter.4']
#     $phi270.2 = $266for_iter.3               ['$266for_iter.3', '$phi270.2']
#     branch $266for_iter.4, 270, 1306         ['$266for_iter.4']
# label 270:
#     indicator_settings_counter = $phi270.2   ['$phi270.2', 'indicator_settings_counter']
#     $const274.4 = const(NoneType, None)      ['$const274.4']
#     $const276.5 = const(NoneType, None)      ['$const276.5']
#     $278build_slice.6 = global(slice: <class 'slice'>) ['$278build_slice.6']
#     $278build_slice.7 = call $278build_slice.6($const274.4, $const276.5, func=$278build_slice.6, args=(Var($const274.4, simulate.py:84), Var($const276.5, simulate.py:84)), kws=(), vararg=None, varkwarg=None, target=None) ['$278build_slice.6', '$278build_slice.7', '$const274.4', '$const276.5']
#     $282build_tuple.9 = build_tuple(items=[Var($278build_slice.7, simulate.py:84), Var(indicator_settings_counter, simulate.py:83)]) ['$278build_slice.7', '$282build_tuple.9', 'indicator_settings_counter']
#     current_indicator_entries = getitem(value=symbol_entries, index=$282build_tuple.9, fn=<built-in function getitem>) ['$282build_tuple.9', 'current_indicator_entries', 'symbol_entries']
#     $288load_global.11 = global(range: <class 'range'>) ['$288load_global.11']
#     $292call_function.13 = call $288load_global.11(total_order_settings, func=$288load_global.11, args=[Var(total_order_settings, simulate.py:43)], kws=(), vararg=None, varkwarg=None, target=None) ['$288load_global.11', '$292call_function.13', 'total_order_settings']
#     $294get_iter.14 = getiter(value=$292call_function.13) ['$292call_function.13', '$294get_iter.14']
#     $phi296.2 = $294get_iter.14              ['$294get_iter.14', '$phi296.2']
#     jump 296                                 []
# label 296:
#     $296for_iter.3 = iternext(value=$phi296.2) ['$296for_iter.3', '$phi296.2']
#     $296for_iter.4 = pair_first(value=$296for_iter.3) ['$296for_iter.3', '$296for_iter.4']
#     $296for_iter.5 = pair_second(value=$296for_iter.3) ['$296for_iter.3', '$296for_iter.5']
#     $phi300.3 = $296for_iter.4               ['$296for_iter.4', '$phi300.3']
#     branch $296for_iter.5, 300, 1296         ['$296for_iter.5']
# label 300:
#     order_settings_counter = $phi300.3       ['$phi300.3', 'order_settings_counter']
#     $302load_global.4 = global(OrderSettings: <class 'quantfreedom.enums.enums.OrderSettings'>) ['$302load_global.4']
#     $const308.7 = const(str, leverage)       ['$const308.7']
#     $312load_attr.9 = getattr(value=os_cart_arrays_tuple, attr=leverage) ['$312load_attr.9', 'os_cart_arrays_tuple']
#     $316binary_subscr.11 = getitem(value=$312load_attr.9, index=order_settings_counter, fn=<built-in function getitem>) ['$312load_attr.9', '$316binary_subscr.11', 'order_settings_counter']
#     $const320.14 = const(str, max_equity_risk_pct) ['$const320.14']
#     $324load_attr.16 = getattr(value=os_cart_arrays_tuple, attr=max_equity_risk_pct) ['$324load_attr.16', 'os_cart_arrays_tuple']
#     $328binary_subscr.18 = getitem(value=$324load_attr.16, index=order_settings_counter, fn=<built-in function getitem>) ['$324load_attr.16', '$328binary_subscr.18', 'order_settings_counter']
#     $const332.21 = const(str, max_equity_risk_value) ['$const332.21']
#     $336load_attr.23 = getattr(value=os_cart_arrays_tuple, attr=max_equity_risk_value) ['$336load_attr.23', 'os_cart_arrays_tuple']
#     $340binary_subscr.25 = getitem(value=$336load_attr.23, index=order_settings_counter, fn=<built-in function getitem>) ['$336load_attr.23', '$340binary_subscr.25', 'order_settings_counter']
#     $const344.28 = const(str, risk_reward)   ['$const344.28']
#     $348load_attr.30 = getattr(value=os_cart_arrays_tuple, attr=risk_reward) ['$348load_attr.30', 'os_cart_arrays_tuple']
#     $352binary_subscr.32 = getitem(value=$348load_attr.30, index=order_settings_counter, fn=<built-in function getitem>) ['$348load_attr.30', '$352binary_subscr.32', 'order_settings_counter']
#     $const356.35 = const(str, size_pct)      ['$const356.35']
#     $360load_attr.37 = getattr(value=os_cart_arrays_tuple, attr=size_pct) ['$360load_attr.37', 'os_cart_arrays_tuple']
#     $364binary_subscr.39 = getitem(value=$360load_attr.37, index=order_settings_counter, fn=<built-in function getitem>) ['$360load_attr.37', '$364binary_subscr.39', 'order_settings_counter']
#     $const368.42 = const(str, size_value)    ['$const368.42']
#     $372load_attr.44 = getattr(value=os_cart_arrays_tuple, attr=size_value) ['$372load_attr.44', 'os_cart_arrays_tuple']
#     $376binary_subscr.46 = getitem(value=$372load_attr.44, index=order_settings_counter, fn=<built-in function getitem>) ['$372load_attr.44', '$376binary_subscr.46', 'order_settings_counter']
#     $const380.49 = const(str, sl_based_on)   ['$const380.49']
#     $384load_attr.51 = getattr(value=os_cart_arrays_tuple, attr=sl_based_on) ['$384load_attr.51', 'os_cart_arrays_tuple']
#     $388binary_subscr.53 = getitem(value=$384load_attr.51, index=order_settings_counter, fn=<built-in function getitem>) ['$384load_attr.51', '$388binary_subscr.53', 'order_settings_counter']
#     $const392.56 = const(str, sl_based_on_add_pct) ['$const392.56']
#     $396load_attr.58 = getattr(value=os_cart_arrays_tuple, attr=sl_based_on_add_pct) ['$396load_attr.58', 'os_cart_arrays_tuple']
#     $400binary_subscr.60 = getitem(value=$396load_attr.58, index=order_settings_counter, fn=<built-in function getitem>) ['$396load_attr.58', '$400binary_subscr.60', 'order_settings_counter']
#     $const404.63 = const(str, sl_based_on_lookback) ['$const404.63']
#     $408load_attr.65 = getattr(value=os_cart_arrays_tuple, attr=sl_based_on_lookback) ['$408load_attr.65', 'os_cart_arrays_tuple']
#     $412binary_subscr.67 = getitem(value=$408load_attr.65, index=order_settings_counter, fn=<built-in function getitem>) ['$408load_attr.65', '$412binary_subscr.67', 'order_settings_counter']
#     $const416.70 = const(str, sl_pct)        ['$const416.70']
#     $420load_attr.72 = getattr(value=os_cart_arrays_tuple, attr=sl_pct) ['$420load_attr.72', 'os_cart_arrays_tuple']
#     $424binary_subscr.74 = getitem(value=$420load_attr.72, index=order_settings_counter, fn=<built-in function getitem>) ['$420load_attr.72', '$424binary_subscr.74', 'order_settings_counter']
#     $const428.77 = const(str, sl_to_be_based_on) ['$const428.77']
#     $432load_attr.79 = getattr(value=os_cart_arrays_tuple, attr=sl_to_be_based_on) ['$432load_attr.79', 'os_cart_arrays_tuple']
#     $436binary_subscr.81 = getitem(value=$432load_attr.79, index=order_settings_counter, fn=<built-in function getitem>) ['$432load_attr.79', '$436binary_subscr.81', 'order_settings_counter']
#     $const440.84 = const(str, sl_to_be_zero_or_entry) ['$const440.84']
#     $444load_attr.86 = getattr(value=os_cart_arrays_tuple, attr=sl_to_be_zero_or_entry) ['$444load_attr.86', 'os_cart_arrays_tuple']
#     $448binary_subscr.88 = getitem(value=$444load_attr.86, index=order_settings_counter, fn=<built-in function getitem>) ['$444load_attr.86', '$448binary_subscr.88', 'order_settings_counter']
#     $const452.91 = const(str, sl_to_be_when_pct_from_avg_entry) ['$const452.91']
#     $456load_attr.93 = getattr(value=os_cart_arrays_tuple, attr=sl_to_be_when_pct_from_avg_entry) ['$456load_attr.93', 'os_cart_arrays_tuple']
#     $460binary_subscr.95 = getitem(value=$456load_attr.93, index=order_settings_counter, fn=<built-in function getitem>) ['$456load_attr.93', '$460binary_subscr.95', 'order_settings_counter']
#     $const464.98 = const(str, tp_pct)        ['$const464.98']
#     $468load_attr.100 = getattr(value=os_cart_arrays_tuple, attr=tp_pct) ['$468load_attr.100', 'os_cart_arrays_tuple']
#     $472binary_subscr.102 = getitem(value=$468load_attr.100, index=order_settings_counter, fn=<built-in function getitem>) ['$468load_attr.100', '$472binary_subscr.102', 'order_settings_counter']
#     $const476.105 = const(str, trail_sl_based_on) ['$const476.105']
#     $480load_attr.107 = getattr(value=os_cart_arrays_tuple, attr=trail_sl_based_on) ['$480load_attr.107', 'os_cart_arrays_tuple']
#     $484binary_subscr.109 = getitem(value=$480load_attr.107, index=order_settings_counter, fn=<built-in function getitem>) ['$480load_attr.107', '$484binary_subscr.109', 'order_settings_counter']
#     $const488.112 = const(str, trail_sl_by_pct) ['$const488.112']
#     $492load_attr.114 = getattr(value=os_cart_arrays_tuple, attr=trail_sl_by_pct) ['$492load_attr.114', 'os_cart_arrays_tuple']
#     $496binary_subscr.116 = getitem(value=$492load_attr.114, index=order_settings_counter, fn=<built-in function getitem>) ['$492load_attr.114', '$496binary_subscr.116', 'order_settings_counter']
#     $const500.119 = const(str, trail_sl_when_pct_from_avg_entry) ['$const500.119']
#     $504load_attr.121 = getattr(value=os_cart_arrays_tuple, attr=trail_sl_when_pct_from_avg_entry) ['$504load_attr.121', 'os_cart_arrays_tuple']
#     $508binary_subscr.123 = getitem(value=$504load_attr.121, index=order_settings_counter, fn=<built-in function getitem>) ['$504load_attr.121', '$508binary_subscr.123', 'order_settings_counter']
#     order_settings = call $302load_global.4(func=$302load_global.4, args=[], kws=[('leverage', Var($316binary_subscr.11, simulate.py:88)), ('max_equity_risk_pct', Var($328binary_subscr.18, simulate.py:89)), ('max_equity_risk_value', Var($340binary_subscr.25, simulate.py:92)), ('risk_reward', Var($352binary_subscr.32, simulate.py:95)), ('size_pct', Var($364binary_subscr.39, simulate.py:98)), ('size_value', Var($376binary_subscr.46, simulate.py:99)), ('sl_based_on', Var($388binary_subscr.53, simulate.py:100)), ('sl_based_on_add_pct', Var($400binary_subscr.60, simulate.py:103)), ('sl_based_on_lookback', Var($412binary_subscr.67, simulate.py:106)), ('sl_pct', Var($424binary_subscr.74, simulate.py:109)), ('sl_to_be_based_on', Var($436binary_subscr.81, simulate.py:110)), ('sl_to_be_zero_or_entry', Var($448binary_subscr.88, simulate.py:113)), ('sl_to_be_when_pct_from_avg_entry', Var($460binary_subscr.95, simulate.py:116)), ('tp_pct', Var($472binary_subscr.102, simulate.py:119)), ('trail_sl_based_on', Var($484binary_subscr.109, simulate.py:120)), ('trail_sl_by_pct', Var($496binary_subscr.116, simulate.py:123)), ('trail_sl_when_pct_from_avg_entry', Var($508binary_subscr.123, simulate.py:126))], vararg=None, varkwarg=None, target=None) ['$302load_global.4', '$316binary_subscr.11', '$328binary_subscr.18', '$340binary_subscr.25', '$352binary_subscr.32', '$364binary_subscr.39', '$376binary_subscr.46', '$388binary_subscr.53', '$400binary_subscr.60', '$412binary_subscr.67', '$424binary_subscr.74', '$436binary_subscr.81', '$448binary_subscr.88', '$460binary_subscr.95', '$472binary_subscr.102', '$484binary_subscr.109', '$496binary_subscr.116', '$508binary_subscr.123', 'order_settings']
#     $516load_global.127 = global(AccountState: <class 'quantfreedom.enums.enums.AccountState'>) ['$516load_global.127']
#     $520load_attr.129 = getattr(value=static_variables_tuple, attr=equity) ['$520load_attr.129', 'static_variables_tuple']
#     $const522.130 = const(float, 0.0)        ['$const522.130']
#     $const524.131 = const(float, 0.0)        ['$const524.131']
#     $528load_attr.133 = getattr(value=static_variables_tuple, attr=equity) ['$528load_attr.133', 'static_variables_tuple']
#     account_state = call $516load_global.127(func=$516load_global.127, args=[], kws=[('available_balance', Var($520load_attr.129, simulate.py:132)), ('cash_borrowed', Var($const522.130, simulate.py:133)), ('cash_used', Var($const524.131, simulate.py:134)), ('equity', Var($528load_attr.133, simulate.py:135))], vararg=None, varkwarg=None, target=None) ['$516load_global.127', '$520load_attr.129', '$528load_attr.133', '$const522.130', '$const524.131', 'account_state']
#     $536load_global.136 = global(OrderResult: <class 'quantfreedom.enums.enums.OrderResult'>) ['$536load_global.136']
#     $const542.139 = const(str, average_entry) ['$const542.139']
#     $const544.140 = const(float, 0.0)        ['$const544.140']
#     $const548.143 = const(str, fees_paid)    ['$const548.143']
#     $const550.144 = const(float, 0.0)        ['$const550.144']
#     $const554.147 = const(str, leverage)     ['$const554.147']
#     $const556.148 = const(float, 0.0)        ['$const556.148']
#     $const560.151 = const(str, liq_price)    ['$const560.151']
#     $562load_global.152 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$562load_global.152']
#     $564load_attr.153 = getattr(value=$562load_global.152, attr=nan) ['$562load_global.152', '$564load_attr.153']
#     $const568.156 = const(str, moved_sl_to_be) ['$const568.156']
#     $const570.157 = const(bool, False)       ['$const570.157']
#     $const574.160 = const(str, order_status) ['$const574.160']
#     $const576.161 = const(int, 0)            ['$const576.161']
#     $const580.164 = const(str, order_status_info) ['$const580.164']
#     $const582.165 = const(int, 0)            ['$const582.165']
#     $const586.168 = const(str, order_type)   ['$const586.168']
#     $590load_attr.170 = getattr(value=static_variables_tuple, attr=order_type) ['$590load_attr.170', 'static_variables_tuple']
#     $const594.173 = const(str, pct_chg_trade) ['$const594.173']
#     $const596.174 = const(float, 0.0)        ['$const596.174']
#     $const600.177 = const(str, position)     ['$const600.177']
#     $const602.178 = const(float, 0.0)        ['$const602.178']
#     $const606.181 = const(str, price)        ['$const606.181']
#     $const608.182 = const(float, 0.0)        ['$const608.182']
#     $const612.185 = const(str, realized_pnl) ['$const612.185']
#     $const614.186 = const(float, 0.0)        ['$const614.186']
#     $const618.189 = const(str, size_value)   ['$const618.189']
#     $const620.190 = const(float, 0.0)        ['$const620.190']
#     $const624.193 = const(str, sl_pct)       ['$const624.193']
#     $const626.194 = const(float, 0.0)        ['$const626.194']
#     $const630.197 = const(str, sl_price)     ['$const630.197']
#     $const632.198 = const(float, 0.0)        ['$const632.198']
#     $const636.201 = const(str, tp_pct)       ['$const636.201']
#     $const638.202 = const(float, 0.0)        ['$const638.202']
#     $const642.205 = const(str, tp_price)     ['$const642.205']
#     $const644.206 = const(float, 0.0)        ['$const644.206']
#     order_result = call $536load_global.136(func=$536load_global.136, args=[], kws=[('average_entry', Var($const544.140, simulate.py:140)), ('fees_paid', Var($const550.144, simulate.py:141)), ('leverage', Var($const556.148, simulate.py:142)), ('liq_price', Var($564load_attr.153, simulate.py:143)), ('moved_sl_to_be', Var($const570.157, simulate.py:144)), ('order_status', Var($const576.161, simulate.py:145)), ('order_status_info', Var($const582.165, simulate.py:146)), ('order_type', Var($590load_attr.170, simulate.py:147)), ('pct_chg_trade', Var($const596.174, simulate.py:148)), ('position', Var($const602.178, simulate.py:149)), ('price', Var($const608.182, simulate.py:150)), ('realized_pnl', Var($const614.186, simulate.py:151)), ('size_value', Var($const620.190, simulate.py:152)), ('sl_pct', Var($const626.194, simulate.py:153)), ('sl_price', Var($const632.198, simulate.py:154)), ('tp_pct', Var($const638.202, simulate.py:155)), ('tp_price', Var($const644.206, simulate.py:156))], vararg=None, varkwarg=None, target=None) ['$536load_global.136', '$564load_attr.153', '$590load_attr.170', '$const544.140', '$const550.144', '$const556.148', '$const570.157', '$const576.161', '$const582.165', '$const596.174', '$const602.178', '$const608.182', '$const614.186', '$const620.190', '$const626.194', '$const632.198', '$const638.202', '$const644.206', 'order_result']
#     $const652.210 = const(int, 0)            ['$const652.210']
#     $const656.212 = const(int, 0)            ['$const656.212']
#     strat_records_filled[$const656.212] = $const652.210 ['$const652.210', '$const656.212', 'strat_records_filled']
#     $660load_global.213 = global(range: <class 'range'>) ['$660load_global.213']
#     $664call_function.215 = call $660load_global.213(total_bars, func=$660load_global.213, args=[Var(total_bars, simulate.py:43)], kws=(), vararg=None, varkwarg=None, target=None) ['$660load_global.213', '$664call_function.215', 'total_bars']
#     $666get_iter.216 = getiter(value=$664call_function.215) ['$664call_function.215', '$666get_iter.216']
#     $phi668.3 = $666get_iter.216             ['$666get_iter.216', '$phi668.3']
#     jump 668                                 []
# label 668:
#     $668for_iter.4 = iternext(value=$phi668.3) ['$668for_iter.4', '$phi668.3']
#     $668for_iter.5 = pair_first(value=$668for_iter.4) ['$668for_iter.4', '$668for_iter.5']
#     $668for_iter.6 = pair_second(value=$668for_iter.4) ['$668for_iter.4', '$668for_iter.6']
#     $phi670.4 = $668for_iter.5               ['$668for_iter.5', '$phi670.4']
#     branch $668for_iter.6, 670, 1116         ['$668for_iter.6']
# label 670:
#     bar = $phi670.4                          ['$phi670.4', 'bar']
#     $674load_attr.6 = getattr(value=account_state, attr=available_balance) ['$674load_attr.6', 'account_state']
#     $const676.7 = const(int, 5)              ['$const676.7']
#     $678compare_op.8 = $674load_attr.6 < $const676.7 ['$674load_attr.6', '$678compare_op.8', '$const676.7']
#     bool680 = global(bool: <class 'bool'>)   ['bool680']
#     $680pred = call bool680($678compare_op.8, func=bool680, args=(Var($678compare_op.8, simulate.py:162),), kws=(), vararg=None, varkwarg=None, target=None) ['$678compare_op.8', '$680pred', 'bool680']
#     branch $680pred, 684, 688                ['$680pred']
# label 684:
#     jump 1116                                []
# label 688:
#     $692binary_subscr.6 = getitem(value=current_indicator_entries, index=bar, fn=<built-in function getitem>) ['$692binary_subscr.6', 'bar', 'current_indicator_entries']
#     bool694 = global(bool: <class 'bool'>)   ['bool694']
#     $694pred = call bool694($692binary_subscr.6, func=bool694, args=(Var($692binary_subscr.6, simulate.py:165),), kws=(), vararg=None, varkwarg=None, target=None) ['$692binary_subscr.6', '$694pred', 'bool694']
#     branch $694pred, 698, 980                ['$694pred']
# label 698:
#     $698load_global.4 = global(np: <module 'numpy' from 'e:\\Coding\\virtual environments\\qfFree\\lib\\site-packages\\numpy\\__init__.py'>) ['$698load_global.4']
#     $700load_method.5 = getattr(value=$698load_global.4, attr=isnan) ['$698load_global.4', '$700load_method.5']
#     $704load_attr.7 = getattr(value=order_settings, attr=sl_based_on) ['$704load_attr.7', 'order_settings']
#     $706call_method.8 = call $700load_method.5($704load_attr.7, func=$700load_method.5, args=[Var($704load_attr.7, simulate.py:166)], kws=(), vararg=None, varkwarg=None, target=None) ['$700load_method.5', '$704load_attr.7', '$706call_method.8']
#     bool708 = global(bool: <class 'bool'>)   ['bool708']
#     $708pred = call bool708($706call_method.8, func=bool708, args=(Var($706call_method.8, simulate.py:166),), kws=(), vararg=None, varkwarg=None, target=None) ['$706call_method.8', '$708pred', 'bool708']
#     branch $708pred, 880, 712                ['$708pred']
# label 712:
#     $712load_global.4 = global(int: <class 'int'>) ['$712load_global.4']
#     $718load_attr.7 = getattr(value=order_settings, attr=sl_based_on_lookback) ['$718load_attr.7', 'order_settings']
#     $720binary_subtract.8 = bar - $718load_attr.7 ['$718load_attr.7', '$720binary_subtract.8', 'bar']
#     lb = call $712load_global.4($720binary_subtract.8, func=$712load_global.4, args=[Var($720binary_subtract.8, simulate.py:167)], kws=(), vararg=None, varkwarg=None, target=None) ['$712load_global.4', '$720binary_subtract.8', 'lb']
#     $const728.11 = const(int, 0)             ['$const728.11']
#     $730compare_op.12 = lb < $const728.11    ['$730compare_op.12', '$const728.11', 'lb']
#     bool732 = global(bool: <class 'bool'>)   ['bool732']
#     $732pred = call bool732($730compare_op.12, func=bool732, args=(Var($730compare_op.12, simulate.py:168),), kws=(), vararg=None, varkwarg=None, target=None) ['$730compare_op.12', '$732pred', 'bool732']
#     branch $732pred, 736, 808                ['$732pred']
# label 736:
#     $736load_global.4 = global(PriceArrayTuple: <class 'quantfreedom.enums.enums.PriceArrayTuple'>) ['$736load_global.4']
#     $742binary_subscr.7 = getitem(value=open_prices, index=bar, fn=<built-in function getitem>) ['$742binary_subscr.7', 'bar', 'open_prices']
#     $const746.9 = const(int, 0)              ['$const746.9']
#     $const750.11 = const(int, 1)             ['$const750.11']
#     $752binary_add.12 = bar + $const750.11   ['$752binary_add.12', '$const750.11', 'bar']
#     $754build_slice.13 = global(slice: <class 'slice'>) ['$754build_slice.13']
#     $754build_slice.14 = call $754build_slice.13($const746.9, $752binary_add.12, func=$754build_slice.13, args=(Var($const746.9, simulate.py:171), Var($752binary_add.12, simulate.py:171)), kws=(), vararg=None, varkwarg=None, target=None) ['$752binary_add.12', '$754build_slice.13', '$754build_slice.14', '$const746.9']
#     $756binary_subscr.15 = getitem(value=open_prices, index=$754build_slice.14, fn=<built-in function getitem>) ['$754build_slice.14', '$756binary_subscr.15', 'open_prices']
#     $const760.17 = const(int, 0)             ['$const760.17']
#     $const764.19 = const(int, 1)             ['$const764.19']
#     $766binary_add.20 = bar + $const764.19   ['$766binary_add.20', '$const764.19', 'bar']
#     $768build_slice.21 = global(slice: <class 'slice'>) ['$768build_slice.21']
#     $768build_slice.22 = call $768build_slice.21($const760.17, $766binary_add.20, func=$768build_slice.21, args=(Var($const760.17, simulate.py:172), Var($766binary_add.20, simulate.py:172)), kws=(), vararg=None, varkwarg=None, target=None) ['$766binary_add.20', '$768build_slice.21', '$768build_slice.22', '$const760.17']
#     $770binary_subscr.23 = getitem(value=high_prices, index=$768build_slice.22, fn=<built-in function getitem>) ['$768build_slice.22', '$770binary_subscr.23', 'high_prices']
#     $const774.25 = const(int, 0)             ['$const774.25']
#     $const778.27 = const(int, 1)             ['$const778.27']
#     $780binary_add.28 = bar + $const778.27   ['$780binary_add.28', '$const778.27', 'bar']
#     $782build_slice.29 = global(slice: <class 'slice'>) ['$782build_slice.29']
#     $782build_slice.30 = call $782build_slice.29($const774.25, $780binary_add.28, func=$782build_slice.29, args=(Var($const774.25, simulate.py:173), Var($780binary_add.28, simulate.py:173)), kws=(), vararg=None, varkwarg=None, target=None) ['$780binary_add.28', '$782build_slice.29', '$782build_slice.30', '$const774.25']
#     $784binary_subscr.31 = getitem(value=low_prices, index=$782build_slice.30, fn=<built-in function getitem>) ['$782build_slice.30', '$784binary_subscr.31', 'low_prices']
#     $const788.33 = const(int, 0)             ['$const788.33']
#     $const792.35 = const(int, 1)             ['$const792.35']
#     $794binary_add.36 = bar + $const792.35   ['$794binary_add.36', '$const792.35', 'bar']
#     $796build_slice.37 = global(slice: <class 'slice'>) ['$796build_slice.37']
#     $796build_slice.38 = call $796build_slice.37($const788.33, $794binary_add.36, func=$796build_slice.37, args=(Var($const788.33, simulate.py:174), Var($794binary_add.36, simulate.py:174)), kws=(), vararg=None, varkwarg=None, target=None) ['$794binary_add.36', '$796build_slice.37', '$796build_slice.38', '$const788.33']
#     $798binary_subscr.39 = getitem(value=close_prices, index=$796build_slice.38, fn=<built-in function getitem>) ['$796build_slice.38', '$798binary_subscr.39', 'close_prices']
#     prices = call $736load_global.4(func=$736load_global.4, args=[], kws=[('entry', Var($742binary_subscr.7, simulate.py:170)), ('open', Var($756binary_subscr.15, simulate.py:171)), ('high', Var($770binary_subscr.23, simulate.py:172)), ('low', Var($784binary_subscr.31, simulate.py:173)), ('close', Var($798binary_subscr.39, simulate.py:174))], vararg=None, varkwarg=None, target=None) ['$736load_global.4', '$742binary_subscr.7', '$756binary_subscr.15', '$770binary_subscr.23', '$784binary_subscr.31', '$798binary_subscr.39', 'prices']
#     jump 934                                 []
# label 808:
#     $808load_global.4 = global(PriceArrayTuple: <class 'quantfreedom.enums.enums.PriceArrayTuple'>) ['$808load_global.4']
#     $814binary_subscr.7 = getitem(value=open_prices, index=bar, fn=<built-in function getitem>) ['$814binary_subscr.7', 'bar', 'open_prices']
#     $const822.11 = const(int, 1)             ['$const822.11']
#     $824binary_add.12 = bar + $const822.11   ['$824binary_add.12', '$const822.11', 'bar']
#     $826build_slice.13 = global(slice: <class 'slice'>) ['$826build_slice.13']
#     $826build_slice.14 = call $826build_slice.13(lb, $824binary_add.12, func=$826build_slice.13, args=(Var(lb, simulate.py:167), Var($824binary_add.12, simulate.py:179)), kws=(), vararg=None, varkwarg=None, target=None) ['$824binary_add.12', '$826build_slice.13', '$826build_slice.14', 'lb']
#     $828binary_subscr.15 = getitem(value=open_prices, index=$826build_slice.14, fn=<built-in function getitem>) ['$826build_slice.14', '$828binary_subscr.15', 'open_prices']
#     $const836.19 = const(int, 1)             ['$const836.19']
#     $838binary_add.20 = bar + $const836.19   ['$838binary_add.20', '$const836.19', 'bar']
#     $840build_slice.21 = global(slice: <class 'slice'>) ['$840build_slice.21']
#     $840build_slice.22 = call $840build_slice.21(lb, $838binary_add.20, func=$840build_slice.21, args=(Var(lb, simulate.py:167), Var($838binary_add.20, simulate.py:180)), kws=(), vararg=None, varkwarg=None, target=None) ['$838binary_add.20', '$840build_slice.21', '$840build_slice.22', 'lb']
#     $842binary_subscr.23 = getitem(value=high_prices, index=$840build_slice.22, fn=<built-in function getitem>) ['$840build_slice.22', '$842binary_subscr.23', 'high_prices']
#     $const850.27 = const(int, 1)             ['$const850.27']
#     $852binary_add.28 = bar + $const850.27   ['$852binary_add.28', '$const850.27', 'bar']
#     $854build_slice.29 = global(slice: <class 'slice'>) ['$854build_slice.29']
#     $854build_slice.30 = call $854build_slice.29(lb, $852binary_add.28, func=$854build_slice.29, args=(Var(lb, simulate.py:167), Var($852binary_add.28, simulate.py:181)), kws=(), vararg=None, varkwarg=None, target=None) ['$852binary_add.28', '$854build_slice.29', '$854build_slice.30', 'lb']
#     $856binary_subscr.31 = getitem(value=low_prices, index=$854build_slice.30, fn=<built-in function getitem>) ['$854build_slice.30', '$856binary_subscr.31', 'low_prices']
#     $const864.35 = const(int, 1)             ['$const864.35']
#     $866binary_add.36 = bar + $const864.35   ['$866binary_add.36', '$const864.35', 'bar']
#     $868build_slice.37 = global(slice: <class 'slice'>) ['$868build_slice.37']
#     $868build_slice.38 = call $868build_slice.37(lb, $866binary_add.36, func=$868build_slice.37, args=(Var(lb, simulate.py:167), Var($866binary_add.36, simulate.py:182)), kws=(), vararg=None, varkwarg=None, target=None) ['$866binary_add.36', '$868build_slice.37', '$868build_slice.38', 'lb']
#     $870binary_subscr.39 = getitem(value=close_prices, index=$868build_slice.38, fn=<built-in function getitem>) ['$868build_slice.38', '$870binary_subscr.39', 'close_prices']
#     prices = call $808load_global.4(func=$808load_global.4, args=[], kws=[('entry', Var($814binary_subscr.7, simulate.py:178)), ('open', Var($828binary_subscr.15, simulate.py:179)), ('high', Var($842binary_subscr.23, simulate.py:180)), ('low', Var($856binary_subscr.31, simulate.py:181)), ('close', Var($870binary_subscr.39, simulate.py:182))], vararg=None, varkwarg=None, target=None) ['$808load_global.4', '$814binary_subscr.7', '$828binary_subscr.15', '$842binary_subscr.23', '$856binary_subscr.31', '$870binary_subscr.39', 'prices']
#     jump 934                                 []
# label 880:
#     $880load_global.4 = global(PriceArrayTuple: <class 'quantfreedom.enums.enums.PriceArrayTuple'>) ['$880load_global.4']
#     $886binary_subscr.7 = getitem(value=open_prices, index=bar, fn=<built-in function getitem>) ['$886binary_subscr.7', 'bar', 'open_prices']
#     $const890.9 = const(int, 0)              ['$const890.9']
#     $const892.10 = const(int, 1)             ['$const892.10']
#     $894build_slice.11 = global(slice: <class 'slice'>) ['$894build_slice.11']
#     $894build_slice.12 = call $894build_slice.11($const890.9, $const892.10, func=$894build_slice.11, args=(Var($const890.9, simulate.py:187), Var($const892.10, simulate.py:187)), kws=(), vararg=None, varkwarg=None, target=None) ['$894build_slice.11', '$894build_slice.12', '$const890.9', '$const892.10']
# ...
#  $982load_attr.5 := float64,
#  $986compare_op.7 := bool,
#  $988pred := bool,
#  $98load_attr.41 := UniTuple(int64 x 2),
#  $992load_global.4 := class(<class 'quantfreedom.enums.enums.PriceFloatTuple'>),
#  $998binary_subscr.7 := float64,
#  $const100.42 := Literal[int](1),
#  $const1096.19 := Literal[int](0),
#  $const1132.11 := Literal[int](100),
#  $const1152.4 := Literal[int](0),
#  $const1156.6 := Literal[int](0),
#  $const1168.12 := Literal[str](real_pnl),
#  $const1178.17 := Literal[str](real_pnl),
#  $const1208.5 := Literal[int](0),
#  $const1288.25 := Literal[int](1),
#  $const1298.3 := Literal[int](1),
#  $const1310.1 := none,
#  $const1320.7 := none,
#  $const144.3 := none,
#  $const146.4 := none,
#  $const160.11 := none,
#  $const162.12 := none,
#  $const168.16 := Literal[int](1),
#  $const180.21 := none,
#  $const182.22 := none,
#  $const188.26 := Literal[int](2),
#  $const200.31 := none,
#  $const202.32 := none,
#  $const208.36 := Literal[int](3),
#  $const220.41 := Literal[int](4),
#  $const228.44 := none,
#  $const230.45 := none,
#  $const274.4 := none,
#  $const276.5 := none,
#  $const308.7 := Literal[str](leverage),
#  $const320.14 := Literal[str](max_equity_risk_pct),
#  $const332.21 := Literal[str](max_equity_risk_value),
#  $const344.28 := Literal[str](risk_reward),
#  $const356.35 := Literal[str](size_pct),
#  $const368.42 := Literal[str](size_value),
#  $const380.49 := Literal[str](sl_based_on),
#  $const392.56 := Literal[str](sl_based_on_add_pct),
#  $const404.63 := Literal[str](sl_based_on_lookback),
#  $const416.70 := Literal[str](sl_pct),
#  $const428.77 := Literal[str](sl_to_be_based_on),
#  $const440.84 := Literal[str](sl_to_be_zero_or_entry),
#  $const452.91 := Literal[str](sl_to_be_when_pct_from_avg_entry),
#  $const464.98 := Literal[str](tp_pct),
#  $const476.105 := Literal[str](trail_sl_based_on),
#  $const488.112 := Literal[str](trail_sl_by_pct),
#  $const500.119 := Literal[str](trail_sl_when_pct_from_avg_entry),
#  $const522.130 := float64,
#  $const524.131 := float64,
#  $const542.139 := Literal[str](average_entry),
#  $const544.140 := float64,
#  $const548.143 := Literal[str](fees_paid),
#  $const550.144 := float64,
#  $const554.147 := Literal[str](leverage),
#  $const556.148 := float64,
#  $const560.151 := Literal[str](liq_price),
#  $const568.156 := Literal[str](moved_sl_to_be),
#  $const570.157 := Literal[bool](False),
#  $const574.160 := Literal[str](order_status),
#  $const576.161 := Literal[int](0),
#  $const580.164 := Literal[str](order_status_info),
#  $const582.165 := Literal[int](0),
#  $const586.168 := Literal[str](order_type),
#  $const594.173 := Literal[str](pct_chg_trade),
#  $const596.174 := float64,
#  $const600.177 := Literal[str](position),
#  $const602.178 := float64,
#  $const606.181 := Literal[str](price),
#  $const608.182 := float64,
#  $const612.185 := Literal[str](realized_pnl),
#  $const614.186 := float64,
#  $const618.189 := Literal[str](size_value),
#  $const620.190 := float64,
#  $const624.193 := Literal[str](sl_pct),
#  $const626.194 := float64,
#  $const630.197 := Literal[str](sl_price),
#  $const632.198 := float64,
#  $const636.201 := Literal[str](tp_pct),
#  $const638.202 := float64,
#  $const64.27 := Literal[int](3),
#  $const642.205 := Literal[str](tp_price),
#  $const644.206 := float64,
#  $const652.210 := Literal[int](0),
#  $const656.212 := Literal[int](0),
#  $const676.7 := Literal[int](5),
#  $const728.11 := Literal[int](0),
#  $const746.9 := Literal[int](0),
#  $const750.11 := Literal[int](1),
#  $const760.17 := Literal[int](0),
#  $const764.19 := Literal[int](1),
#  $const774.25 := Literal[int](0),
#  $const778.27 := Literal[int](1),
#  $const788.33 := Literal[int](0),
#  $const792.35 := Literal[int](1),
#  $const82.35 := Literal[int](0),
#  $const822.11 := Literal[int](1),
#  $const836.19 := Literal[int](1),
#  $const850.27 := Literal[int](1),
#  $const864.35 := Literal[int](1),
#  $const890.9 := Literal[int](0),
#  $const892.10 := Literal[int](1),
#  $const900.15 := Literal[int](0),
#  $const902.16 := Literal[int](1),
#  $const910.21 := Literal[int](0),
#  $const912.22 := Literal[int](1),
#  $const920.27 := Literal[int](0),
#  $const922.28 := Literal[int](1),
#  $const964.19 := Literal[int](0),
#  $const984.6 := Literal[int](0),
#  $phi136.0 := range_iter_int64,
#  $phi140.1 := int64,
#  $phi266.1 := range_iter_int64,
#  $phi270.2 := int64,
#  $phi296.2 := range_iter_int64,
#  $phi300.3 := int64,
#  $phi668.3 := range_iter_int64,
#  $phi670.4 := int64,
#  account_state := AccountState(float64 x 4),
#  account_state.1 := AccountState(float64 x 4),
#  account_state.2 := <undecided>,
#  account_state.3 := AccountState(float64 x 4),
#  account_state.4 := AccountState(float64 x 4),
#  account_state.5 := AccountState(float64 x 4),
#  arg.entries := array(bool, 2d, C),
#  arg.num_of_symbols := int64,
#  arg.os_cart_arrays_tuple := OrderSettingsArrays(array(float64, 1d, C) x 17),
#  arg.price_data := array(float64, 2d, F),
#  arg.static_variables_tuple := StaticVariables(float64, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64, int64, float64),
#  arg.total_bars := int64,
#  arg.total_indicator_settings := int64,
#  arg.total_order_settings := int64,
#  array_size := int64,
#  bar := int64,
#  bool1062 := Function(<class 'bool'>),
#  bool1146 := Function(<class 'bool'>),
#  bool1200 := Function(<class 'bool'>),
#  bool1236 := Function(<class 'bool'>),
#  bool680 := Function(<class 'bool'>),
#  bool694 := Function(<class 'bool'>),
#  bool708 := Function(<class 'bool'>),
#  bool732 := Function(<class 'bool'>),
#  bool988 := Function(<class 'bool'>),
#  close_prices := array(float64, 1d, F),
#  current_indicator_entries := array(bool, 1d, A),
#  entries := array(bool, 2d, C),
#  entries_col := Literal[int](0),
#  entries_col.1 := int64,
#  entries_col.2 := int64,
#  entries_col.3 := int64,
#  entries_end := int64,
#  entries_end.1 := int64,
#  entries_end.2 := int64,
#  entries_per_symbol := int64,
#  entries_start := Literal[int](0),
#  entries_start.1 := int64,
#  entries_start.2 := int64,
#  gains_pct := float64,
#  high_prices := array(float64, 1d, F),
#  indicator_settings_counter := int64,
#  lb := int64,
#  low_prices := array(float64, 1d, F),
#  num_of_symbols := int64,
#  open_prices := array(float64, 1d, F),
#  order_result := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.1 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.2 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.3 := <undecided>,
#  order_result.4 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.5 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_result.6 := OrderResult(float64, float64, float64, float64, bool, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64),
#  order_settings := OrderSettings(float64 x 17),
#  order_settings_counter := int64,
#  order_settings_result_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],leverage[type=float64;offset=8],max_equity_risk_pct[type=float64;offset=16],max_equity_risk_value[type=float64;offset=24],risk_reward[type=float64;offset=32],size_pct[type=float64;offset=40],size_value[type=float64;offset=48],sl_based_on[type=float64;offset=56],sl_based_on_add_pct[type=float64;offset=64],sl_based_on_lookback[type=float64;offset=72],sl_pct[type=float64;offset=80],sl_to_be_based_on[type=float64;offset=88],sl_to_be_when_pct_from_avg_entry[type=float64;offset=96],sl_to_be_zero_or_entry[type=float64;offset=104],tp_pct[type=float64;offset=112],trail_sl_based_on[type=float64;offset=120],trail_sl_by_pct[type=float64;offset=128],trail_sl_when_pct_from_avg_entry[type=float64;offset=136];144;True), 1d, C),
#  os_cart_arrays_tuple := OrderSettingsArrays(array(float64, 1d, C) x 17),
#  price_data := array(float64, 2d, F),
#  prices := Literal[int](0),
#  prices.1 := PriceArrayTuple(float64, array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F)),
#  prices.2 := PriceArrayTuple(float64, array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F)),
#  prices.3 := PriceArrayTuple(float64, array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F)),
#  prices.4 := PriceFloatTuple(float64 x 5),
#  prices.5 := PriceArrayTuple(float64, array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F), array(float64, 1d, F)),
#  prices_start := Literal[int](0),
#  prices_start.1 := int64,
#  prices_start.2 := int64,
#  result_records_filled := Literal[int](0),
#  result_records_filled.1 := int64,
#  result_records_filled.2 := int64,
#  result_records_filled.3 := int64,
#  result_records_filled.4 := int64,
#  result_records_filled.5 := int64,
#  static_variables_tuple := StaticVariables(float64, int64, int64, int64, float64, float64, float64, float64, float64, float64, float64, float64, float64, int64, float64),
#  strat_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],or_set[type=int32;offset=8],real_pnl[type=float64;offset=16],equity[type=float64;offset=24];32;True), 1d, C),
#  strat_records_filled := array(int64, 1d, C),
#  strategy_result_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],or_set[type=int32;offset=8],total_trades[type=float64;offset=16],gains_pct[type=float64;offset=24],win_rate[type=float64;offset=32],to_the_upside[type=float64;offset=40],total_pnl[type=float64;offset=48],ending_eq[type=float64;offset=56];64;True), 1d, C),
#  symbol_counter := int64,
#  symbol_entries := array(bool, 2d, A),
#  temp_strat_records := array(Record(symbol[type=int32;offset=0],entries_col[type=int32;offset=4],or_set[type=int32;offset=8],real_pnl[type=float64;offset=16],equity[type=float64;offset=24];32;True), 1d, C),
#  to_the_upside := float64,
#  total_bars := int64,
#  total_indicator_settings := int64,
#  total_order_settings := int64,
#  wins_and_losses_array := array(float64, 1d, C),
#  wins_and_losses_array_no_be := array(float64, 1d, C)]
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 strat_results_df, settings_results_df = sm.backtest_df(
#       2     price_data=price_data,
#       3     static_variables_tuple=static_vars,
#       4     order_settings_arrays_tuple=order_settings,
#       5 )
#
# File e:\coding\backtesters\quantfreedom\quantfreedom\base\strategy_maker_cls.py:130, in StrategyMaker.backtest_df(self, price_data, static_variables_tuple, order_settings_arrays_tuple)
#     127 self.price_data = price_data
#     128 self.static_vars = static_variables_tuple
# --> 130 self.strat_results_df, self.settings_results_df = backtest_df_only(
#     131     price_data=price_data,
#     132     entries=entries,
#     133     static_variables_tuple=static_variables_tuple,
#     134     order_settings_arrays_tuple=order_settings_arrays_tuple,
#     135 )
#     136 return self.strat_results_df, self.settings_results_df
#
# File e:\coding\backtesters\quantfreedom\quantfreedom\base\base.py:79, in backtest_df_only(price_data, entries, static_variables_tuple, order_settings_arrays_tuple)
#      72 print(
#      73     f"Total candles to test: {total_indicator_settings * total_order_settings * total_bars:,}"
#      74 )
#      75 print(
#      76     f"\nTotal combinations to test: {total_indicator_settings * total_order_settings:,}"
#      77 )
# ---> 79 strat_array, settings_array = backtest_df_only_nb(
#      80     entries=entries.values,
#      81     num_of_symbols=num_of_symbols,
#      82     os_cart_arrays_tuple=os_cart_arrays_tuple,
#      83     price_data=price_data.values,
#      84     static_variables_tuple=static_variables_tuple,
#      85     total_bars=total_bars,
#      86     total_indicator_settings=total_indicator_settings,
#      87     total_order_settings=total_order_settings,
#      88 )
#      90 strat_results_df = pd.DataFrame(strat_array).sort_values(
#      91     by=["to_the_upside", "gains_pct"], ascending=False
#      92 )
#      94 symbols = list(price_data.columns.levels[0])
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\numba\core\dispatcher.py:468, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     464         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     465                f"by the following argument(s):\n{args_str}\n")
#     466         e.patch_message(msg)
# --> 468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
#     471     error_rewrite(e, 'unsupported_error')
#
# File e:\Coding\virtual environments\qfFree\lib\site-packages\numba\core\dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Unknown attribute 'min' of type float64
#
# File "..\quantfreedom\nb\buy_funcs.py", line 72:
# def long_increase_nb(
#     <source elided>
#             if sl_based_on == CandleBody.low:
#                 sl_price_new = prices.low.min() - (
#                 ^
#
# During: typing of get attribute at e:\coding\backtesters\quantfreedom\quantfreedom\nb\buy_funcs.py (72)
#
# File "..\quantfreedom\nb\buy_funcs.py", line 72:
# def long_increase_nb(
#     <source elided>
#             if sl_based_on == CandleBody.low:
#                 sl_price_new = prices.low.min() - (
#                 ^
#
# During: resolving callee type: type(CPUDispatcher(<function long_increase_nb at 0x000001E68FD9A950>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\execute_funcs.py (257)
#
# During: resolving callee type: type(CPUDispatcher(<function long_increase_nb at 0x000001E68FD9A950>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\execute_funcs.py (257)
#
# During: resolving callee type: type(CPUDispatcher(<function long_increase_nb at 0x000001E68FD9A950>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\execute_funcs.py (257)
#
# During: resolving callee type: type(CPUDispatcher(<function long_increase_nb at 0x000001E68FD9A950>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\execute_funcs.py (257)
#
#
# File "..\quantfreedom\nb\execute_funcs.py", line 257:
# def process_order_nb(
#     <source elided>
#     if order_type == OrderType.LongEntry:
#         account_state_new, order_result_new = long_increase_nb(
#         ^
#
# During: resolving callee type: type(CPUDispatcher(<function process_order_nb at 0x000001E68FE95510>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\simulate.py (227)
#
# During: resolving callee type: type(CPUDispatcher(<function process_order_nb at 0x000001E68FE95510>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\simulate.py (227)
#
# During: resolving callee type: type(CPUDispatcher(<function process_order_nb at 0x000001E68FE95510>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\simulate.py (227)
#
# During: resolving callee type: type(CPUDispatcher(<function process_order_nb at 0x000001E68FE95510>))
# During: typing of call at e:\coding\backtesters\quantfreedom\quantfreedom\nb\simulate.py (227)
#
#
# File "..\quantfreedom\nb\simulate.py", line 227:
# def backtest_df_only_nb(
#     <source elided>
#                         if not np.isnan(order_result.size_value):
#                             account_state, order_result = process_order_nb(
#                             ^

# %%
sm.strategy_dashboard([1,18, 8, 6])
