# %%
import numpy as np
import pandas as pd
from my_stuff import ApexTestKeys
from quantfreedom.exchanges.apex_exchange.apex import Apex

np.set_printoptions(formatter={"float_kind": "{:0.1f}".format})

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
apex_test = Apex(
    api_key=ApexTestKeys.api_key,
    secret_key=ApexTestKeys.secret_key,
    passphrase=ApexTestKeys.passphrase,
    stark_key_private=ApexTestKeys.stark_key_private,
    stark_key_public=ApexTestKeys.stark_key_public,
    stark_key_y=ApexTestKeys.stark_key_y,
    use_test_net=True
)

# %%
apex_test.get_candles(symbol="BTCUSDC", timeframe="5m", limit=50)
# Out:
# array([[1699448700000.0, 35444.0, 35457.0, 35435.0, 35438.0],
#        [1699449000000.0, 35438.0, 35443.0, 35375.0, 35380.0],
#        [1699449300000.0, 35380.0, 35380.0, 35328.0, 35331.0],
#        [1699449600000.0, 35331.0, 35333.0, 35325.0, 35325.0],
#        [1699449900000.0, 35325.0, 35346.0, 35320.0, 35346.0],
#        [1699450200000.0, 35346.0, 35352.0, 35339.0, 35352.0],
#        [1699450500000.0, 35352.0, 35361.0, 35352.0, 35361.0],
#        [1699450800000.0, 35361.0, 35370.0, 35349.0, 35349.0],
#        [1699451100000.0, 35349.0, 35369.0, 35347.0, 35369.0],
#        [1699451400000.0, 35369.0, 35400.0, 35369.0, 35400.0],
#        [1699451700000.0, 35400.0, 35421.0, 35400.0, 35421.0],
#        [1699452000000.0, 35421.0, 35436.0, 35384.0, 35384.0],
#        [1699452300000.0, 35384.0, 35410.0, 35378.0, 35410.0],
#        [1699452600000.0, 35410.0, 35423.0, 35402.0, 35419.0],
#        [1699452900000.0, 35419.0, 35426.0, 35406.0, 35425.0],
#        [1699453200000.0, 35425.0, 35425.0, 35393.0, 35395.0],
#        [1699453500000.0, 35395.0, 35416.0, 35395.0, 35415.0],
#        [1699453800000.0, 35415.0, 35415.0, 35386.0, 35389.0],
#        [1699454100000.0, 35389.0, 35389.0, 35343.0, 35343.0],
#        [1699454400000.0, 35343.0, 35343.0, 35297.0, 35303.0],
#        [1699454700000.0, 35303.0, 35312.0, 35293.0, 35305.0],
#        [1699455000000.0, 35305.0, 35307.0, 35290.0, 35302.0],
#        [1699455300000.0, 35302.0, 35318.0, 35300.0, 35318.0],
#        [1699455600000.0, 35318.0, 35333.0, 35268.0, 35268.0],
#        [1699455900000.0, 35268.0, 35276.0, 35256.0, 35264.0],
#        [1699456200000.0, 35264.0, 35264.0, 35226.0, 35226.0],
#        [1699456500000.0, 35226.0, 35264.0, 35223.0, 35260.0],
#        [1699456800000.0, 35260.0, 35260.0, 35200.0, 35200.0],
#        [1699457100000.0, 35200.0, 35200.0, 35154.0, 35182.0],
#        [1699457400000.0, 35182.0, 35208.0, 35179.0, 35187.0],
#        [1699457700000.0, 35187.0, 35215.0, 35173.0, 35205.0],
#        [1699458000000.0, 35205.0, 35218.0, 35184.0, 35218.0],
#        [1699458300000.0, 35218.0, 35232.0, 35208.0, 35232.0],
#        [1699458600000.0, 35232.0, 35233.0, 35193.0, 35207.0],
#        [1699458900000.0, 35207.0, 35234.0, 35207.0, 35234.0],
#        [1699459200000.0, 35234.0, 35234.0, 35211.0, 35234.0],
#        [1699459500000.0, 35234.0, 35234.0, 35191.0, 35192.0],
#        [1699459800000.0, 35192.0, 35203.0, 35192.0, 35203.0],
#        [1699460100000.0, 35203.0, 35223.0, 35192.0, 35223.0],
#        [1699460400000.0, 35223.0, 35242.0, 35223.0, 35226.0],
#        [1699460700000.0, 35226.0, 35227.0, 35223.0, 35227.0],
#        [1699461000000.0, 35227.0, 35239.0, 35227.0, 35231.0],
#        [1699461300000.0, 35231.0, 35281.0, 35231.0, 35280.0],
#        [1699461600000.0, 35280.0, 35381.0, 35274.5, 35368.0],
#        [1699461900000.0, 35368.0, 35373.0, 35338.0, 35373.0],
#        [1699462200000.0, 35373.0, 35449.0, 35373.0, 35438.0],
#        [1699462500000.0, 35438.0, 35444.0, 35406.0, 35406.0],
#        [1699462800000.0, 35406.0, 35422.0, 35371.0, 35375.0],
#        [1699463100000.0, 35375.0, 35377.0, 35333.0, 35333.0],
#        [1699463400000.0, 35333.0, 35340.0, 35331.0, 35332.0]])

# %%
from datetime import datetime


datetime.now().timestamp()
# Out:
# 1699468106.815466

# %%
from time import time

time()
# Out:
# 1699468106.8244689
