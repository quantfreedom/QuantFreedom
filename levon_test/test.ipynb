# %%
import numpy as np
import pandas as pd
from quantfreedom.levon_qf.talib_ind_levon import from_talib

# %%
price_data = pd.read_hdf('../tests/data/prices.hd5')

# %%
stoch_data = from_talib(
     func_name="stoch",
     price_data=price_data,
    fastk_period=[15, 30, 40],
    column_wise_combos=True,
    plot_results=False,
    # price="low",
)
rsi_data = from_talib(
     func_name="rsi",
     price_data=price_data,
    timeperiod=[15, 30, 40],
    plot_results=False,
    # price="low",
)
rsi_ema_ind = from_talib(
    func_name='ema',
    indicator_data=rsi_data.data,
    cart_product=False,
    combos=False,
    timeperiod=[25, 45]
)
# rsibelow = rsi_data.is_below(user_args=[40, 50])

# %%
rsi_ema_ind.data
# Out:
# symbol              BTCUSDT                               EOSUSD              \
# RSI_timeperiod           15          30          40           15          30
# RSI_EMA_timeperiod       25    45    25    45    25    45     25    45    25
# open_time
# 2020-10-01 00:00:00     NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 00:30:00     NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 01:00:00     NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 01:30:00     NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 02:00:00     NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN   NaN
# ...                     ...   ...   ...   ...   ...   ...    ...   ...   ...
# 2021-04-14 21:30:00   45.96 50.49 50.49 53.80 52.10 54.80  49.37 51.86 52.38
# 2021-04-14 22:00:00   45.80 50.20 50.22 53.51 51.84 54.54  49.80 51.99 52.49
# 2021-04-14 22:30:00   45.85 50.04 50.07 53.28 51.68 54.33  50.35 52.21 52.67
# 2021-04-14 23:00:00   46.08 49.98 50.02 53.11 51.60 54.17  51.05 52.52 52.94
# 2021-04-14 23:30:00   46.20 49.88 49.93 52.93 51.48 53.99  51.33 52.62 53.01
#
# symbol                     ... LTCUSDT                   XRPUSD              \
# RSI_timeperiod             ...      30          40           15          30
# RSI_EMA_timeperiod     45  ...      25    45    25    45     25    45    25
# open_time                  ...
# 2020-10-01 00:00:00   NaN  ...     NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 00:30:00   NaN  ...     NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 01:00:00   NaN  ...     NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 01:30:00   NaN  ...     NaN   NaN   NaN   NaN    NaN   NaN   NaN
# 2020-10-01 02:00:00   NaN  ...     NaN   NaN   NaN   NaN    NaN   NaN   NaN
# ...                   ...  ...     ...   ...   ...   ...    ...   ...   ...
# 2021-04-14 21:30:00 54.35  ...   51.28 52.66 52.03 53.19  48.56 51.41 51.46
# 2021-04-14 22:00:00 54.33  ...   51.69 52.83 52.33 53.31  48.84 51.44 51.49
# 2021-04-14 22:30:00 54.35  ...   52.01 52.96 52.57 53.40  49.22 51.54 51.59
# 2021-04-14 23:00:00 54.43  ...   52.37 53.12 52.84 53.51  49.81 51.77 51.80
# 2021-04-14 23:30:00 54.40  ...   52.73 53.29 53.10 53.63  50.42 52.03 52.03
#
# symbol
# RSI_timeperiod               40
# RSI_EMA_timeperiod     45    25    45
# open_time
# 2020-10-01 00:00:00   NaN   NaN   NaN
# 2020-10-01 00:30:00   NaN   NaN   NaN
# 2020-10-01 01:00:00   NaN   NaN   NaN
# 2020-10-01 01:30:00   NaN   NaN   NaN
# 2020-10-01 02:00:00   NaN   NaN   NaN
# ...                   ...   ...   ...
# 2021-04-14 21:30:00 54.04 52.78 55.03
# 2021-04-14 22:00:00 53.94 52.76 54.92
# 2021-04-14 22:30:00 53.89 52.80 54.85
# 2021-04-14 23:00:00 53.91 52.93 54.83
# 2021-04-14 23:30:00 53.95 53.08 54.83
#
# [9408 rows x 30 columns]

# %%
rsi_data.is_below(indicator_data=rsi_ema_ind.data)
# Out:
# symbol              BTCUSDT                                    EOSUSD         \
# RSI_timeperiod           15            30            40            15
# RSI_EMA_timeperiod       25     45     25     45     25     45     25     45
# EMA_is_below            RSI    RSI    RSI    RSI    RSI    RSI    RSI    RSI
# open_time
# 2020-10-01 00:00:00   False  False  False  False  False  False  False  False
# 2020-10-01 00:30:00   False  False  False  False  False  False  False  False
# 2020-10-01 01:00:00   False  False  False  False  False  False  False  False
# 2020-10-01 01:30:00   False  False  False  False  False  False  False  False
# 2020-10-01 02:00:00   False  False  False  False  False  False  False  False
# ...                     ...    ...    ...    ...    ...    ...    ...    ...
# 2021-04-14 21:30:00   False  False  False  False  False  False   True   True
# 2021-04-14 22:00:00   False  False  False  False  False  False   True   True
# 2021-04-14 22:30:00    True  False  False  False  False  False   True   True
# 2021-04-14 23:00:00    True  False  False  False  False  False   True   True
# 2021-04-14 23:30:00    True  False  False  False  False  False   True   True
#
# symbol                             ... LTCUSDT                      XRPUSD  \
# RSI_timeperiod          30         ...      30            40            15
# RSI_EMA_timeperiod      25     45  ...      25     45     25     45     25
# EMA_is_below           RSI    RSI  ...     RSI    RSI    RSI    RSI    RSI
# open_time                          ...
# 2020-10-01 00:00:00  False  False  ...   False  False  False  False  False
# 2020-10-01 00:30:00  False  False  ...   False  False  False  False  False
# 2020-10-01 01:00:00  False  False  ...   False  False  False  False  False
# 2020-10-01 01:30:00  False  False  ...   False  False  False  False  False
# 2020-10-01 02:00:00  False  False  ...   False  False  False  False  False
# ...                    ...    ...  ...     ...    ...    ...    ...    ...
# 2021-04-14 21:30:00   True  False  ...    True   True   True   True   True
# 2021-04-14 22:00:00   True  False  ...    True   True   True   True   True
# 2021-04-14 22:30:00   True   True  ...    True   True   True   True   True
# 2021-04-14 23:00:00   True   True  ...    True   True   True   True   True
# 2021-04-14 23:30:00   True  False  ...    True   True   True   True   True
#
# symbol
# RSI_timeperiod                 30            40
# RSI_EMA_timeperiod      45     25     45     25     45
# EMA_is_below           RSI    RSI    RSI    RSI    RSI
# open_time
# 2020-10-01 00:00:00  False  False  False  False  False
# 2020-10-01 00:30:00  False  False  False  False  False
# 2020-10-01 01:00:00  False  False  False  False  False
# 2020-10-01 01:30:00  False  False  False  False  False
# 2020-10-01 02:00:00  False  False  False  False  False
# ...                    ...    ...    ...    ...    ...
# 2021-04-14 21:30:00   True   True  False   True  False
# 2021-04-14 22:00:00   True   True  False  False  False
# 2021-04-14 22:30:00   True   True  False   True  False
# 2021-04-14 23:00:00   True   True   True   True  False
# 2021-04-14 23:30:00   True   True   True   True   True
#
# [9408 rows x 30 columns]
