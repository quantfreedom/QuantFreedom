# %%
import numpy as np
import pandas as pd
from quantfreedom.base.strategy_maker_cls import StrategyMaker
from quantfreedom.indicators.talib_ind import from_talib
from quantfreedom.enums.enums import (
    CandleBody,
    LeverageMode,
    OrderType,
    SizeType,
    OrderSettingsArrays,
    StaticVariables,
)

np.set_printoptions(formatter={"float_kind": "{:.2f}".format})
pd.options.display.float_format = "{:,.2f}".format

# prices = data_download_from_ccxt(
#     exchange='bybit',
#     start='2020-10-01T00:00:00Z',
#     end='2021-04-15T00:00:00Z',
#     symbols=['BTCUSDT', 'ETHUSD'],
#     timeframe='30m',
# )

sm = StrategyMaker()

price_data = pd.read_hdf("../QuantFreedom/tests/data/prices.hd5")
# %load_ext autoreload
# %autoreload 2

# %%
rsi_ind = from_talib(
    func_name='rsi',
    nickname='rsi',
    price_data=price_data,
    input_names = ['open'],
    parameters = {'timeperiod': [15, 20]}
)

# %%
entries = rsi_ind.is_below(
    user_args=[40, 50],
    candle_ohlc="close",
)

# %%
entries
# Out:
# symbol               BTCUSDT                        EOSUSD                \
# rsi_output              real                          real
# rsi_candle_body     ["open"]                      ["open"]
# rsi_timeperiod            15            20              15            20
# rsi_is_below              40     50     40     50       40     50     40
# open_time
# 2020-10-01 00:00:00    False  False  False  False    False  False  False
# 2020-10-01 00:30:00    False  False  False  False    False  False  False
# 2020-10-01 01:00:00    False  False  False  False    False  False  False
# 2020-10-01 01:30:00    False  False  False  False    False  False  False
# 2020-10-01 02:00:00    False  False  False  False    False  False  False
# ...                      ...    ...    ...    ...      ...    ...    ...
# 2021-04-14 21:30:00    False   True  False   True    False  False  False
# 2021-04-14 22:00:00    False   True  False   True    False  False  False
# 2021-04-14 22:30:00    False   True  False   True    False  False  False
# 2021-04-14 23:00:00    False   True  False   True    False  False  False
# 2021-04-14 23:30:00    False   True  False   True    False  False  False
#
# symbol                       ETHUSD                       LTCUSDT         \
# rsi_output                     real                          real
# rsi_candle_body            ["open"]                      ["open"]
# rsi_timeperiod                   15            20              15
# rsi_is_below            50       40     50     40     50       40     50
# open_time
# 2020-10-01 00:00:00  False    False  False  False  False    False  False
# 2020-10-01 00:30:00  False    False  False  False  False    False  False
# 2020-10-01 01:00:00  False    False  False  False  False    False  False
# 2020-10-01 01:30:00  False    False  False  False  False    False  False
# 2020-10-01 02:00:00  False    False  False  False  False    False  False
# ...                    ...      ...    ...    ...    ...      ...    ...
# 2021-04-14 21:30:00  False    False  False  False  False    False  False
# 2021-04-14 22:00:00  False    False  False  False  False    False  False
# 2021-04-14 22:30:00  False    False  False  False  False    False  False
# 2021-04-14 23:00:00  False    False  False  False  False    False  False
# 2021-04-14 23:30:00  False    False  False  False  False    False  False
#
# symbol                              XRPUSD
# rsi_output                            real
# rsi_candle_body                   ["open"]
# rsi_timeperiod          20              15            20
# rsi_is_below            40     50       40     50     40     50
# open_time
# 2020-10-01 00:00:00  False  False    False  False  False  False
# 2020-10-01 00:30:00  False  False    False  False  False  False
# 2020-10-01 01:00:00  False  False    False  False  False  False
# 2020-10-01 01:30:00  False  False    False  False  False  False
# 2020-10-01 02:00:00  False  False    False  False  False  False
# ...                    ...    ...      ...    ...    ...    ...
# 2021-04-14 21:30:00  False  False    False  False  False  False
# 2021-04-14 22:00:00  False  False    False  False  False  False
# 2021-04-14 22:30:00  False  False    False  False  False  False
# 2021-04-14 23:00:00  False  False    False  False  False  False
# 2021-04-14 23:30:00  False  False    False  False  False  False
#
# [9408 rows x 20 columns]

# %%
static_vars = StaticVariables(
    equity=1000.,
    lev_mode=LeverageMode.LeastFreeCashUsed,
    order_type=OrderType.LongEntry,
    size_type=SizeType.RiskPercentOfAccount,
)
order_settings = OrderSettingsArrays(
    max_equity_risk_pct=6.,
    risk_reward=[2,4,5],
    size_pct=1.,
    sl_based_on=CandleBody.low,
    sl_based_on_lookback=30,
    sl_based_on_add_pct=.2,
)

# %%
strat_results_df, settings_results_df = sm.backtest_df(
    price_data=price_data,
    static_variables_tuple=static_vars,
    order_settings_arrays_tuple=order_settings,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 strat_results_df, settings_results_df = sm.backtest_df(
#       2     price_data=price_data,
#       3     static_variables_tuple=static_vars,
#       4     order_settings_arrays_tuple=order_settings,
#       5 )
#
# File e:\Coding\backtesters\QuantFreedom\quantfreedom\base\strategy_maker_cls.py:125, in StrategyMaker.backtest_df(self, price_data, static_variables_tuple, order_settings_arrays_tuple)
#     123 entries = self.combined_data
#     124 if entries is None:
# --> 125     raise ValueError("You have to call combine data method first.")
#     127 self.price_data = price_data
#     128 self.static_vars = static_variables_tuple
#
# ValueError: You have to call combine data method first.

# %%
# sm.strategy_dashboard([1,18, 8, 6])
